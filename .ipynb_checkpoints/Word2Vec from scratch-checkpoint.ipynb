# %%
import string
import re
import numpy as np
import random

# %%
def toWord(x, dic):
    return dic[np.argmax(x)]
def toVec(x, dic):
    newVec = np.zeros((len(dic), 1))
    index = np.where(np.array(dic) == x)
    newVec[index] = 1
    return newVec


f = open("tekst.txt", "r")
stopwords = open("stopwords.txt", "r")
stops = []
dictionary = []
vecs = []
targets = []
contexts = []
cleanText = ""
print("cleaning text")
for l in stopwords:
    stops.append(l[0:-1])
for l in f:
    words = l.split(" ")
    for w in words:
        re.sub(r'[^\w\s]', '', w.lower().strip("\n")) 
        formated = re.sub(r'[^\w\s]', '', w.lower().strip("\n"))
        if formated not in stops and len(formated) > 1:
            cleanText += (" " + formated)
            if formated not in dictionary:
                dictionary.append(formated.strip(" "))
      
    
    
print("Dict dimensions: " + str(len(dictionary)))
for i in range(0, len(dictionary)):
    newVec = np.zeros((len(dictionary), 1))
    newVec[i] = 1
    vecs.append(newVec)
    
print("vecs done")

wrds = cleanText.split(" ")
for i in range(2, len(wrds)-2):
    targets.append([toVec(wrds[i], dictionary)])
    contexts.append([toVec(wrds[i-2], dictionary), toVec(wrds[i-1], dictionary), toVec(wrds[i+1], dictionary), toVec(wrds[i+2], dictionary)])
    print("target: " + wrds[i] + "  context: " + wrds[i-2] + ", " + wrds[i-1] + ", "+ wrds[i+1] + ", "+ wrds[i+2])
    if i%1000 == 0:
        print(float(i)/len(wrds))
print("finished making pairs")
f.close()
stopwords.close()
# Out:
# cleaning text
# Dict dimensions: 17
# vecs done
# target: king  context: , future, prince, daughter
# target: prince  context: future, king, daughter, princess
# target: daughter  context: king, prince, princess, son
# target: princess  context: prince, daughter, son, prince
# target: son  context: daughter, princess, prince, man
# target: prince  context: princess, son, man, king
# target: man  context: son, prince, king, woman
# target: king  context: prince, man, woman, queen
# target: woman  context: man, king, queen, princess
# target: queen  context: king, woman, princess, queen
# target: princess  context: woman, queen, queen, queen
# target: queen  context: queen, princess, queen, king
# target: queen  context: princess, queen, king, rule
# target: king  context: queen, queen, rule, realm
# target: rule  context: queen, king, realm, prince
# target: realm  context: king, rule, prince, strong
# target: prince  context: rule, realm, strong, man
# target: strong  context: realm, prince, man, princess
# target: man  context: prince, strong, princess, beautiful
# target: princess  context: strong, man, beautiful, woman
# target: beautiful  context: man, princess, woman, royal
# target: woman  context: princess, beautiful, royal, family
# target: royal  context: beautiful, woman, family, king
# target: family  context: woman, royal, king, queen
# target: king  context: royal, family, queen, children
# target: queen  context: family, king, children, prince
# target: children  context: king, queen, prince, boy
# target: prince  context: queen, children, boy, boy
# target: boy  context: children, prince, boy, man
# finished making pairs

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))
def softmax(x, temp=1.0):
    xt = x/temp
    e_x = np.exp(xt - np.max(xt))
    return e_x / e_x.sum(axis=0)
def MSE(guess, target):
    return np.power(target-guess, 2)
def MSE_der(guess, target):
    return 2 * (guess-target)

# %%
class Word2Vec:
    def __init__(self, lr):
        self.learnRate = lr
        self.layers = []
        
    def addLayer(self, inp, out, act="none"):
        newLayer = Layer(inp, out, self.learnRate, act)
        self.layers.append(newLayer)
        
    def forward(self, x):
        self.layers[0].forward(x)
        for i in range(1, len(self.layers)):
            self.layers[i].forward(self.layers[i-1].a)
        return self.layers[-1].a
    
    def backprop(self, inp, ans, t):
        grad = MSE_der(self.layers[-1].a, ans)
        for i in range(1, len(self.layers)):
            grad = self.layers[-i].backprop(grad, self.layers[-i-1].a, t)
        self.layers[0].backprop(grad, inp, t)

# %%
class Layer:
    def __init__(self, inp, out, lr, act="none"):
        self.inputs = inp
        self.neurons = out
        self.activation = act
        self.learnRate = lr
        self.weights = np.random.uniform(-1, 1, (out, inp))
        self.bias = np.random.uniform(-1, 1, (out, 1))
        self.a = []
        self.z = []
        
        self.mw = np.zeros(self.weights.shape)
        self.mb = np.zeros(self.bias.shape)
        self.vw = np.zeros(self.weights.shape)
        self.vb = np.zeros(self.bias.shape)
        
    def forward(self, x):
        self.z = self.weights@x + self.bias
        if self.activation == "none":
            self.a = self.z
        elif self.activation == "sigmoid":
            self.a = sigmoid(self.z)
        elif self.activation == "tanh":
            self.a = np.tanh(self.z)
        elif self.activation == "softmax":
            self.a = softmax(self.z, 0.5)
            
    def backprop(self, grad, x, t):
        inp = np.array(x)
        
        d0 = grad
        d1 = d0
        if self.activation == "sigmoid":
            d1 *= (self.a * (1 - self.a))
        elif self.activation == "tanh":
            d1 *= (1 - np.power(self.a, 2))
        elif self.activation == "softmax":
            d1 *= self.a
        dX = self.weights.T @ d1
        dW = d1 @ inp.T
        dB = d1
        newGrad = dX
        
        beta1 = 0.9
        beta2 = 0.999
        
        self.mw = self.mw * beta1 + (1-beta1) * dW
        self.mb = self.mb * beta1 + (1-beta1) * dB
        
        self.vw = self.vw * beta2 + (1-beta2) * np.power(dW, 2)
        self.vb = self.vb * beta2 + (1-beta2) * np.power(dB, 2)
        
        beta1pow = (1 - pow(beta1, t))
        beta2pow = (1 - pow(beta2, t))
        
        mw_hat = self.mw / beta1pow
        mb_hat = self.mb / beta1pow
        
        vw_hat = self.vw / beta2pow
        vb_hat = self.vb / beta2pow
        
        epsilon = 0.0000001
        
        dW = mw_hat / (np.sqrt(vw_hat) + epsilon)
        dB = mb_hat / (np.sqrt(vb_hat) + epsilon)
        
        self.weights = self.weights - dW * self.learnRate 
        self.bias    = self.bias    - dB * self.learnRate
        
        return newGrad

# %%
network = Word2Vec(0.005)
network.addLayer(len(dictionary), 300, "none")
network.addLayer(300, len(dictionary), "softmax")

# %%
epoch = 4000
for e in range(0, epoch+1):
    if e%1 == 0:
        print("Epoch: " + str(e))
        index = random.randint(0, len(targets)-1)
        print("target: " + toWord(targets[index][0], dictionary))
        print(str(index) + " " + " context word: " + toWord(network.forward(contexts[index][1]), dictionary))
    for t in range(0, len(targets)-1):
        if t%100 == 0:
            print((t/(len(targets)-1.0))*100.0)
        for c in range(0, 4):
            network.forward(targets[t][0])
            network.backprop(targets[t][0], contexts[t][c], t+1)
# Out:
# Epoch: 0
# target: man
# 6  context word: son
# 0.0
# Epoch: 1
# target: son
# 4  context word: royal
# 0.0
# Epoch: 2
# target: daughter
# 2  context word: children
# 0.0
# Epoch: 3
# target: queen
# 25  context word: realm
# 0.0
# Epoch: 4
# target: princess
# 10  context word: prince
# 0.0
# Epoch: 5
# target: queen
# 11  context word: royal
# 0.0
# Epoch: 6
# target: king
# 13  context word: family
# 0.0
# Epoch: 7
# target: queen
# 25  context word: royal
# 0.0
# Epoch: 8
# target: prince
# 16  context word: king
# 0.0
# Epoch: 9
# target: boy
# 28  context word: family
# 0.0
# Epoch: 10
# target: rule
# 14  context word: queen
# 0.0
# Epoch: 11
# target: woman
# 8  context word: royal
# 0.0
# Epoch: 12
# target: princess
# 19  context word: princess
# 0.0
# Epoch: 13
# target: princess
# 3  context word: son
# 0.0
# Epoch: 14
# target: princess
# 10  context word: family
# 0.0
# Epoch: 15
# target: boy
# 28  context word: rule
# 0.0
# Epoch: 16
# target: children
# 26  context word: family
# 0.0
# Epoch: 17
# target: queen
# 12  context word: boy
# 0.0
# Epoch: 18
# target: daughter
# 2  context word: children
# 0.0
# Epoch: 19
# target: queen
# 11  context word: family
# 0.0
# Epoch: 20
# target: queen
# 25  context word: queen
# 0.0
# Epoch: 21
# target: princess
# 10  context word: children
# 0.0
# Epoch: 22
# target: son
# 4  context word: royal
# 0.0
# Epoch: 23
# target: boy
# 28  context word: children
# 0.0
# Epoch: 24
# target: man
# 6  context word: princess
# 0.0
# Epoch: 25
# target: king
# 0  context word: family
# 0.0
# Epoch: 26
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 27
# target: royal
# 22  context word: daughter
# 0.0
# Epoch: 28
# target: prince
# 16  context word: prince
# 0.0
# Epoch: 29
# target: princess
# 10  context word: boy
# 0.0
# Epoch: 30
# target: prince
# 1  context word: queen
# 0.0
# Epoch: 31
# target: man
# 6  context word: children
# 0.0
# Epoch: 32
# target: man
# 18  context word: princess
# 0.0
# Epoch: 33
# target: beautiful
# 20  context word: prince
# 0.0
# Epoch: 34
# target: queen
# 12  context word: prince
# 0.0
# Epoch: 35
# target: king
# 7  context word: princess
# 0.0
# Epoch: 36
# target: woman
# 21  context word: boy
# 0.0
# Epoch: 37
# target: prince
# 27  context word: prince
# 0.0
# Epoch: 38
# target: princess
# 19  context word: woman
# 0.0
# Epoch: 39
# target: princess
# 10  context word: queen
# 0.0
# Epoch: 40
# target: princess
# 10  context word: children
# 0.0
# Epoch: 41
# target: prince
# 16  context word: boy
# 0.0
# Epoch: 42
# target: queen
# 12  context word: prince
# 0.0
# Epoch: 43
# target: queen
# 12  context word: prince
# 0.0
# Epoch: 44
# target: king
# 24  context word: queen
# 0.0
# Epoch: 45
# target: prince
# 1  context word: children
# 0.0
# Epoch: 46
# target: realm
# 15  context word: prince
# 0.0
# Epoch: 47
# target: man
# 6  context word: children
# 0.0
# Epoch: 48
# target: prince
# 27  context word: prince
# 0.0
# Epoch: 49
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 50
# target: beautiful
# 20  context word: queen
# 0.0
# Epoch: 51
# target: strong
# 17  context word: boy
# 0.0
# Epoch: 52
# target: princess
# 3  context word: queen
# 0.0
# Epoch: 53
# target: king
# 13  context word: children
# 0.0
# Epoch: 54
# target: king
# 7  context word: strong
# 0.0
# Epoch: 55
# target: beautiful
# 20  context word: queen
# 0.0
# Epoch: 56
# target: man
# 6  context word: children
# 0.0
# Epoch: 57
# target: princess
# 10  context word: king
# 0.0
# Epoch: 58
# target: woman
# 21  context word: woman
# 0.0
# Epoch: 59
# target: princess
# 3  context word: son
# 0.0
# Epoch: 60
# target: prince
# 27  context word: boy
# 0.0
# Epoch: 61
# target: strong
# 17  context word: boy
# 0.0
# Epoch: 62
# target: woman
# 21  context word: strong
# 0.0
# Epoch: 63
# target: prince
# 27  context word: boy
# 0.0
# Epoch: 64
# target: woman
# 8  context word: royal
# 0.0
# Epoch: 65
# target: man
# 6  context word: man
# 0.0
# Epoch: 66
# target: prince
# 27  context word: royal
# 0.0
# Epoch: 67
# target: woman
# 8  context word: queen
# 0.0
# Epoch: 68
# target: beautiful
# 20  context word: strong
# 0.0
# Epoch: 69
# target: woman
# 8  context word: rule
# 0.0
# Epoch: 70
# target: royal
# 22  context word: strong
# 0.0
# Epoch: 71
# target: realm
# 15  context word: future
# 0.0
# Epoch: 72
# target: strong
# 17  context word: rule
# 0.0
# Epoch: 73
# target: king
# 24  context word: king
# 0.0
# Epoch: 74
# target: royal
# 22  context word: realm
# 0.0
# Epoch: 75
# target: woman
# 8  context word: children
# 0.0
# Epoch: 76
# target: daughter
# 2  context word: future
# 0.0
# Epoch: 77
# target: prince
# 5  context word: daughter
# 0.0
# Epoch: 78
# target: queen
# 11  context word: prince
# 0.0
# Epoch: 79
# target: daughter
# 2  context word: strong
# 0.0
# Epoch: 80
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 81
# target: prince
# 1  context word: woman
# 0.0
# Epoch: 82
# target: queen
# 12  context word: woman
# 0.0
# Epoch: 83
# target: princess
# 3  context word: strong
# 0.0
# Epoch: 84
# target: queen
# 25  context word: future
# 0.0
# Epoch: 85
# target: queen
# 25  context word: queen
# 0.0
# Epoch: 86
# target: king
# 13  context word: queen
# 0.0
# Epoch: 87
# target: queen
# 12  context word: man
# 0.0
# Epoch: 88
# target: king
# 24  context word: queen
# 0.0
# Epoch: 89
# target: prince
# 5  context word: daughter
# 0.0
# Epoch: 90
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 91
# target: princess
# 3  context word: princess
# 0.0
# Epoch: 92
# target: queen
# 12  context word: beautiful
# 0.0
# Epoch: 93
# target: daughter
# 2  context word: woman
# 0.0
# Epoch: 94
# target: realm
# 15  context word: rule
# 0.0
# Epoch: 95
# target: prince
# 5  context word: daughter
# 0.0
# Epoch: 96
# target: king
# 7  context word: strong
# 0.0
# Epoch: 97
# target: queen
# 11  context word: royal
# 0.0
# Epoch: 98
# target: king
# 24  context word: beautiful
# 0.0
# Epoch: 99
# target: king
# 24  context word: man
# 0.0
# Epoch: 100
# target: woman
# 21  context word: strong
# 0.0
# Epoch: 101
# target: daughter
# 2  context word: beautiful
# 0.0
# Epoch: 102
# target: rule
# 14  context word: children
# 0.0
# Epoch: 103
# target: daughter
# 2  context word: woman
# 0.0
# Epoch: 104
# target: prince
# 1  context word: queen
# 0.0
# Epoch: 105
# target: princess
# 10  context word: strong
# 0.0
# Epoch: 106
# target: king
# 13  context word: queen
# 0.0
# Epoch: 107
# target: king
# 13  context word: king
# 0.0
# Epoch: 108
# target: prince
# 16  context word: strong
# 0.0
# Epoch: 109
# target: daughter
# 2  context word: woman
# 0.0
# Epoch: 110
# target: prince
# 5  context word: daughter
# 0.0
# Epoch: 111
# target: princess
# 10  context word: beautiful
# 0.0
# Epoch: 112
# target: prince
# 5  context word: man
# 0.0
# Epoch: 113
# target: princess
# 10  context word: king
# 0.0
# Epoch: 114
# target: queen
# 11  context word: beautiful
# 0.0
# Epoch: 115
# target: queen
# 12  context word: queen
# 0.0
# Epoch: 116
# target: prince
# 5  context word: man
# 0.0
# Epoch: 117
# target: children
# 26  context word: man
# 0.0
# Epoch: 118
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 119
# target: princess
# 10  context word: king
# 0.0
# Epoch: 120
# target: children
# 26  context word: beautiful
# 0.0
# Epoch: 121
# target: woman
# 8  context word: future
# 0.0
# Epoch: 122
# target: prince
# 5  context word: beautiful
# 0.0
# Epoch: 123
# target: king
# 0  context word: future
# 0.0
# Epoch: 124
# target: son
# 4  context word: queen
# 0.0
# Epoch: 125
# target: realm
# 15  context word: daughter
# 0.0
# Epoch: 126
# target: prince
# 27  context word: realm
# 0.0
# Epoch: 127
# target: prince
# 1  context word: queen
# 0.0
# Epoch: 128
# target: boy
# 28  context word: future
# 0.0
# Epoch: 129
# target: woman
# 8  context word: realm
# 0.0
# Epoch: 130
# target: king
# 24  context word: beautiful
# 0.0
# Epoch: 131
# target: children
# 26  context word: future
# 0.0
# Epoch: 132
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 133
# target: boy
# 28  context word: boy
# 0.0
# Epoch: 134
# target: royal
# 22  context word: son
# 0.0
# Epoch: 135
# target: princess
# 10  context word: queen
# 0.0
# Epoch: 136
# target: son
# 4  context word: queen
# 0.0
# Epoch: 137
# target: queen
# 25  context word: beautiful
# 0.0
# Epoch: 138
# target: king
# 13  context word: future
# 0.0
# Epoch: 139
# target: woman
# 8  context word: future
# 0.0
# Epoch: 140
# target: prince
# 1  context word: beautiful
# 0.0
# Epoch: 141
# target: man
# 6  context word: son
# 0.0
# Epoch: 142
# target: family
# 23  context word: man
# 0.0
# Epoch: 143
# target: prince
# 5  context word: daughter
# 0.0
# Epoch: 144
# target: boy
# 28  context word: son
# 0.0
# Epoch: 145
# target: prince
# 5  context word: princess
# 0.0
# Epoch: 146
# target: prince
# 5  context word: daughter
# 0.0
# Epoch: 147
# target: family
# 23  context word: strong
# 0.0
# Epoch: 148
# target: man
# 18  context word: man
# 0.0
# Epoch: 149
# target: queen
# 25  context word: daughter
# 0.0
# Epoch: 150
# target: strong
# 17  context word: rule
# 0.0
# Epoch: 151
# target: children
# 26  context word: princess
# 0.0
# Epoch: 152
# target: man
# 18  context word: man
# 0.0
# Epoch: 153
# target: royal
# 22  context word: man
# 0.0
# Epoch: 154
# target: man
# 18  context word: princess
# 0.0
# Epoch: 155
# target: prince
# 27  context word: realm
# 0.0
# Epoch: 156
# target: boy
# 28  context word: beautiful
# 0.0
# Epoch: 157
# target: queen
# 12  context word: son
# 0.0
# Epoch: 158
# target: man
# 18  context word: man
# 0.0
# Epoch: 159
# target: princess
# 10  context word: man
# 0.0
# Epoch: 160
# target: children
# 26  context word: king
# 0.0
# Epoch: 161
# target: boy
# 28  context word: rule
# 0.0
# Epoch: 162
# target: king
# 0  context word: future
# 0.0
# Epoch: 163
# target: queen
# 12  context word: queen
# 0.0
# Epoch: 164
# target: beautiful
# 20  context word: beautiful
# 0.0
# Epoch: 165
# target: princess
# 10  context word: princess
# 0.0
# Epoch: 166
# target: man
# 6  context word: royal
# 0.0
# Epoch: 167
# target: children
# 26  context word: king
# 0.0
# Epoch: 168
# target: queen
# 25  context word: queen
# 0.0
# Epoch: 169
# target: daughter
# 2  context word: strong
# 0.0
# Epoch: 170
# target: family
# 23  context word: strong
# 0.0
# Epoch: 171
# target: daughter
# 2  context word: man
# 0.0
# Epoch: 172
# target: king
# 7  context word: strong
# 0.0
# Epoch: 173
# target: queen
# 9  context word: beautiful
# 0.0
# Epoch: 174
# target: woman
# 21  context word: realm
# 0.0
# Epoch: 175
# target: realm
# 15  context word: beautiful
# 0.0
# Epoch: 176
# target: queen
# 12  context word: future
# 0.0
# Epoch: 177
# target: princess
# 3  context word: son
# 0.0
# Epoch: 178
# target: boy
# 28  context word: son
# 0.0
# Epoch: 179
# target: king
# 13  context word: beautiful
# 0.0
# Epoch: 180
# target: queen
# 12  context word: son
# 0.0
# Epoch: 181
# target: beautiful
# 20  context word: beautiful
# 0.0
# Epoch: 182
# target: princess
# 10  context word: son
# 0.0
# Epoch: 183
# target: strong
# 17  context word: daughter
# 0.0
# Epoch: 184
# target: prince
# 5  context word: man
# 0.0
# Epoch: 185
# target: queen
# 12  context word: strong
# 0.0
# Epoch: 186
# target: prince
# 16  context word: rule
# 0.0
# Epoch: 187
# target: children
# 26  context word: beautiful
# 0.0
# Epoch: 188
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 189
# target: son
# 4  context word: beautiful
# 0.0
# Epoch: 190
# target: prince
# 16  context word: rule
# 0.0
# Epoch: 191
# target: daughter
# 2  context word: woman
# 0.0
# Epoch: 192
# target: queen
# 9  context word: man
# 0.0
# Epoch: 193
# target: king
# 0  context word: strong
# 0.0
# Epoch: 194
# target: woman
# 8  context word: future
# 0.0
# Epoch: 195
# target: prince
# 5  context word: daughter
# 0.0
# Epoch: 196
# target: family
# 23  context word: son
# 0.0
# Epoch: 197
# target: man
# 6  context word: children
# 0.0
# Epoch: 198
# target: prince
# 16  context word: children
# 0.0
# Epoch: 199
# target: son
# 4  context word: beautiful
# 0.0
# Epoch: 200
# target: strong
# 17  context word: future
# 0.0
# Epoch: 201
# target: prince
# 16  context word: beautiful
# 0.0
# Epoch: 202
# target: queen
# 12  context word: rule
# 0.0
# Epoch: 203
# target: beautiful
# 20  context word: strong
# 0.0
# Epoch: 204
# target: son
# 4  context word: beautiful
# 0.0
# Epoch: 205
# target: daughter
# 2  context word: man
# 0.0
# Epoch: 206
# target: king
# 24  context word: strong
# 0.0
# Epoch: 207
# target: family
# 23  context word: son
# 0.0
# Epoch: 208
# target: beautiful
# 20  context word: beautiful
# 0.0
# Epoch: 209
# target: children
# 26  context word: queen
# 0.0
# Epoch: 210
# target: children
# 26  context word: king
# 0.0
# Epoch: 211
# target: man
# 18  context word: man
# 0.0
# Epoch: 212
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 213
# target: princess
# 3  context word: son
# 0.0
# Epoch: 214
# target: queen
# 11  context word: beautiful
# 0.0
# Epoch: 215
# target: woman
# 8  context word: queen
# 0.0
# Epoch: 216
# target: queen
# 11  context word: strong
# 0.0
# Epoch: 217
# target: prince
# 16  context word: strong
# 0.0
# Epoch: 218
# target: prince
# 1  context word: future
# 0.0
# Epoch: 219
# target: queen
# 25  context word: queen
# 0.0
# Epoch: 220
# target: princess
# 10  context word: beautiful
# 0.0
# Epoch: 221
# target: king
# 13  context word: beautiful
# 0.0
# Epoch: 222
# target: queen
# 9  context word: man
# 0.0
# Epoch: 223
# target: rule
# 14  context word: queen
# 0.0
# Epoch: 224
# target: man
# 6  context word: son
# 0.0
# Epoch: 225
# target: queen
# 9  context word: rule
# 0.0
# Epoch: 226
# target: prince
# 16  context word: son
# 0.0
# Epoch: 227
# target: family
# 23  context word: beautiful
# 0.0
# Epoch: 228
# target: king
# 0  context word: strong
# 0.0
# Epoch: 229
# target: daughter
# 2  context word: children
# 0.0
# Epoch: 230
# target: royal
# 22  context word: man
# 0.0
# Epoch: 231
# target: prince
# 5  context word: beautiful
# 0.0
# Epoch: 232
# target: princess
# 3  context word: strong
# 0.0
# Epoch: 233
# target: prince
# 1  context word: son
# 0.0
# Epoch: 234
# target: children
# 26  context word: princess
# 0.0
# Epoch: 235
# target: princess
# 10  context word: man
# 0.0
# Epoch: 236
# target: son
# 4  context word: beautiful
# 0.0
# Epoch: 237
# target: daughter
# 2  context word: children
# 0.0
# Epoch: 238
# target: queen
# 9  context word: princess
# 0.0
# Epoch: 239
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 240
# target: woman
# 8  context word: queen
# 0.0
# Epoch: 241
# target: prince
# 5  context word: daughter
# 0.0
# Epoch: 242
# target: queen
# 25  context word: children
# 0.0
# Epoch: 243
# target: princess
# 3  context word: princess
# 0.0
# Epoch: 244
# target: woman
# 8  context word: queen
# 0.0
# Epoch: 245
# target: queen
# 12  context word: future
# 0.0
# Epoch: 246
# target: prince
# 16  context word: future
# 0.0
# Epoch: 247
# target: daughter
# 2  context word: royal
# 0.0
# Epoch: 248
# target: royal
# 22  context word: strong
# 0.0
# Epoch: 249
# target: king
# 0  context word: strong
# 0.0
# Epoch: 250
# target: queen
# 25  context word: rule
# 0.0
# Epoch: 251
# target: strong
# 17  context word: son
# 0.0
# Epoch: 252
# target: princess
# 3  context word: son
# 0.0
# Epoch: 253
# target: man
# 6  context word: future
# 0.0
# Epoch: 254
# target: boy
# 28  context word: daughter
# 0.0
# Epoch: 255
# target: children
# 26  context word: queen
# 0.0
# Epoch: 256
# target: royal
# 22  context word: man
# 0.0
# Epoch: 257
# target: king
# 13  context word: rule
# 0.0
# Epoch: 258
# target: princess
# 19  context word: son
# 0.0
# Epoch: 259
# target: children
# 26  context word: children
# 0.0
# Epoch: 260
# target: strong
# 17  context word: boy
# 0.0
# Epoch: 261
# target: beautiful
# 20  context word: beautiful
# 0.0
# Epoch: 262
# target: daughter
# 2  context word: realm
# 0.0
# Epoch: 263
# target: man
# 6  context word: boy
# 0.0
# Epoch: 264
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 265
# target: man
# 6  context word: future
# 0.0
# Epoch: 266
# target: queen
# 9  context word: man
# 0.0
# Epoch: 267
# target: beautiful
# 20  context word: beautiful
# 0.0
# Epoch: 268
# target: children
# 26  context word: beautiful
# 0.0
# Epoch: 269
# target: queen
# 11  context word: rule
# 0.0
# Epoch: 270
# target: children
# 26  context word: future
# 0.0
# Epoch: 271
# target: queen
# 9  context word: man
# 0.0
# Epoch: 272
# target: king
# 0  context word: beautiful
# 0.0
# Epoch: 273
# target: queen
# 11  context word: beautiful
# 0.0
# Epoch: 274
# target: woman
# 8  context word: realm
# 0.0
# Epoch: 275
# target: rule
# 14  context word: daughter
# 0.0
# Epoch: 276
# target: royal
# 22  context word: man
# 0.0
# Epoch: 277
# target: boy
# 28  context word: daughter
# 0.0
# Epoch: 278
# target: royal
# 22  context word: beautiful
# 0.0
# Epoch: 279
# target: royal
# 22  context word: realm
# 0.0
# Epoch: 280
# target: king
# 0  context word: family
# 0.0
# Epoch: 281
# target: queen
# 9  context word: man
# 0.0
# Epoch: 282
# target: queen
# 12  context word: rule
# 0.0
# Epoch: 283
# target: man
# 6  context word: boy
# 0.0
# Epoch: 284
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 285
# target: woman
# 21  context word: woman
# 0.0
# Epoch: 286
# target: queen
# 12  context word: future
# 0.0
# Epoch: 287
# target: man
# 6  context word: rule
# 0.0
# Epoch: 288
# target: queen
# 25  context word: son
# 0.0
# Epoch: 289
# target: queen
# 12  context word: king
# 0.0
# Epoch: 290
# target: king
# 0  context word: beautiful
# 0.0
# Epoch: 291
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 292
# target: rule
# 14  context word: future
# 0.0
# Epoch: 293
# target: king
# 7  context word: strong
# 0.0
# Epoch: 294
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 295
# target: royal
# 22  context word: man
# 0.0
# Epoch: 296
# target: children
# 26  context word: daughter
# 0.0
# Epoch: 297
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 298
# target: queen
# 25  context word: future
# 0.0
# Epoch: 299
# target: king
# 0  context word: beautiful
# 0.0
# Epoch: 300
# target: royal
# 22  context word: man
# 0.0
# Epoch: 301
# target: rule
# 14  context word: future
# 0.0
# Epoch: 302
# target: queen
# 12  context word: man
# 0.0
# Epoch: 303
# target: children
# 26  context word: son
# 0.0
# Epoch: 304
# target: boy
# 28  context word: daughter
# 0.0
# Epoch: 305
# target: beautiful
# 20  context word: beautiful
# 0.0
# Epoch: 306
# target: rule
# 14  context word: rule
# 0.0
# Epoch: 307
# target: family
# 23  context word: strong
# 0.0
# Epoch: 308
# target: queen
# 25  context word: family
# 0.0
# Epoch: 309
# target: boy
# 28  context word: children
# 0.0
# Epoch: 310
# target: prince
# 16  context word: rule
# 0.0
# Epoch: 311
# target: prince
# 27  context word: family
# 0.0
# Epoch: 312
# target: king
# 7  context word: beautiful
# 0.0
# Epoch: 313
# target: children
# 26  context word: woman
# 0.0
# Epoch: 314
# target: beautiful
# 20  context word: beautiful
# 0.0
# Epoch: 315
# target: prince
# 5  context word: man
# 0.0
# Epoch: 316
# target: children
# 26  context word: beautiful
# 0.0
# Epoch: 317
# target: prince
# 27  context word: realm
# 0.0
# Epoch: 318
# target: queen
# 25  context word: queen
# 0.0
# Epoch: 319
# target: princess
# 3  context word: son
# 0.0
# Epoch: 320
# target: king
# 24  context word: beautiful
# 0.0
# Epoch: 321
# target: beautiful
# 20  context word: beautiful
# 0.0
# Epoch: 322
# target: man
# 18  context word: man
# 0.0
# Epoch: 323
# target: queen
# 9  context word: beautiful
# 0.0
# Epoch: 324
# target: prince
# 27  context word: rule
# 0.0
# Epoch: 325
# target: rule
# 14  context word: queen
# 0.0
# Epoch: 326
# target: family
# 23  context word: son
# 0.0
# Epoch: 327
# target: princess
# 3  context word: son
# 0.0
# Epoch: 328
# target: queen
# 12  context word: beautiful
# 0.0
# Epoch: 329
# target: queen
# 12  context word: strong
# 0.0
# Epoch: 330
# target: son
# 4  context word: beautiful
# 0.0
# Epoch: 331
# target: queen
# 9  context word: man
# 0.0
# Epoch: 332
# target: prince
# 5  context word: daughter
# 0.0
# Epoch: 333
# target: king
# 0  context word: family
# 0.0
# Epoch: 334
# target: children
# 26  context word: son
# 0.0
# Epoch: 335
# target: queen
# 9  context word: man
# 0.0
# Epoch: 336
# target: princess
# 19  context word: realm
# 0.0
# Epoch: 337
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 338
# target: man
# 6  context word: princess
# 0.0
# Epoch: 339
# target: woman
# 21  context word: rule
# 0.0
# Epoch: 340
# target: queen
# 9  context word: man
# 0.0
# Epoch: 341
# target: prince
# 1  context word: woman
# 0.0
# Epoch: 342
# target: woman
# 8  context word: strong
# 0.0
# Epoch: 343
# target: beautiful
# 20  context word: beautiful
# 0.0
# Epoch: 344
# target: king
# 24  context word: rule
# 0.0
# Epoch: 345
# target: man
# 6  context word: realm
# 0.0
# Epoch: 346
# target: daughter
# 2  context word: beautiful
# 0.0
# Epoch: 347
# target: prince
# 5  context word: beautiful
# 0.0
# Epoch: 348
# target: prince
# 1  context word: realm
# 0.0
# Epoch: 349
# target: daughter
# 2  context word: beautiful
# 0.0
# Epoch: 350
# target: man
# 6  context word: daughter
# 0.0
# Epoch: 351
# target: prince
# 16  context word: realm
# 0.0
# Epoch: 352
# target: prince
# 16  context word: rule
# 0.0
# Epoch: 353
# target: king
# 24  context word: beautiful
# 0.0
# Epoch: 354
# target: royal
# 22  context word: strong
# 0.0
# Epoch: 355
# target: woman
# 21  context word: man
# 0.0
# Epoch: 356
# target: queen
# 9  context word: man
# 0.0
# Epoch: 357
# target: prince
# 27  context word: realm
# 0.0
# Epoch: 358
# target: children
# 26  context word: man
# 0.0
# Epoch: 359
# target: king
# 13  context word: rule
# 0.0
# Epoch: 360
# target: beautiful
# 20  context word: beautiful
# 0.0
# Epoch: 361
# target: woman
# 21  context word: beautiful
# 0.0
# Epoch: 362
# target: queen
# 12  context word: children
# 0.0
# Epoch: 363
# target: queen
# 11  context word: beautiful
# 0.0
# Epoch: 364
# target: man
# 18  context word: man
# 0.0
# Epoch: 365
# target: woman
# 21  context word: beautiful
# 0.0
# Epoch: 366
# target: strong
# 17  context word: daughter
# 0.0
# Epoch: 367
# target: princess
# 3  context word: princess
# 0.0
# Epoch: 368
# target: king
# 7  context word: beautiful
# 0.0
# Epoch: 369
# target: daughter
# 2  context word: son
# 0.0
# Epoch: 370
# target: prince
# 27  context word: prince
# 0.0
# Epoch: 371
# target: queen
# 25  context word: children
# 0.0
# Epoch: 372
# target: son
# 4  context word: beautiful
# 0.0
# Epoch: 373
# target: woman
# 8  context word: woman
# 0.0
# Epoch: 374
# target: woman
# 8  context word: man
# 0.0
# Epoch: 375
# target: boy
# 28  context word: strong
# 0.0
# Epoch: 376
# target: woman
# 21  context word: man
# 0.0
# Epoch: 377
# target: king
# 7  context word: strong
# 0.0
# Epoch: 378
# target: prince
# 1  context word: realm
# 0.0
# Epoch: 379
# target: daughter
# 2  context word: princess
# 0.0
# Epoch: 380
# target: prince
# 27  context word: man
# 0.0
# Epoch: 381
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 382
# target: prince
# 16  context word: rule
# 0.0
# Epoch: 383
# target: prince
# 27  context word: queen
# 0.0
# Epoch: 384
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 385
# target: queen
# 9  context word: strong
# 0.0
# Epoch: 386
# target: king
# 0  context word: beautiful
# 0.0
# Epoch: 387
# target: prince
# 1  context word: queen
# 0.0
# Epoch: 388
# target: daughter
# 2  context word: daughter
# 0.0
# Epoch: 389
# target: king
# 13  context word: rule
# 0.0
# Epoch: 390
# target: daughter
# 2  context word: son
# 0.0
# Epoch: 391
# target: queen
# 12  context word: rule
# 0.0
# Epoch: 392
# target: man
# 6  context word: beautiful
# 0.0
# Epoch: 393
# target: queen
# 11  context word: beautiful
# 0.0
# Epoch: 394
# target: family
# 23  context word: strong
# 0.0
# Epoch: 395
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 396
# target: royal
# 22  context word: man
# 0.0
# Epoch: 397
# target: children
# 26  context word: beautiful
# 0.0
# Epoch: 398
# target: woman
# 21  context word: queen
# 0.0
# Epoch: 399
# target: queen
# 11  context word: son
# 0.0
# Epoch: 400
# target: prince
# 5  context word: daughter
# 0.0
# Epoch: 401
# target: woman
# 21  context word: beautiful
# 0.0
# Epoch: 402
# target: woman
# 8  context word: future
# 0.0
# Epoch: 403
# target: prince
# 1  context word: future
# 0.0
# Epoch: 404
# target: queen
# 12  context word: king
# 0.0
# Epoch: 405
# target: queen
# 11  context word: beautiful
# 0.0
# Epoch: 406
# target: prince
# 27  context word: queen
# 0.0
# Epoch: 407
# target: princess
# 10  context word: rule
# 0.0
# Epoch: 408
# target: rule
# 14  context word: queen
# 0.0
# Epoch: 409
# target: king
# 24  context word: strong
# 0.0
# Epoch: 410
# target: man
# 18  context word: man
# 0.0
# Epoch: 411
# target: prince
# 16  context word: strong
# 0.0
# Epoch: 412
# target: strong
# 17  context word: family
# 0.0
# Epoch: 413
# target: man
# 18  context word: man
# 0.0
# Epoch: 414
# target: woman
# 21  context word: rule
# 0.0
# Epoch: 415
# target: princess
# 10  context word: son
# 0.0
# Epoch: 416
# target: king
# 7  context word: strong
# 0.0
# Epoch: 417
# target: king
# 0  context word: strong
# 0.0
# Epoch: 418
# target: beautiful
# 20  context word: beautiful
# 0.0
# Epoch: 419
# target: man
# 6  context word: realm
# 0.0
# Epoch: 420
# target: princess
# 3  context word: princess
# 0.0
# Epoch: 421
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 422
# target: strong
# 17  context word: woman
# 0.0
# Epoch: 423
# target: son
# 4  context word: beautiful
# 0.0
# Epoch: 424
# target: beautiful
# 20  context word: son
# 0.0
# Epoch: 425
# target: beautiful
# 20  context word: son
# 0.0
# Epoch: 426
# target: queen
# 25  context word: queen
# 0.0
# Epoch: 427
# target: family
# 23  context word: son
# 0.0
# Epoch: 428
# target: prince
# 5  context word: daughter
# 0.0
# Epoch: 429
# target: king
# 24  context word: royal
# 0.0
# Epoch: 430
# target: king
# 7  context word: woman
# 0.0
# Epoch: 431
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 432
# target: prince
# 27  context word: realm
# 0.0
# Epoch: 433
# target: prince
# 16  context word: rule
# 0.0
# Epoch: 434
# target: daughter
# 2  context word: beautiful
# 0.0
# Epoch: 435
# target: queen
# 9  context word: man
# 0.0
# Epoch: 436
# target: children
# 26  context word: princess
# 0.0
# Epoch: 437
# target: rule
# 14  context word: beautiful
# 0.0
# Epoch: 438
# target: prince
# 5  context word: daughter
# 0.0
# Epoch: 439
# target: boy
# 28  context word: royal
# 0.0
# Epoch: 440
# target: man
# 6  context word: man
# 0.0
# Epoch: 441
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 442
# target: queen
# 25  context word: future
# 0.0
# Epoch: 443
# target: king
# 7  context word: daughter
# 0.0
# Epoch: 444
# target: beautiful
# 20  context word: beautiful
# 0.0
# Epoch: 445
# target: family
# 23  context word: strong
# 0.0
# Epoch: 446
# target: princess
# 3  context word: beautiful
# 0.0
# Epoch: 447
# target: son
# 4  context word: beautiful
# 0.0
# Epoch: 448
# target: king
# 0  context word: beautiful
# 0.0
# Epoch: 449
# target: son
# 4  context word: beautiful
# 0.0
# Epoch: 450
# target: man
# 6  context word: son
# 0.0
# Epoch: 451
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 452
# target: woman
# 8  context word: future
# 0.0
# Epoch: 453
# target: princess
# 19  context word: son
# 0.0
# Epoch: 454
# target: prince
# 16  context word: strong
# 0.0
# Epoch: 455
# target: king
# 24  context word: royal
# 0.0
# Epoch: 456
# target: prince
# 1  context word: queen
# 0.0
# Epoch: 457
# target: strong
# 17  context word: beautiful
# 0.0
# Epoch: 458
# target: king
# 0  context word: son
# 0.0
# Epoch: 459
# target: king
# 7  context word: strong
# 0.0
# Epoch: 460
# target: queen
# 12  context word: man
# 0.0
# Epoch: 461
# target: queen
# 25  context word: rule
# 0.0
# Epoch: 462
# target: rule
# 14  context word: future
# 0.0
# Epoch: 463
# target: woman
# 8  context word: queen
# 0.0
# Epoch: 464
# target: princess
# 3  context word: beautiful
# 0.0
# Epoch: 465
# target: woman
# 21  context word: realm
# 0.0
# Epoch: 466
# target: royal
# 22  context word: man
# 0.0
# Epoch: 467
# target: queen
# 25  context word: children
# 0.0
# Epoch: 468
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 469
# target: princess
# 10  context word: king
# 0.0
# Epoch: 470
# target: princess
# 10  context word: strong
# 0.0
# Epoch: 471
# target: prince
# 16  context word: woman
# 0.0
# Epoch: 472
# target: boy
# 28  context word: strong
# 0.0
# Epoch: 473
# target: rule
# 14  context word: man
# 0.0
# Epoch: 474
# target: prince
# 1  context word: future
# 0.0
# Epoch: 475
# target: daughter
# 2  context word: boy
# 0.0
# Epoch: 476
# target: king
# 24  context word: beautiful
# 0.0
# Epoch: 477
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 478
# target: king
# 0  context word: rule
# 0.0
# Epoch: 479
# target: queen
# 11  context word: beautiful
# 0.0
# Epoch: 480
# target: beautiful
# 20  context word: strong
# 0.0
# Epoch: 481
# target: princess
# 10  context word: princess
# 0.0
# Epoch: 482
# target: prince
# 27  context word: prince
# 0.0
# Epoch: 483
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 484
# target: rule
# 14  context word: children
# 0.0
# Epoch: 485
# target: princess
# 3  context word: princess
# 0.0
# Epoch: 486
# target: princess
# 3  context word: son
# 0.0
# Epoch: 487
# target: prince
# 27  context word: woman
# 0.0
# Epoch: 488
# target: queen
# 12  context word: king
# 0.0
# Epoch: 489
# target: children
# 26  context word: woman
# 0.0
# Epoch: 490
# target: man
# 6  context word: rule
# 0.0
# Epoch: 491
# target: rule
# 14  context word: future
# 0.0
# Epoch: 492
# target: beautiful
# 20  context word: beautiful
# 0.0
# Epoch: 493
# target: queen
# 9  context word: strong
# 0.0
# Epoch: 494
# target: king
# 7  context word: son
# 0.0
# Epoch: 495
# target: man
# 6  context word: future
# 0.0
# Epoch: 496
# target: woman
# 8  context word: rule
# 0.0
# Epoch: 497
# target: beautiful
# 20  context word: beautiful
# 0.0
# Epoch: 498
# target: prince
# 5  context word: man
# 0.0
# Epoch: 499
# target: princess
# 3  context word: princess
# 0.0
# Epoch: 500
# target: prince
# 27  context word: princess
# 0.0
# Epoch: 501
# target: daughter
# 2  context word: princess
# 0.0
# Epoch: 502
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 503
# target: strong
# 17  context word: princess
# 0.0
# Epoch: 504
# target: princess
# 10  context word: woman
# 0.0
# Epoch: 505
# target: strong
# 17  context word: royal
# 0.0
# Epoch: 506
# target: prince
# 5  context word: daughter
# 0.0
# Epoch: 507
# target: rule
# 14  context word: son
# 0.0
# Epoch: 508
# target: queen
# 11  context word: beautiful
# 0.0
# Epoch: 509
# target: queen
# 11  context word: children
# 0.0
# Epoch: 510
# target: queen
# 11  context word: rule
# 0.0
# Epoch: 511
# target: king
# 7  context word: strong
# 0.0
# Epoch: 512
# target: man
# 6  context word: strong
# 0.0
# Epoch: 513
# target: queen
# 9  context word: man
# 0.0
# Epoch: 514
# target: king
# 7  context word: strong
# 0.0
# Epoch: 515
# target: son
# 4  context word: beautiful
# 0.0
# Epoch: 516
# target: boy
# 28  context word: king
# 0.0
# Epoch: 517
# target: prince
# 27  context word: strong
# 0.0
# Epoch: 518
# target: rule
# 14  context word: queen
# 0.0
# Epoch: 519
# target: king
# 24  context word: strong
# 0.0
# Epoch: 520
# target: beautiful
# 20  context word: beautiful
# 0.0
# Epoch: 521
# target: son
# 4  context word: beautiful
# 0.0
# Epoch: 522
# target: boy
# 28  context word: boy
# 0.0
# Epoch: 523
# target: son
# 4  context word: beautiful
# 0.0
# Epoch: 524
# target: realm
# 15  context word: beautiful
# 0.0
# Epoch: 525
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 526
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 527
# target: family
# 23  context word: beautiful
# 0.0
# Epoch: 528
# target: woman
# 21  context word: woman
# 0.0
# Epoch: 529
# target: prince
# 16  context word: son
# 0.0
# Epoch: 530
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 531
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 532
# target: woman
# 21  context word: realm
# 0.0
# Epoch: 533
# target: queen
# 9  context word: beautiful
# 0.0
# Epoch: 534
# target: beautiful
# 20  context word: strong
# 0.0
# Epoch: 535
# target: queen
# 25  context word: rule
# 0.0
# Epoch: 536
# target: queen
# 9  context word: man
# 0.0
# Epoch: 537
# target: man
# 6  context word: strong
# 0.0
# Epoch: 538
# target: princess
# 3  context word: princess
# 0.0
# Epoch: 539
# target: man
# 6  context word: boy
# 0.0
# Epoch: 540
# target: prince
# 16  context word: beautiful
# 0.0
# Epoch: 541
# target: queen
# 12  context word: princess
# 0.0
# Epoch: 542
# target: woman
# 21  context word: woman
# 0.0
# Epoch: 543
# target: family
# 23  context word: strong
# 0.0
# Epoch: 544
# target: man
# 18  context word: man
# 0.0
# Epoch: 545
# target: prince
# 16  context word: strong
# 0.0
# Epoch: 546
# target: prince
# 27  context word: beautiful
# 0.0
# Epoch: 547
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 548
# target: king
# 7  context word: strong
# 0.0
# Epoch: 549
# target: princess
# 19  context word: realm
# 0.0
# Epoch: 550
# target: prince
# 16  context word: rule
# 0.0
# Epoch: 551
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 552
# target: prince
# 1  context word: future
# 0.0
# Epoch: 553
# target: strong
# 17  context word: man
# 0.0
# Epoch: 554
# target: rule
# 14  context word: children
# 0.0
# Epoch: 555
# target: queen
# 9  context word: beautiful
# 0.0
# Epoch: 556
# target: prince
# 1  context word: queen
# 0.0
# Epoch: 557
# target: king
# 13  context word: beautiful
# 0.0
# Epoch: 558
# target: queen
# 25  context word: future
# 0.0
# Epoch: 559
# target: son
# 4  context word: son
# 0.0
# Epoch: 560
# target: royal
# 22  context word: rule
# 0.0
# Epoch: 561
# target: prince
# 16  context word: rule
# 0.0
# Epoch: 562
# target: boy
# 28  context word: man
# 0.0
# Epoch: 563
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 564
# target: prince
# 1  context word: queen
# 0.0
# Epoch: 565
# target: beautiful
# 20  context word: beautiful
# 0.0
# Epoch: 566
# target: man
# 6  context word: realm
# 0.0
# Epoch: 567
# target: prince
# 5  context word: daughter
# 0.0
# Epoch: 568
# target: prince
# 1  context word: queen
# 0.0
# Epoch: 569
# target: prince
# 1  context word: strong
# 0.0
# Epoch: 570
# target: rule
# 14  context word: queen
# 0.0
# Epoch: 571
# target: rule
# 14  context word: future
# 0.0
# Epoch: 572
# target: king
# 13  context word: king
# 0.0
# Epoch: 573
# target: strong
# 17  context word: daughter
# 0.0
# Epoch: 574
# target: king
# 7  context word: strong
# 0.0
# Epoch: 575
# target: king
# 24  context word: strong
# 0.0
# Epoch: 576
# target: royal
# 22  context word: strong
# 0.0
# Epoch: 577
# target: royal
# 22  context word: strong
# 0.0
# Epoch: 578
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 579
# target: princess
# 10  context word: queen
# 0.0
# Epoch: 580
# target: queen
# 9  context word: royal
# 0.0
# Epoch: 581
# target: children
# 26  context word: man
# 0.0
# Epoch: 582
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 583
# target: daughter
# 2  context word: son
# 0.0
# Epoch: 584
# target: woman
# 8  context word: realm
# 0.0
# Epoch: 585
# target: king
# 24  context word: royal
# 0.0
# Epoch: 586
# target: man
# 18  context word: man
# 0.0
# Epoch: 587
# target: daughter
# 2  context word: princess
# 0.0
# Epoch: 588
# target: queen
# 25  context word: woman
# 0.0
# Epoch: 589
# target: prince
# 5  context word: daughter
# 0.0
# Epoch: 590
# target: woman
# 8  context word: queen
# 0.0
# Epoch: 591
# target: princess
# 3  context word: son
# 0.0
# Epoch: 592
# target: king
# 13  context word: woman
# 0.0
# Epoch: 593
# target: queen
# 9  context word: son
# 0.0
# Epoch: 594
# target: children
# 26  context word: son
# 0.0
# Epoch: 595
# target: children
# 26  context word: son
# 0.0
# Epoch: 596
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 597
# target: woman
# 8  context word: future
# 0.0
# Epoch: 598
# target: king
# 0  context word: future
# 0.0
# Epoch: 599
# target: rule
# 14  context word: realm
# 0.0
# Epoch: 600
# target: princess
# 3  context word: princess
# 0.0
# Epoch: 601
# target: prince
# 5  context word: man
# 0.0
# Epoch: 602
# target: boy
# 28  context word: boy
# 0.0
# Epoch: 603
# target: queen
# 11  context word: beautiful
# 0.0
# Epoch: 604
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 605
# target: prince
# 27  context word: rule
# 0.0
# Epoch: 606
# target: daughter
# 2  context word: daughter
# 0.0
# Epoch: 607
# target: woman
# 8  context word: queen
# 0.0
# Epoch: 608
# target: royal
# 22  context word: man
# 0.0
# Epoch: 609
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 610
# target: prince
# 27  context word: princess
# 0.0
# Epoch: 611
# target: prince
# 1  context word: beautiful
# 0.0
# Epoch: 612
# target: queen
# 11  context word: beautiful
# 0.0
# Epoch: 613
# target: beautiful
# 20  context word: beautiful
# 0.0
# Epoch: 614
# target: son
# 4  context word: daughter
# 0.0
# Epoch: 615
# target: prince
# 1  context word: strong
# 0.0
# Epoch: 616
# target: princess
# 10  context word: queen
# 0.0
# Epoch: 617
# target: prince
# 1  context word: children
# 0.0
# Epoch: 618
# target: children
# 26  context word: king
# 0.0
# Epoch: 619
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 620
# target: strong
# 17  context word: son
# 0.0
# Epoch: 621
# target: rule
# 14  context word: children
# 0.0
# Epoch: 622
# target: woman
# 21  context word: rule
# 0.0
# Epoch: 623
# target: prince
# 27  context word: rule
# 0.0
# Epoch: 624
# target: prince
# 16  context word: rule
# 0.0
# Epoch: 625
# target: prince
# 27  context word: children
# 0.0
# Epoch: 626
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 627
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 628
# target: king
# 0  context word: beautiful
# 0.0
# Epoch: 629
# target: king
# 7  context word: strong
# 0.0
# Epoch: 630
# target: beautiful
# 20  context word: queen
# 0.0
# Epoch: 631
# target: queen
# 11  context word: strong
# 0.0
# Epoch: 632
# target: princess
# 3  context word: princess
# 0.0
# Epoch: 633
# target: family
# 23  context word: man
# 0.0
# Epoch: 634
# target: prince
# 1  context word: beautiful
# 0.0
# Epoch: 635
# target: man
# 6  context word: son
# 0.0
# Epoch: 636
# target: queen
# 11  context word: beautiful
# 0.0
# Epoch: 637
# target: princess
# 3  context word: man
# 0.0
# Epoch: 638
# target: king
# 0  context word: woman
# 0.0
# Epoch: 639
# target: rule
# 14  context word: queen
# 0.0
# Epoch: 640
# target: queen
# 25  context word: children
# 0.0
# Epoch: 641
# target: prince
# 1  context word: future
# 0.0
# Epoch: 642
# target: woman
# 21  context word: strong
# 0.0
# Epoch: 643
# target: man
# 6  context word: son
# 0.0
# Epoch: 644
# target: queen
# 11  context word: beautiful
# 0.0
# Epoch: 645
# target: daughter
# 2  context word: rule
# 0.0
# Epoch: 646
# target: king
# 13  context word: queen
# 0.0
# Epoch: 647
# target: king
# 13  context word: king
# 0.0
# Epoch: 648
# target: queen
# 12  context word: future
# 0.0
# Epoch: 649
# target: children
# 26  context word: daughter
# 0.0
# Epoch: 650
# target: queen
# 25  context word: woman
# 0.0
# Epoch: 651
# target: royal
# 22  context word: woman
# 0.0
# Epoch: 652
# target: man
# 6  context word: daughter
# 0.0
# Epoch: 653
# target: children
# 26  context word: queen
# 0.0
# Epoch: 654
# target: children
# 26  context word: king
# 0.0
# Epoch: 655
# target: king
# 7  context word: strong
# 0.0
# Epoch: 656
# target: king
# 0  context word: woman
# 0.0
# Epoch: 657
# target: strong
# 17  context word: man
# 0.0
# Epoch: 658
# target: children
# 26  context word: future
# 0.0
# Epoch: 659
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 660
# target: beautiful
# 20  context word: man
# 0.0
# Epoch: 661
# target: strong
# 17  context word: strong
# 0.0
# Epoch: 662
# target: princess
# 10  context word: woman
# 0.0
# Epoch: 663
# target: woman
# 21  context word: woman
# 0.0
# Epoch: 664
# target: princess
# 10  context word: queen
# 0.0
# Epoch: 665
# target: queen
# 11  context word: woman
# 0.0
# Epoch: 666
# target: man
# 18  context word: princess
# 0.0
# Epoch: 667
# target: man
# 18  context word: son
# 0.0
# Epoch: 668
# target: son
# 4  context word: rule
# 0.0
# Epoch: 669
# target: woman
# 8  context word: children
# 0.0
# Epoch: 670
# target: king
# 7  context word: strong
# 0.0
# Epoch: 671
# target: woman
# 8  context word: rule
# 0.0
# Epoch: 672
# target: king
# 13  context word: king
# 0.0
# Epoch: 673
# target: man
# 6  context word: man
# 0.0
# Epoch: 674
# target: princess
# 10  context word: king
# 0.0
# Epoch: 675
# target: queen
# 12  context word: queen
# 0.0
# Epoch: 676
# target: woman
# 8  context word: queen
# 0.0
# Epoch: 677
# target: princess
# 19  context word: beautiful
# 0.0
# Epoch: 678
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 679
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 680
# target: children
# 26  context word: beautiful
# 0.0
# Epoch: 681
# target: princess
# 10  context word: king
# 0.0
# Epoch: 682
# target: queen
# 9  context word: queen
# 0.0
# Epoch: 683
# target: queen
# 25  context word: family
# 0.0
# Epoch: 684
# target: son
# 4  context word: son
# 0.0
# Epoch: 685
# target: man
# 6  context word: daughter
# 0.0
# Epoch: 686
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 687
# target: prince
# 1  context word: son
# 0.0
# Epoch: 688
# target: man
# 18  context word: princess
# 0.0
# Epoch: 689
# target: queen
# 25  context word: queen
# 0.0
# Epoch: 690
# target: queen
# 11  context word: beautiful
# 0.0
# Epoch: 691
# target: king
# 13  context word: beautiful
# 0.0
# Epoch: 692
# target: prince
# 5  context word: man
# 0.0
# Epoch: 693
# target: prince
# 16  context word: rule
# 0.0
# Epoch: 694
# target: beautiful
# 20  context word: beautiful
# 0.0
# Epoch: 695
# target: queen
# 11  context word: strong
# 0.0
# Epoch: 696
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 697
# target: queen
# 9  context word: man
# 0.0
# Epoch: 698
# target: king
# 24  context word: woman
# 0.0
# Epoch: 699
# target: daughter
# 2  context word: princess
# 0.0
# Epoch: 700
# target: family
# 23  context word: woman
# 0.0
# Epoch: 701
# target: queen
# 25  context word: woman
# 0.0
# Epoch: 702
# target: prince
# 5  context word: rule
# 0.0
# Epoch: 703
# target: rule
# 14  context word: future
# 0.0
# Epoch: 704
# target: king
# 0  context word: beautiful
# 0.0
# Epoch: 705
# target: king
# 0  context word: beautiful
# 0.0
# Epoch: 706
# target: man
# 18  context word: man
# 0.0
# Epoch: 707
# target: princess
# 10  context word: man
# 0.0
# Epoch: 708
# target: man
# 6  context word: strong
# 0.0
# Epoch: 709
# target: princess
# 10  context word: queen
# 0.0
# Epoch: 710
# target: son
# 4  context word: strong
# 0.0
# Epoch: 711
# target: prince
# 5  context word: daughter
# 0.0
# Epoch: 712
# target: strong
# 17  context word: son
# 0.0
# Epoch: 713
# target: rule
# 14  context word: princess
# 0.0
# Epoch: 714
# target: queen
# 25  context word: queen
# 0.0
# Epoch: 715
# target: princess
# 10  context word: queen
# 0.0
# Epoch: 716
# target: family
# 23  context word: family
# 0.0
# Epoch: 717
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 718
# target: queen
# 9  context word: man
# 0.0
# Epoch: 719
# target: man
# 18  context word: beautiful
# 0.0
# Epoch: 720
# target: man
# 18  context word: man
# 0.0
# Epoch: 721
# target: queen
# 9  context word: man
# 0.0
# Epoch: 722
# target: prince
# 27  context word: strong
# 0.0
# Epoch: 723
# target: king
# 0  context word: strong
# 0.0
# Epoch: 724
# target: king
# 24  context word: royal
# 0.0
# Epoch: 725
# target: king
# 0  context word: daughter
# 0.0
# Epoch: 726
# target: prince
# 27  context word: woman
# 0.0
# Epoch: 727
# target: children
# 26  context word: queen
# 0.0
# Epoch: 728
# target: princess
# 10  context word: queen
# 0.0
# Epoch: 729
# target: family
# 23  context word: strong
# 0.0
# Epoch: 730
# target: strong
# 17  context word: boy
# 0.0
# Epoch: 731
# target: man
# 18  context word: daughter
# 0.0
# Epoch: 732
# target: prince
# 5  context word: rule
# 0.0
# Epoch: 733
# target: princess
# 10  context word: queen
# 0.0
# Epoch: 734
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 735
# target: prince
# 5  context word: woman
# 0.0
# Epoch: 736
# target: woman
# 21  context word: rule
# 0.0
# Epoch: 737
# target: princess
# 3  context word: strong
# 0.0
# Epoch: 738
# target: queen
# 25  context word: woman
# 0.0
# Epoch: 739
# target: king
# 13  context word: queen
# 0.0
# Epoch: 740
# target: queen
# 25  context word: man
# 0.0
# Epoch: 741
# target: queen
# 25  context word: future
# 0.0
# Epoch: 742
# target: princess
# 10  context word: king
# 0.0
# Epoch: 743
# target: woman
# 21  context word: strong
# 0.0
# Epoch: 744
# target: strong
# 17  context word: man
# 0.0
# Epoch: 745
# target: royal
# 22  context word: man
# 0.0
# Epoch: 746
# target: man
# 18  context word: princess
# 0.0
# Epoch: 747
# target: children
# 26  context word: beautiful
# 0.0
# Epoch: 748
# target: strong
# 17  context word: daughter
# 0.0
# Epoch: 749
# target: man
# 6  context word: man
# 0.0
# Epoch: 750
# target: princess
# 3  context word: princess
# 0.0
# Epoch: 751
# target: woman
# 8  context word: queen
# 0.0
# Epoch: 752
# target: king
# 7  context word: man
# 0.0
# Epoch: 753
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 754
# target: rule
# 14  context word: son
# 0.0
# Epoch: 755
# target: king
# 13  context word: king
# 0.0
# Epoch: 756
# target: king
# 24  context word: princess
# 0.0
# Epoch: 757
# target: prince
# 16  context word: rule
# 0.0
# Epoch: 758
# target: man
# 6  context word: royal
# 0.0
# Epoch: 759
# target: queen
# 25  context word: rule
# 0.0
# Epoch: 760
# target: rule
# 14  context word: strong
# 0.0
# Epoch: 761
# target: princess
# 10  context word: queen
# 0.0
# Epoch: 762
# target: queen
# 12  context word: king
# 0.0
# Epoch: 763
# target: king
# 7  context word: strong
# 0.0
# Epoch: 764
# target: princess
# 3  context word: woman
# 0.0
# Epoch: 765
# target: king
# 7  context word: strong
# 0.0
# Epoch: 766
# target: prince
# 16  context word: woman
# 0.0
# Epoch: 767
# target: prince
# 16  context word: rule
# 0.0
# Epoch: 768
# target: woman
# 21  context word: woman
# 0.0
# Epoch: 769
# target: beautiful
# 20  context word: man
# 0.0
# Epoch: 770
# target: prince
# 1  context word: future
# 0.0
# Epoch: 771
# target: king
# 7  context word: daughter
# 0.0
# Epoch: 772
# target: son
# 4  context word: strong
# 0.0
# Epoch: 773
# target: daughter
# 2  context word: princess
# 0.0
# Epoch: 774
# target: boy
# 28  context word: daughter
# 0.0
# Epoch: 775
# target: man
# 18  context word: man
# 0.0
# Epoch: 776
# target: son
# 4  context word: beautiful
# 0.0
# Epoch: 777
# target: king
# 13  context word: woman
# 0.0
# Epoch: 778
# target: queen
# 12  context word: man
# 0.0
# Epoch: 779
# target: daughter
# 2  context word: rule
# 0.0
# Epoch: 780
# target: queen
# 25  context word: children
# 0.0
# Epoch: 781
# target: family
# 23  context word: family
# 0.0
# Epoch: 782
# target: king
# 7  context word: strong
# 0.0
# Epoch: 783
# target: princess
# 10  context word: woman
# 0.0
# Epoch: 784
# target: children
# 26  context word: woman
# 0.0
# Epoch: 785
# target: son
# 4  context word: beautiful
# 0.0
# Epoch: 786
# target: family
# 23  context word: woman
# 0.0
# Epoch: 787
# target: man
# 18  context word: man
# 0.0
# Epoch: 788
# target: princess
# 10  context word: beautiful
# 0.0
# Epoch: 789
# target: queen
# 25  context word: beautiful
# 0.0
# Epoch: 790
# target: princess
# 3  context word: son
# 0.0
# Epoch: 791
# target: princess
# 10  context word: queen
# 0.0
# Epoch: 792
# target: son
# 4  context word: beautiful
# 0.0
# Epoch: 793
# target: woman
# 8  context word: future
# 0.0
# Epoch: 794
# target: queen
# 9  context word: beautiful
# 0.0
# Epoch: 795
# target: children
# 26  context word: rule
# 0.0
# Epoch: 796
# target: beautiful
# 20  context word: beautiful
# 0.0
# Epoch: 797
# target: queen
# 11  context word: queen
# 0.0
# Epoch: 798
# target: queen
# 9  context word: man
# 0.0
# Epoch: 799
# target: man
# 6  context word: man
# 0.0
# Epoch: 800
# target: boy
# 28  context word: children
# 0.0
# Epoch: 801
# target: son
# 4  context word: son
# 0.0
# Epoch: 802
# target: family
# 23  context word: rule
# 0.0
# Epoch: 803
# target: woman
# 8  context word: family
# 0.0
# Epoch: 804
# target: rule
# 14  context word: future
# 0.0
# Epoch: 805
# target: strong
# 17  context word: strong
# 0.0
# Epoch: 806
# target: beautiful
# 20  context word: queen
# 0.0
# Epoch: 807
# target: queen
# 9  context word: man
# 0.0
# Epoch: 808
# target: royal
# 22  context word: man
# 0.0
# Epoch: 809
# target: strong
# 17  context word: boy
# 0.0
# Epoch: 810
# target: family
# 23  context word: royal
# 0.0
# Epoch: 811
# target: beautiful
# 20  context word: son
# 0.0
# Epoch: 812
# target: royal
# 22  context word: beautiful
# 0.0
# Epoch: 813
# target: daughter
# 2  context word: realm
# 0.0
# Epoch: 814
# target: queen
# 12  context word: king
# 0.0
# Epoch: 815
# target: man
# 18  context word: rule
# 0.0
# Epoch: 816
# target: woman
# 21  context word: woman
# 0.0
# Epoch: 817
# target: prince
# 27  context word: future
# 0.0
# Epoch: 818
# target: queen
# 11  context word: beautiful
# 0.0
# Epoch: 819
# target: king
# 7  context word: rule
# 0.0
# Epoch: 820
# target: rule
# 14  context word: future
# 0.0
# Epoch: 821
# target: family
# 23  context word: man
# 0.0
# Epoch: 822
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 823
# target: rule
# 14  context word: princess
# 0.0
# Epoch: 824
# target: prince
# 16  context word: rule
# 0.0
# Epoch: 825
# target: princess
# 3  context word: beautiful
# 0.0
# Epoch: 826
# target: man
# 18  context word: man
# 0.0
# Epoch: 827
# target: queen
# 9  context word: strong
# 0.0
# Epoch: 828
# target: prince
# 5  context word: daughter
# 0.0
# Epoch: 829
# target: son
# 4  context word: beautiful
# 0.0
# Epoch: 830
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 831
# target: princess
# 10  context word: man
# 0.0
# Epoch: 832
# target: prince
# 16  context word: rule
# 0.0
# Epoch: 833
# target: queen
# 25  context word: future
# 0.0
# Epoch: 834
# target: king
# 13  context word: rule
# 0.0
# Epoch: 835
# target: woman
# 21  context word: woman
# 0.0
# Epoch: 836
# target: king
# 13  context word: beautiful
# 0.0
# Epoch: 837
# target: woman
# 8  context word: realm
# 0.0
# Epoch: 838
# target: princess
# 3  context word: strong
# 0.0
# Epoch: 839
# target: daughter
# 2  context word: rule
# 0.0
# Epoch: 840
# target: daughter
# 2  context word: royal
# 0.0
# Epoch: 841
# target: family
# 23  context word: family
# 0.0
# Epoch: 842
# target: prince
# 27  context word: prince
# 0.0
# Epoch: 843
# target: queen
# 12  context word: man
# 0.0
# Epoch: 844
# target: woman
# 8  context word: children
# 0.0
# Epoch: 845
# target: king
# 7  context word: strong
# 0.0
# Epoch: 846
# target: boy
# 28  context word: son
# 0.0
# Epoch: 847
# target: man
# 18  context word: realm
# 0.0
# Epoch: 848
# target: princess
# 10  context word: queen
# 0.0
# Epoch: 849
# target: prince
# 27  context word: daughter
# 0.0
# Epoch: 850
# target: queen
# 12  context word: queen
# 0.0
# Epoch: 851
# target: queen
# 11  context word: queen
# 0.0
# Epoch: 852
# target: beautiful
# 20  context word: son
# 0.0
# Epoch: 853
# target: children
# 26  context word: man
# 0.0
# Epoch: 854
# target: prince
# 16  context word: rule
# 0.0
# Epoch: 855
# target: family
# 23  context word: son
# 0.0
# Epoch: 856
# target: man
# 6  context word: future
# 0.0
# Epoch: 857
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 858
# target: son
# 4  context word: beautiful
# 0.0
# Epoch: 859
# target: queen
# 11  context word: beautiful
# 0.0
# Epoch: 860
# target: family
# 23  context word: man
# 0.0
# Epoch: 861
# target: queen
# 25  context word: queen
# 0.0
# Epoch: 862
# target: man
# 6  context word: son
# 0.0
# Epoch: 863
# target: royal
# 22  context word: beautiful
# 0.0
# Epoch: 864
# target: realm
# 15  context word: daughter
# 0.0
# Epoch: 865
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 866
# target: queen
# 25  context word: daughter
# 0.0
# Epoch: 867
# target: prince
# 5  context word: daughter
# 0.0
# Epoch: 868
# target: children
# 26  context word: future
# 0.0
# Epoch: 869
# target: daughter
# 2  context word: family
# 0.0
# Epoch: 870
# target: man
# 18  context word: man
# 0.0
# Epoch: 871
# target: boy
# 28  context word: boy
# 0.0
# Epoch: 872
# target: king
# 7  context word: strong
# 0.0
# Epoch: 873
# target: princess
# 10  context word: man
# 0.0
# Epoch: 874
# target: queen
# 12  context word: man
# 0.0
# Epoch: 875
# target: king
# 24  context word: man
# 0.0
# Epoch: 876
# target: daughter
# 2  context word: boy
# 0.0
# Epoch: 877
# target: man
# 6  context word: boy
# 0.0
# Epoch: 878
# target: boy
# 28  context word: children
# 0.0
# Epoch: 879
# target: princess
# 19  context word: beautiful
# 0.0
# Epoch: 880
# target: man
# 18  context word: man
# 0.0
# Epoch: 881
# target: queen
# 11  context word: woman
# 0.0
# Epoch: 882
# target: king
# 13  context word: beautiful
# 0.0
# Epoch: 883
# target: princess
# 3  context word: rule
# 0.0
# Epoch: 884
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 885
# target: queen
# 11  context word: man
# 0.0
# Epoch: 886
# target: queen
# 12  context word: woman
# 0.0
# Epoch: 887
# target: prince
# 27  context word: strong
# 0.0
# Epoch: 888
# target: prince
# 27  context word: strong
# 0.0
# Epoch: 889
# target: beautiful
# 20  context word: daughter
# 0.0
# Epoch: 890
# target: prince
# 5  context word: man
# 0.0
# Epoch: 891
# target: beautiful
# 20  context word: strong
# 0.0
# Epoch: 892
# target: prince
# ...
# 0.0
# Epoch: 1647
# target: princess
# 10  context word: beautiful
# 0.0
# Epoch: 1648
# target: king
# 13  context word: queen
# 0.0
# Epoch: 1649
# target: queen
# 9  context word: children
# 0.0
# Epoch: 1650
# target: king
# 7  context word: future
# 0.0
# Epoch: 1651
# target: king
# 24  context word: daughter
# 0.0
# Epoch: 1652
# target: prince
# 1  context word: woman
# 0.0
# Epoch: 1653
# target: princess
# 3  context word: children
# 0.0
# Epoch: 1654
# target: queen
# 9  context word: man
# 0.0
# Epoch: 1655
# target: queen
# 9  context word: woman
# 0.0
# Epoch: 1656
# target: queen
# 9  context word: man
# 0.0
# Epoch: 1657
# target: royal
# 22  context word: royal
# 0.0
# Epoch: 1658
# target: boy
# 28  context word: rule
# 0.0
# Epoch: 1659
# target: queen
# 11  context word: queen
# 0.0
# Epoch: 1660
# target: children
# 26  context word: daughter
# 0.0
# Epoch: 1661
# target: king
# 24  context word: son
# 0.0
# Epoch: 1662
# target: strong
# 17  context word: boy
# 0.0
# Epoch: 1663
# target: realm
# 15  context word: man
# 0.0
# Epoch: 1664
# target: king
# 0  context word: future
# 0.0
# Epoch: 1665
# target: prince
# 5  context word: beautiful
# 0.0
# Epoch: 1666
# target: rule
# 14  context word: woman
# 0.0
# Epoch: 1667
# target: queen
# 9  context word: royal
# 0.0
# Epoch: 1668
# target: family
# 23  context word: strong
# 0.0
# Epoch: 1669
# target: man
# 6  context word: strong
# 0.0
# Epoch: 1670
# target: man
# 6  context word: boy
# 0.0
# Epoch: 1671
# target: children
# 26  context word: daughter
# 0.0
# Epoch: 1672
# target: strong
# 17  context word: children
# 0.0
# Epoch: 1673
# target: king
# 13  context word: strong
# 0.0
# Epoch: 1674
# target: children
# 26  context word: queen
# 0.0
# Epoch: 1675
# target: queen
# 12  context word: son
# 0.0
# Epoch: 1676
# target: woman
# 8  context word: strong
# 0.0
# Epoch: 1677
# target: queen
# 9  context word: royal
# 0.0
# Epoch: 1678
# target: man
# 6  context word: family
# 0.0
# Epoch: 1679
# target: royal
# 22  context word: realm
# 0.0
# Epoch: 1680
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 1681
# target: queen
# 25  context word: family
# 0.0
# Epoch: 1682
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 1683
# target: woman
# 21  context word: queen
# 0.0
# Epoch: 1684
# target: prince
# 16  context word: family
# 0.0
# Epoch: 1685
# target: woman
# 8  context word: future
# 0.0
# Epoch: 1686
# target: daughter
# 2  context word: boy
# 0.0
# Epoch: 1687
# target: family
# 23  context word: daughter
# 0.0
# Epoch: 1688
# target: strong
# 17  context word: realm
# 0.0
# Epoch: 1689
# target: king
# 7  context word: strong
# 0.0
# Epoch: 1690
# target: realm
# 15  context word: man
# 0.0
# Epoch: 1691
# target: king
# 7  context word: son
# 0.0
# Epoch: 1692
# target: children
# 26  context word: children
# 0.0
# Epoch: 1693
# target: man
# 6  context word: daughter
# 0.0
# Epoch: 1694
# target: prince
# 5  context word: princess
# 0.0
# Epoch: 1695
# target: family
# 23  context word: son
# 0.0
# Epoch: 1696
# target: daughter
# 2  context word: man
# 0.0
# Epoch: 1697
# target: man
# 6  context word: son
# 0.0
# Epoch: 1698
# target: princess
# 19  context word: man
# 0.0
# Epoch: 1699
# target: beautiful
# 20  context word: man
# 0.0
# Epoch: 1700
# target: son
# 4  context word: beautiful
# 0.0
# Epoch: 1701
# target: prince
# 16  context word: rule
# 0.0
# Epoch: 1702
# target: royal
# 22  context word: family
# 0.0
# Epoch: 1703
# target: prince
# 5  context word: queen
# 0.0
# Epoch: 1704
# target: man
# 6  context word: boy
# 0.0
# Epoch: 1705
# target: family
# 23  context word: man
# 0.0
# Epoch: 1706
# target: king
# 0  context word: family
# 0.0
# Epoch: 1707
# target: royal
# 22  context word: strong
# 0.0
# Epoch: 1708
# target: children
# 26  context word: woman
# 0.0
# Epoch: 1709
# target: royal
# 22  context word: man
# 0.0
# Epoch: 1710
# target: family
# 23  context word: strong
# 0.0
# Epoch: 1711
# target: prince
# 27  context word: family
# 0.0
# Epoch: 1712
# target: king
# 0  context word: future
# 0.0
# Epoch: 1713
# target: princess
# 10  context word: family
# 0.0
# Epoch: 1714
# target: queen
# 9  context word: man
# 0.0
# Epoch: 1715
# target: king
# 7  context word: royal
# 0.0
# Epoch: 1716
# target: royal
# 22  context word: family
# 0.0
# Epoch: 1717
# target: queen
# 11  context word: man
# 0.0
# Epoch: 1718
# target: man
# 18  context word: princess
# 0.0
# Epoch: 1719
# target: prince
# 16  context word: woman
# 0.0
# Epoch: 1720
# target: princess
# 3  context word: princess
# 0.0
# Epoch: 1721
# target: children
# 26  context word: future
# 0.0
# Epoch: 1722
# target: strong
# 17  context word: strong
# 0.0
# Epoch: 1723
# target: family
# 23  context word: rule
# 0.0
# Epoch: 1724
# target: prince
# 1  context word: queen
# 0.0
# Epoch: 1725
# target: beautiful
# 20  context word: beautiful
# 0.0
# Epoch: 1726
# target: realm
# 15  context word: strong
# 0.0
# Epoch: 1727
# target: queen
# 9  context word: children
# 0.0
# Epoch: 1728
# target: princess
# 19  context word: realm
# 0.0
# Epoch: 1729
# target: prince
# 5  context word: woman
# 0.0
# Epoch: 1730
# target: prince
# 5  context word: royal
# 0.0
# Epoch: 1731
# target: prince
# 16  context word: rule
# 0.0
# Epoch: 1732
# target: man
# 18  context word: man
# 0.0
# Epoch: 1733
# target: royal
# 22  context word: queen
# 0.0
# Epoch: 1734
# target: rule
# 14  context word: daughter
# 0.0
# Epoch: 1735
# target: daughter
# 2  context word: future
# 0.0
# Epoch: 1736
# target: princess
# 10  context word: man
# 0.0
# Epoch: 1737
# target: queen
# 25  context word: realm
# 0.0
# Epoch: 1738
# target: man
# 18  context word: man
# 0.0
# Epoch: 1739
# target: realm
# 15  context word: future
# 0.0
# Epoch: 1740
# target: son
# 4  context word: prince
# 0.0
# Epoch: 1741
# target: princess
# 19  context word: woman
# 0.0
# Epoch: 1742
# target: princess
# 3  context word: man
# 0.0
# Epoch: 1743
# target: woman
# 8  context word: queen
# 0.0
# Epoch: 1744
# target: boy
# 28  context word: family
# 0.0
# Epoch: 1745
# target: princess
# 3  context word: family
# 0.0
# Epoch: 1746
# target: man
# 6  context word: son
# 0.0
# Epoch: 1747
# target: rule
# 14  context word: future
# 0.0
# Epoch: 1748
# target: royal
# 22  context word: man
# 0.0
# Epoch: 1749
# target: beautiful
# 20  context word: queen
# 0.0
# Epoch: 1750
# target: man
# 18  context word: man
# 0.0
# Epoch: 1751
# target: daughter
# 2  context word: royal
# 0.0
# Epoch: 1752
# target: son
# 4  context word: children
# 0.0
# Epoch: 1753
# target: children
# 26  context word: family
# 0.0
# Epoch: 1754
# target: king
# 24  context word: royal
# 0.0
# Epoch: 1755
# target: princess
# 3  context word: man
# 0.0
# Epoch: 1756
# target: prince
# 16  context word: strong
# 0.0
# Epoch: 1757
# target: king
# 13  context word: beautiful
# 0.0
# Epoch: 1758
# target: prince
# 16  context word: princess
# 0.0
# Epoch: 1759
# target: prince
# 1  context word: future
# 0.0
# Epoch: 1760
# target: queen
# 11  context word: man
# 0.0
# Epoch: 1761
# target: queen
# 25  context word: woman
# 0.0
# Epoch: 1762
# target: princess
# 10  context word: king
# 0.0
# Epoch: 1763
# target: prince
# 16  context word: strong
# 0.0
# Epoch: 1764
# target: children
# 26  context word: king
# 0.0
# Epoch: 1765
# target: king
# 24  context word: strong
# 0.0
# Epoch: 1766
# target: king
# 24  context word: son
# 0.0
# Epoch: 1767
# target: royal
# 22  context word: man
# 0.0
# Epoch: 1768
# target: man
# 18  context word: man
# 0.0
# Epoch: 1769
# target: family
# 23  context word: son
# 0.0
# Epoch: 1770
# target: man
# 18  context word: princess
# 0.0
# Epoch: 1771
# target: woman
# 8  context word: woman
# 0.0
# Epoch: 1772
# target: children
# 26  context word: king
# 0.0
# Epoch: 1773
# target: son
# 4  context word: beautiful
# 0.0
# Epoch: 1774
# target: queen
# 12  context word: princess
# 0.0
# Epoch: 1775
# target: prince
# 27  context word: family
# 0.0
# Epoch: 1776
# target: realm
# 15  context word: man
# 0.0
# Epoch: 1777
# target: strong
# 17  context word: strong
# 0.0
# Epoch: 1778
# target: king
# 7  context word: daughter
# 0.0
# Epoch: 1779
# target: rule
# 14  context word: daughter
# 0.0
# Epoch: 1780
# target: rule
# 14  context word: queen
# 0.0
# Epoch: 1781
# target: queen
# 25  context word: future
# 0.0
# Epoch: 1782
# target: princess
# 10  context word: king
# 0.0
# Epoch: 1783
# target: woman
# 21  context word: woman
# 0.0
# Epoch: 1784
# target: king
# 24  context word: man
# 0.0
# Epoch: 1785
# target: daughter
# 2  context word: princess
# 0.0
# Epoch: 1786
# target: princess
# 19  context word: daughter
# 0.0
# Epoch: 1787
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 1788
# target: princess
# 19  context word: beautiful
# 0.0
# Epoch: 1789
# target: rule
# 14  context word: boy
# 0.0
# Epoch: 1790
# target: queen
# 11  context word: woman
# 0.0
# Epoch: 1791
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 1792
# target: royal
# 22  context word: son
# 0.0
# Epoch: 1793
# target: rule
# 14  context word: princess
# 0.0
# Epoch: 1794
# target: man
# 6  context word: boy
# 0.0
# Epoch: 1795
# target: princess
# 3  context word: beautiful
# 0.0
# Epoch: 1796
# target: queen
# 11  context word: man
# 0.0
# Epoch: 1797
# target: family
# 23  context word: family
# 0.0
# Epoch: 1798
# target: princess
# 10  context word: family
# 0.0
# Epoch: 1799
# target: children
# 26  context word: beautiful
# 0.0
# Epoch: 1800
# target: prince
# 1  context word: queen
# 0.0
# Epoch: 1801
# target: queen
# 25  context word: royal
# 0.0
# Epoch: 1802
# target: prince
# 16  context word: realm
# 0.0
# Epoch: 1803
# target: king
# 13  context word: son
# 0.0
# Epoch: 1804
# target: boy
# 28  context word: king
# 0.0
# Epoch: 1805
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 1806
# target: prince
# 1  context word: son
# 0.0
# Epoch: 1807
# target: boy
# 28  context word: daughter
# 0.0
# Epoch: 1808
# target: king
# 7  context word: future
# 0.0
# Epoch: 1809
# target: king
# 24  context word: future
# 0.0
# Epoch: 1810
# target: princess
# 19  context word: princess
# 0.0
# Epoch: 1811
# target: son
# 4  context word: royal
# 0.0
# Epoch: 1812
# target: prince
# 27  context word: family
# 0.0
# Epoch: 1813
# target: daughter
# 2  context word: queen
# 0.0
# Epoch: 1814
# target: king
# 0  context word: realm
# 0.0
# Epoch: 1815
# target: prince
# 16  context word: strong
# 0.0
# Epoch: 1816
# target: princess
# 3  context word: princess
# 0.0
# Epoch: 1817
# target: queen
# 9  context word: royal
# 0.0
# Epoch: 1818
# target: queen
# 12  context word: queen
# 0.0
# Epoch: 1819
# target: rule
# 14  context word: man
# 0.0
# Epoch: 1820
# target: princess
# 10  context word: king
# 0.0
# Epoch: 1821
# target: son
# 4  context word: woman
# 0.0
# Epoch: 1822
# target: queen
# 11  context word: beautiful
# 0.0
# Epoch: 1823
# target: prince
# 1  context word: beautiful
# 0.0
# Epoch: 1824
# target: children
# 26  context word: king
# 0.0
# Epoch: 1825
# target: queen
# 12  context word: princess
# 0.0
# Epoch: 1826
# target: king
# 24  context word: family
# 0.0
# Epoch: 1827
# target: king
# 24  context word: beautiful
# 0.0
# Epoch: 1828
# target: royal
# 22  context word: man
# 0.0
# Epoch: 1829
# target: queen
# 11  context word: strong
# 0.0
# Epoch: 1830
# target: woman
# 21  context word: children
# 0.0
# Epoch: 1831
# target: princess
# 19  context word: son
# 0.0
# Epoch: 1832
# target: man
# 18  context word: princess
# 0.0
# Epoch: 1833
# target: queen
# 9  context word: man
# 0.0
# Epoch: 1834
# target: king
# 13  context word: family
# 0.0
# Epoch: 1835
# target: family
# 23  context word: realm
# 0.0
# Epoch: 1836
# target: king
# 13  context word: king
# 0.0
# Epoch: 1837
# target: prince
# 5  context word: strong
# 0.0
# Epoch: 1838
# target: rule
# 14  context word: boy
# 0.0
# Epoch: 1839
# target: children
# 26  context word: queen
# 0.0
# Epoch: 1840
# target: king
# 24  context word: son
# 0.0
# Epoch: 1841
# target: princess
# 10  context word: daughter
# 0.0
# Epoch: 1842
# target: man
# 6  context word: queen
# 0.0
# Epoch: 1843
# target: prince
# 1  context word: queen
# 0.0
# Epoch: 1844
# target: rule
# 14  context word: queen
# 0.0
# Epoch: 1845
# target: realm
# 15  context word: prince
# 0.0
# Epoch: 1846
# target: beautiful
# 20  context word: beautiful
# 0.0
# Epoch: 1847
# target: daughter
# 2  context word: woman
# 0.0
# Epoch: 1848
# target: princess
# 19  context word: royal
# 0.0
# Epoch: 1849
# target: queen
# 12  context word: princess
# 0.0
# Epoch: 1850
# target: princess
# 19  context word: strong
# 0.0
# Epoch: 1851
# target: man
# 6  context word: man
# 0.0
# Epoch: 1852
# target: king
# 24  context word: daughter
# 0.0
# Epoch: 1853
# target: woman
# 8  context word: daughter
# 0.0
# Epoch: 1854
# target: man
# 18  context word: man
# 0.0
# Epoch: 1855
# target: king
# 0  context word: beautiful
# 0.0
# Epoch: 1856
# target: daughter
# 2  context word: rule
# 0.0
# Epoch: 1857
# target: family
# 23  context word: man
# 0.0
# Epoch: 1858
# target: queen
# 9  context word: prince
# 0.0
# Epoch: 1859
# target: man
# 18  context word: strong
# 0.0
# Epoch: 1860
# target: daughter
# 2  context word: boy
# 0.0
# Epoch: 1861
# target: rule
# 14  context word: children
# 0.0
# Epoch: 1862
# target: son
# 4  context word: beautiful
# 0.0
# Epoch: 1863
# target: queen
# 25  context word: future
# 0.0
# Epoch: 1864
# target: prince
# 1  context word: woman
# 0.0
# Epoch: 1865
# target: son
# 4  context word: family
# 0.0
# Epoch: 1866
# target: son
# 4  context word: children
# 0.0
# Epoch: 1867
# target: daughter
# 2  context word: family
# 0.0
# Epoch: 1868
# target: king
# 13  context word: son
# 0.0
# Epoch: 1869
# target: king
# 0  context word: strong
# 0.0
# Epoch: 1870
# target: woman
# 21  context word: beautiful
# 0.0
# Epoch: 1871
# target: princess
# 19  context word: rule
# 0.0
# Epoch: 1872
# target: king
# 24  context word: strong
# 0.0
# Epoch: 1873
# target: beautiful
# 20  context word: woman
# 0.0
# Epoch: 1874
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 1875
# target: prince
# 1  context word: queen
# 0.0
# Epoch: 1876
# target: prince
# 16  context word: daughter
# 0.0
# Epoch: 1877
# target: daughter
# 2  context word: realm
# 0.0
# Epoch: 1878
# target: prince
# 27  context word: queen
# 0.0
# Epoch: 1879
# target: strong
# 17  context word: daughter
# 0.0
# Epoch: 1880
# target: man
# 6  context word: princess
# 0.0
# Epoch: 1881
# target: prince
# 1  context word: future
# 0.0
# Epoch: 1882
# target: king
# 13  context word: rule
# 0.0
# Epoch: 1883
# target: queen
# 11  context word: realm
# 0.0
# Epoch: 1884
# target: prince
# 5  context word: future
# 0.0
# Epoch: 1885
# target: children
# 26  context word: man
# 0.0
# Epoch: 1886
# target: daughter
# 2  context word: rule
# 0.0
# Epoch: 1887
# target: rule
# 14  context word: rule
# 0.0
# Epoch: 1888
# target: queen
# 12  context word: king
# 0.0
# Epoch: 1889
# target: man
# 18  context word: man
# 0.0
# Epoch: 1890
# target: king
# 0  context word: strong
# 0.0
# Epoch: 1891
# target: king
# 0  context word: beautiful
# 0.0
# Epoch: 1892
# target: daughter
# 2  context word: king
# 0.0
# Epoch: 1893
# target: king
# 13  context word: beautiful
# 0.0
# Epoch: 1894
# target: prince
# 1  context word: woman
# 0.0
# Epoch: 1895
# target: family
# 23  context word: rule
# 0.0
# Epoch: 1896
# target: king
# 24  context word: man
# 0.0
# Epoch: 1897
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 1898
# target: king
# 0  context word: future
# 0.0
# Epoch: 1899
# target: man
# 6  context word: royal
# 0.0
# Epoch: 1900
# target: realm
# 15  context word: queen
# 0.0
# Epoch: 1901
# target: strong
# 17  context word: queen
# 0.0
# Epoch: 1902
# target: woman
# 8  context word: queen
# 0.0
# Epoch: 1903
# target: boy
# 28  context word: strong
# 0.0
# Epoch: 1904
# target: king
# 0  context word: realm
# 0.0
# Epoch: 1905
# target: woman
# 21  context word: man
# 0.0
# Epoch: 1906
# target: prince
# 27  context word: strong
# 0.0
# Epoch: 1907
# target: queen
# 25  context word: rule
# 0.0
# Epoch: 1908
# target: realm
# 15  context word: man
# 0.0
# Epoch: 1909
# target: daughter
# 2  context word: woman
# 0.0
# Epoch: 1910
# target: rule
# 14  context word: rule
# 0.0
# Epoch: 1911
# target: queen
# 9  context word: son
# 0.0
# Epoch: 1912
# target: woman
# 8  context word: strong
# 0.0
# Epoch: 1913
# target: queen
# 11  context word: rule
# 0.0
# Epoch: 1914
# target: princess
# 10  context word: rule
# 0.0
# Epoch: 1915
# target: beautiful
# 20  context word: family
# 0.0
# Epoch: 1916
# target: princess
# 19  context word: realm
# 0.0
# Epoch: 1917
# target: man
# 18  context word: strong
# 0.0
# Epoch: 1918
# target: strong
# 17  context word: man
# 0.0
# Epoch: 1919
# target: family
# 23  context word: woman
# 0.0
# Epoch: 1920
# target: royal
# 22  context word: son
# 0.0
# Epoch: 1921
# target: king
# 24  context word: family
# 0.0
# Epoch: 1922
# target: princess
# 10  context word: strong
# 0.0
# Epoch: 1923
# target: realm
# 15  context word: strong
# 0.0
# Epoch: 1924
# target: strong
# 17  context word: boy
# 0.0
# Epoch: 1925
# target: prince
# 27  context word: family
# 0.0
# Epoch: 1926
# target: children
# 26  context word: queen
# 0.0
# Epoch: 1927
# target: boy
# 28  context word: son
# 0.0
# Epoch: 1928
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 1929
# target: woman
# 8  context word: beautiful
# 0.0
# Epoch: 1930
# target: daughter
# 2  context word: boy
# 0.0
# Epoch: 1931
# target: woman
# 21  context word: queen
# 0.0
# Epoch: 1932
# target: woman
# 21  context word: family
# 0.0
# Epoch: 1933
# target: king
# 13  context word: prince
# 0.0
# Epoch: 1934
# target: king
# 24  context word: son
# 0.0
# Epoch: 1935
# target: realm
# 15  context word: realm
# 0.0
# Epoch: 1936
# target: prince
# 27  context word: beautiful
# 0.0
# Epoch: 1937
# target: woman
# 8  context word: prince
# 0.0
# Epoch: 1938
# target: prince
# 1  context word: strong
# 0.0
# Epoch: 1939
# target: prince
# 16  context word: woman
# 0.0
# Epoch: 1940
