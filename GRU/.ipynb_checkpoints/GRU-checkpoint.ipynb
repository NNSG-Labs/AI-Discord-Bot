# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
#word 2 vec
def oneHotEncoding(filename):
    file = open(filename, "r")

# %%
def activate(x, func):
    if func == "tanh":
        return np.tanh(x)
    
    elif func == "sigmoid":
        return 1.0/(1.0+np.exp(-x))
    
    elif func == "none":
        return x
    
    else:
        return None
    
    
    
def activateDer(x, func):
    if func == "tanh":
        return 1 - x**2
    
    elif func == "sigmoid":
        return x*(1-x)
    
    elif func == "none":
        return np.ones(x.shape)
    
    else:
        return np.zeros(x.shape)
    
    
    
def MSE_der(tar, x):
    return 2*(x-tar)

def MSE(tar, x):
    return (x-tar)**2

def initWeights(rows, cols):
    return np.random.rand(rows, cols) * 2 - 1

def xavierInit(rows, cols, prevL=1, thisL=1):
    var = np.sqrt(2/(thisL + prevL))
    return (np.random.rand(rows, cols) * 2 - 1) * var

def printShape(ar1, ar2=np.zeros((0, 0)), ar3=np.zeros((0, 0)), ar4=np.zeros((0, 0))):
    print(ar1.shape, ar2.shape, ar3.shape, ar4.shape)
    
    
def fileToVector(filename, maxDim=26):
    outData = np.zeros((1, maxDim, 1))
    file = open(filename, 'r')
    for line in file:
        for c in line:
            if ord(c) >= ord('A') and abs(ord(c)-ord('A')) < maxDim:
                newChar = np.zeros((1, maxDim, 1))
                newChar[0][ord(c)-ord('A')][0] = 1
                outData = np.append(outData, newChar, axis=0)
            elif c == ' ':
                newChar = np.zeros((1, maxDim, 1))
                newChar[0][maxDim-1][0] = 1
                outData = np.append(outData, newChar, axis=0)
                
    return outData

def softmax(X):
    theta = 2
    ps = np.exp(X * theta)
    ps /= np.sum(ps)
    return ps


def vectorToLetter(inp, maxDim):
    output = ""
    for v in inp:
        indices = range(0, maxDim)
        index = getWeightedMax(v, 4)
        if index == maxDim-1:
            output += " "
        else:
            output += chr(ord('A') + index)
    return output

def getWeightedMax(prob, we=1):
    if np.sum(prob**we) == 0:
        return 0
    indices = range(0, len(prob))
    return np.random.choice(indices, p=((prob**we)/np.sum(prob**we)))

# %%
class Layer:
    
    def __init__(self, inp, out, lr):
        self.inputs = inp
        self.outputs = out
        self.learnRate = lr
        self.backpropSteps = 20
        
        N = out
        T = 1
        M = inp
        
        self.H = np.zeros((T, N, 1))
        self.Hc = np.zeros((T, N, 1))
        self.Z = np.zeros((T, N, 1))
        self.R = np.zeros((T, N, 1))
        self.X = np.zeros((T, M, 1))
        
        self.bh = xavierInit(N, 1, M, N)
        self.br = xavierInit(N, 1, M, N)
        self.bz = xavierInit(N, 1, M, N)
        
        self.Whh = xavierInit(N, N, M, N)
        self.Whz = xavierInit(N, N, M, N)
        self.Whr = xavierInit(N, N, M, N)
        
        self.Wxh = xavierInit(N, M, M, N)
        self.Wxr = xavierInit(N, M, M, N)
        self.Wxz = xavierInit(N, M, M, N)
        
        self.bhm = np.zeros((N, 1))
        self.brm = np.zeros((N, 1))
        self.bzm = np.zeros((N, 1))
        
        self.Whhm = np.zeros((N, N))
        self.Whzm = np.zeros((N, N))
        self.Whrm = np.zeros((N, N))
        
        self.Wxhm = np.zeros((N, M))
        self.Wxrm = np.zeros((N, M))
        self.Wxzm = np.zeros((N, M))
        
        self.bhv = np.zeros((N, 1))
        self.brv = np.zeros((N, 1))
        self.bzv = np.zeros((N, 1))
        
        self.Whhv = np.zeros((N, N))
        self.Whzv = np.zeros((N, N))
        self.Whrv = np.zeros((N, N))
       
        self.Wxhv = np.zeros((N, M))
        self.Wxrv = np.zeros((N, M))
        self.Wxzv = np.zeros((N, M))
        
        self.bhM = np.zeros((N, 1))
        self.brM = np.zeros((N, 1))
        self.bzM = np.zeros((N, 1))
        
        self.WhhM = np.zeros((N, N))
        self.WhzM = np.zeros((N, N))
        self.WhrM = np.zeros((N, N))
        
        self.WxhM = np.zeros((N, M))
        self.WxrM = np.zeros((N, M))
        self.WxzM = np.zeros((N, M))
        
        self.bhV = np.zeros((N, 1))
        self.brV = np.zeros((N, 1))
        self.bzV = np.zeros((N, 1))
        
        self.WhhV = np.zeros((N, N))
        self.WhzV = np.zeros((N, N))
        self.WhrV = np.zeros((N, N))
       
        self.WxhV = np.zeros((N, M))
        self.WxrV = np.zeros((N, M))
        self.WxzV = np.zeros((N, M))
        
    def clearMemory(self):
        
        N = self.outputs
        M = self.inputs
        
        self.H = np.zeros((1, self.outputs, 1))
        self.Hc = np.zeros((1, self.outputs, 1))
        self.Z = np.zeros((1, self.outputs, 1))
        self.R = np.zeros((1, self.outputs, 1))
        self.X = np.zeros((1, self.inputs, 1))
        self.bhm = np.zeros((N, 1))
        self.brm = np.zeros((N, 1))
        self.bzm = np.zeros((N, 1))        
        self.Whhm = np.zeros((N, N))
        self.Whzm = np.zeros((N, N))
        self.Whrm = np.zeros((N, N))        
        self.Wxhm = np.zeros((N, M))
        self.Wxrm = np.zeros((N, M))
        self.Wxzm = np.zeros((N, M))        
        self.bhv = np.zeros((N, 1))
        self.brv = np.zeros((N, 1))
        self.bzv = np.zeros((N, 1))        
        self.Whhv = np.zeros((N, N))
        self.Whzv = np.zeros((N, N))
        self.Whrv = np.zeros((N, N))       
        self.Wxhv = np.zeros((N, M))
        self.Wxrv = np.zeros((N, M))
        self.Wxzv = np.zeros((N, M))        
        self.bhM = np.zeros((N, 1))
        self.brM = np.zeros((N, 1))
        self.bzM = np.zeros((N, 1))        
        self.WhhM = np.zeros((N, N))
        self.WhzM = np.zeros((N, N))
        self.WhrM = np.zeros((N, N))        
        self.WxhM = np.zeros((N, M))
        self.WxrM = np.zeros((N, M))
        self.WxzM = np.zeros((N, M))        
        self.bhV = np.zeros((N, 1))
        self.brV = np.zeros((N, 1))
        self.bzV = np.zeros((N, 1))       
        self.WhhV = np.zeros((N, N))
        self.WhzV = np.zeros((N, N))
        self.WhrV = np.zeros((N, N))
        self.WxhV = np.zeros((N, M))
        self.WxrV = np.zeros((N, M))
        self.WxzV = np.zeros((N, M))
        
    def forwardPass(self, inp):
        
        #calculating forward pass
        prevH = self.H[-1] if len(self.H) > 0 else np.zeros((self.outputs, 1))
        newZ = self.Wxz @ inp + self.Whz @ prevH + self.bz
        newZ = activate(newZ, "sigmoid")
        
        newR = self.Wxr @ inp + self.Whr @ prevH + self.br
        newR = activate(newR, "sigmoid")
        
        newHc = self.Wxh @ inp + self.Whh @ (prevH * newR) + self.bh
        newHc = activate(newHc, "tanh")
        
        newH = newZ * prevH + (1 - newZ) * newHc
        
        #appending to arrays
        self.H = np.append(self.H, np.array([newH]), axis=0)
        self.Z = np.append(self.Z, np.array([newZ]), axis=0)
        self.R = np.append(self.R, np.array([newR]), axis=0)
        self.Hc = np.append(self.Hc, np.array([newHc]), axis=0)
        self.X = np.append(self.X, np.array([inp]), axis=0)
        
        #removing old indices
        if len(self.H) > self.backpropSteps:
            self.H = np.delete(self.H, 0, axis=0)
            self.Z = np.delete(self.Z, 0, axis=0)
            self.R = np.delete(self.R, 0, axis=0)
            self.Hc = np.delete(self.Hc, 0, axis=0)
            self.X = np.delete(self.X, 0, axis=0)
        return newH
    
    def backprop(self, grad, iteration):
        beginTime = len(self.H)-1
        
        dWxh = 0
        dWxr = 0
        dWxz = 0
        
        dbh = 0
        dbr = 0
        dbz = 0
        
        dWhh = 0
        dWhr = 0
        dWhz = 0
        
        dbr = 0
        dbz = 0
        dbh = 0
        
        dX = 0
        dHt = grad
        
        needDX = True
        
        for i in range(0, beginTime):
            t = beginTime-i
            prevH = self.H[t-1] if len(self.H) > 0 else np.zeros((self.outputs, 1))
            
            d0 = dHt
            d1 = self.Z[t] * d0
            d2 = prevH * d0
            d3 = self.Hc[t] * d0
            d4 = -1 * d3
            d5 = d2 + d4
            d6 = (1-self.Z[t]) * d0
            d7 = d5 * (self.Z[t] * (1 - self.Z[t]))
            d8 = d6 * (1 - self.Hc[t]**2)

            d9 = self.Wxh.T @ d8
            d10 = self.Whh.T @ d8
            d11 = self.Wxz.T @ d7
            d12 = self.Whz.T @ d7
            d14 = d10 * self.R[t]
            d15 = d10 * prevH
            d16 = d15 * (self.R[t] * (1 - self.R[t]))
            d13 = self.Wxr.T @ d16
            d17 = self.Whr.T @ d16
            
            if needDX:
                dX = d9 + d11 + d13
                needDX = False
                
            dHt = d12 + d14 + d1 + d17
            dWxr += d16 @ self.X[t].T
            dWxz += d7 @ self.X[t].T
            dWxh += d8 @ self.X[t].T
            
            dWhr += d16 @ prevH.T
            dWhz += d7 @ prevH.T
            dWhh += d8 @ (prevH * self.R[t]).T
            
            dbr += d16
            dbz += d7
            dbh += d8
            
        beta1 = 0.9
        beta2 = 0.999
        self.Whrm = beta1  * self.Whrm + (1-beta1)*dWhr
        self.Whzm = beta1  * self.Whzm + (1-beta1)*dWhz
        self.Whhm = beta1  * self.Whhm + (1-beta1)*dWhh
        self.Wxrm = beta1  * self.Wxrm + (1-beta1)*dWxr
        self.Wxzm = beta1  * self.Wxzm + (1-beta1)*dWxz
        self.Wxhm = beta1  * self.Wxhm + (1-beta1)*dWxh
        self.brm = beta1  * self.brm + (1-beta1)*dbr
        self.bzm = beta1  * self.bzm + (1-beta1)*dbz
        self.bhm = beta1  * self.bhm + (1-beta1)*dbh
        
        self.Whrv = beta2  * self.Whrv + (1-beta2)*dWhr**2
        self.Whzv = beta2  * self.Whzv + (1-beta2)*dWhz**2
        self.Whhv = beta2  * self.Whhv + (1-beta2)*dWhh**2
        self.Wxrv = beta2  * self.Wxrv + (1-beta2)*dWxr**2
        self.Wxzv = beta2  * self.Wxzv + (1-beta2)*dWxz**2
        self.Wxhv = beta2  * self.Wxhv + (1-beta2)*dWxh**2
        self.brv = beta2  * self.brv + (1-beta2)*dbr**2
        self.bzv = beta2  * self.bzv + (1-beta2)*dbz**2
        self.bhv = beta2  * self.bhv + (1-beta2)*dbh**2
            
        betaPower1 = 1 - beta1**iteration
        betaPower2 = 1 - beta2**iteration
        self.WhrM = self.Whrm / betaPower1
        self.WhzM = self.Whzm / betaPower1
        self.WhhM = self.Whhm / betaPower1
        self.WxrM = self.Wxrm / betaPower1
        self.WxzM = self.Wxzm / betaPower1
        self.WxhM = self.Wxhm / betaPower1
        self.brM = self.brm / betaPower1
        self.bzM = self.bzm / betaPower1
        self.bhM = self.bhm / betaPower1
            
        self.WhrV = self.Whrv / betaPower2
        self.WhzV = self.Whzv / betaPower2
        self.WhhV = self.Whhv / betaPower2
        self.WxrV = self.Wxrv / betaPower2
        self.WxzV = self.Wxzv / betaPower2
        self.WxhV = self.Wxhv / betaPower2
        self.brV = self.brv / betaPower2
        self.bzV = self.bzv / betaPower2
        self.bhV = self.bhv / betaPower2
            
        lambd = 0.01
            
        self.Whr = self.Whr - self.learnRate * (self.WhrM/(np.sqrt(self.WhrV) + 0.000001)+ lambd * self.Whr) 
        self.Whz = self.Whz - self.learnRate * (self.WhzM/(np.sqrt(self.WhzV) + 0.000001)+ lambd * self.Whz)
        self.Whh = self.Whh - self.learnRate * (self.WhhM/(np.sqrt(self.WhhV) + 0.000001)+ lambd * self.Whh)
        self.Wxr = self.Wxr - self.learnRate * (self.WxrM/(np.sqrt(self.WxrV) + 0.000001)+ lambd * self.Wxr)
        self.Wxz = self.Wxz - self.learnRate * (self.WxzM/(np.sqrt(self.WxzV) + 0.000001)+ lambd * self.Wxz)
        self.Wxh = self.Wxh - self.learnRate * (self.WxhM/(np.sqrt(self.WxhV) + 0.000001)+ lambd * self.Wxh)
        self.br = self.br - self.learnRate * (self.brM/(np.sqrt(self.brV) + 0.000001)+ lambd * self.br)
        self.bz = self.bz - self.learnRate * (self.bzM/(np.sqrt(self.bzV) + 0.000001)+ lambd * self.bz)
        self.bh = self.bh - self.learnRate * (self.bhM/(np.sqrt(self.bhV) + 0.000001)+ lambd * self.bh)
        
        return dX

# %%
class Network:
    
    def __init__(self, bs, lr):
        self.layers = []
        self.batchSize = bs
        self.learnRate = lr
        
    
    def addLayer(self, inp, out):
        layer = Layer(inp, out, self.learnRate)
        self.layers.append(layer)
        self.ERROR = np.zeros((out,1))
        self.ERRORDER = np.zeros((out,1))
        
    def forwardPass(self, inp):
        self.layers[0].forwardPass(inp)
        for l in range(1, len(self.layers)):
            self.layers[l].forwardPass(self.layers[l-1].H[-1])
            
        self.layers[-1].H[-1] = np.expand_dims(softmax(self.layers[-1].H[-1].squeeze()), axis=1)
        return self.layers[-1].H[-1]
    
    def error(self, ans):
        self.ERROR += MSE(ans, self.layers[-1].H[-1])
        self.ERRORDER += MSE_der(ans, self.layers[-1].H[-1])
    
    def backprop(self, iteration):
        grad = (self.ERRORDER / self.batchSize) * self.layers[-1].H[-1]
        for i in range(1, len(self.layers)+1):
            grad = self.layers[-i].backprop(grad, iteration+1)
            
        errToReturn = self.ERROR / self.batchSize
        self.ERROR.fill(0)
        self.ERRORDER.fill(0)
        return errToReturn
    
    def clearMemory(self):
        for l in self.layers:
            l.clearMemory();

# %%
letters = 27
data = fileToVector("training.txt", letters) * 0.9

printShape(data)
plt.figure(figsize=(12, 6))
plt.plot(range(0, 200), data.squeeze()[:200], linewidth=1)
plt.show()
# Out:
# (25683, 27, 1) (0, 0) (0, 0) (0, 0)

# %%
batchSize = 1
epochs = 100
plotRate = 1
printRate = 1000000
learnRate = 0.001
network = Network(batchSize, learnRate)
network.addLayer(letters, 80)
network.addLayer(80, 70)
network.addLayer(70, 40)
network.addLayer(40, letters)
answers = []

for e in range(0, epochs):
    network.clearMemory()
    for i in range(0, len(data)-1):
        if (e*len(data) + i + 1) % printRate == 0:
            print("---EPOCH " + str(e) + " , SAMPLE " + str(i) + "-----------------")
            print("Forward pass:" + str(network.forwardPass(data[i])))
            print("Truth: " + str(data[i+1]))
        else:
            network.forwardPass(data[i])
        network.error(data[i+1])
        if e % plotRate == 0:
            answers.append(network.layers[-1].H[-1].squeeze())
        if (e*len(data) + i + 1) % batchSize == 0:
            if (e*len(data) + i + 1) % printRate == 0:
                print("                          Backprop: " + str(network.backprop(e*len(data) + i + 1)))
            else:
                network.backprop(e*len(data) + i + 1)
    if e % plotRate == 0:
        plt.figure(figsize=(12, 6))
        plt.plot(range(0, min(len(data), 100)), data.squeeze()[0:100], linewidth=3, alpha=0.2)
        plt.plot(range(0, min(len(data), 100)), answers[:100])
        plt.show()
        answers = []
        prevAns = network.layers[-1].H[-1]
        maxElement = np.argmax(network.layers[-1].H[-1])
        prevAns.fill(0)
        prevAns[maxElement][0] = 1
            
        for s in range(0, 1000):
            prevAns = network.forwardPass(prevAns)
            answers.append(prevAns.squeeze())
            maxElement = getWeightedMax(prevAns.squeeze(), 2.2)
            prevAns.fill(0)
            prevAns[maxElement][0] = 1
            
            
        plt.plot(range(0, 100), answers[:100])
        plt.show()
        print(vectorToLetter(answers, letters))
        answers = []
# Out:
# NE THE AND THE FAR IN THE BART IN THE S THILL AND THE AND SREN BORE WHER THE THE FERT THE SOR THE TERE THE AND YER AND THE SOR WALL NELD WALL WOR THE FOR A SUED THE THE KARD FOR THE TOR WALL THE THE DOR HART EY AND THE S T THE  AAND THE AND SKEN SREIRD SE EED WARD HOOD THE FAR AND THE FARS ET THE HAD WHER ON THE S WIND THE ON THE TEZED WHE ARD THE FOR THE HERE IN HH THE TOR TO THE REED THE S UTT THE ED WHER END BE FOR EED BIR THE OF THE SEED THE AND THE LAILD WALD BAD OF NE THE THER THE THITT THITH HE THE OF THE AND THE IN THE IN THE ON THE VEES MOR THE FIR THE AND THE FARD THE AND THE NARE THE FARD WHER S ALD THE HAD THE THE IT AND ON FGUIRD HILD AND THE THE AND THE FAR AND WHER AND AND THE THE WALD THITHED BREED THE OF THE FOR SRIND TE THE VALD THE THITH  EW THE TER EAD THE HE ON AND THE THE AND THE FARD THE WAPD HIR BOR THE THE  YIR HE FURD THE NARD THE ANM THE ON ES THE THE TIRLER AND THE TILL THE LEQT IN THER AND THE THE THITH THE S NFORS THE THE THE SREND WER ROND THE TURD THE OF
#  ORED WERE THOLE THE TING Y RET THE TIT FOR ON THE OTHER OTHER THE AITTT THE D T O MOTT LEMT WALL IN THE TINY REM THE AA FOR IN QTED WITH THING WITH ALLED AUTT ROE THE AS IN SLAST THE TICITTTHE WALL WHAT AED FOR ALLED OUTT THE F NHE MIMS OF THE TING THE S SET OUTQ AND HAD AQD EE DAQT BEND BEUTT SEAT THE S S OUT HE FAMM REVER NISS NET THE T REOW OUTT WITH ATTTKER WERE FOR SAEN WHITH THE ALLEQ EEEED A VER ZENED THE  SEEQDTTHE WALL SUMBEEP WALL THE FIUS ARIE  FHQIING WIS S  THE OJCFOO FROOR WHERE THE PAND THQ CASD WALL THE FARR WHITH FOR XONGALLED WHITH WHITH AND THE FIM SOT ANLED BAND AXLHE VER  THE FIVE THE FIRING THAT REDING THIS WRICL MONON ATT TO BETTURD SGOTTHE THT IN WITH THE TWIC THE WALL THE OTHE FIPTTTHE D MANDTHE A ON THE FIKE WALL THE ERIND WERE A  IN AAND FOR AARLED AINBED BRING KOO IN THIS REMEQD AND SUF FARD THE RETT BEMANG ANN THE XAST WAND BOTT MOTTTHER THE MIN AHL THE TER SPIND AND THE  FFUUR FRON WHITH THE AT THE TI THE OREE MASOHE KEETTHE EY THE OTHE WITH WALL AD AY TH
# THE FOR THE WALL THE MARM WAT THE MARS HER WHALLED Y S THE LEY SEEEED TO AND THE ON WITHER RACT AND THE KERT THE FIR THE MARE THE FART THE T FOR THE S AND THE T OF AND A THE FARO BEOT OF THE T ON WAS WALL THE MARS SEEE FOR THE MALL THE S AND THE LIN FOR THE WHCL THE MARLED THE FOR SZOCL THE FIRON AND THE T MEEAR OF THE FARM AND S THE HAD THE S OF ABE AND THE STTTORCALL WILL THE NINTT WAS THE FOR THE FROM HER AND S LEUTT BEER NOLED ARE TO THE FOR APANT S AND THE BEFTTRE THE  ALL THE AND THE T THE FOUR  OF THE FIRM WITH AND THE FARL WHER AND SING THE FARZ WAS THE REBOEINE AND THE AND THE BALL NOOOD THE BEMOULD THE EED THE T THE FARN THE FRFM HICARE SMANLES AND THE BED OF THE S THE N T THE TRE BALL WITH THE WALL TO THE GIN THE KERE BETTTTT THE FR ARE HOR AND ALL THE XARM SDASM THE FIRTTRE STTOR AND THE GATT AND FREE BEAR HIIT OF THE KER ALL WARD APNER HAD S HE BALL THE OT THE OHING THE T ON THE MARS QD EEEED SRANG AND BALL THE FARM THE PASGE THE AND THE TON THE HAD THE S HAD THE ZERT NOME
# THE DEMTTRE WALL THE WAS FARTTHERE AND THE AND WHERE OF THE MARIED WHITH THE GARE THE AND THE THE PART ON THY THE FARB AND IN THE DOGN ANIMALS THE FALF S AND BEUSD TO TERL THE AND S AND THE WHILL WRITH THE ONVER SAWG THE MONXTTTER JOW OF AND AIT FAND EVER AATTLER THE THIIL WERE THE WERE AND THE THE Y TO HAD UUTTT THE WORE AND GAND OF THE WAOL THE S THE AND A THE THE QARED AIN THE WALL THE AND THE THE LARM WHHILS AND HAD BERINED BETTER THE THE THE BERI FOR TOR WHORE THE THH BED A AND FIRFER HAD S AND BETTTRE THE FART THE AND BEITTTERE THE SGAND FOR AND THE S AND THE THICICD QWFER NON SOTVER BETTOR  IN THIHG WHING WAS THE WERE BEPE AND THE S AND THE THE THE S THE AND THE FARM AIN THE OTHER AND THE S THE WALL THE THE MARTTRE AND AIN ANIMALS AND WHORE THE WERE BEIN WHERE THE AND THE WALL THIRRED AND THE AND WITH THE BERI THE FARP AND THE THE THE BICCK TER S THE LALD HAD THE FARM THE OUR WAND THE THE LARMING THE LARTTTTRE THE OY BALL WITH THE WITHWHALL HILD HAD WHITH WERE WHERE ON THIS AND
# THE MARTTTTTTTTHER FARD AT OF THE MARD WHITG BEBOUT THE FIRL THE BEALE OF THE BEST THE TRITTTTTTT THE FARM TER THE WERE BITTTTTTO THE MARE THE MALL ALL WHIT THE ANLALL AND SEXF AND THE MEN WERE AND THE BEMAND ON TO SNOCT OF BELAREED AND THE THE ARAARPED SEED UULD TF ALL HE TO A THE SSS THE ANS THE NOAD THE FARN BOT THPETTTHE TORD THE XN THE MALE AND WALL THE KARTTTHE AND ON THE TRON THE TOR AND WHICH THE FAROD AALLED THE BESTTHE TARRED THE BIRTTTTHE WILE FOR THE KERMENW SUEED AND AND THE WARD THE FALRY WHICH THE SSING THE FIRLD AND THE NLALD OF AND THE ANLARD FOR MOR THE OTHER RIRHUND ON THE FARB MORTTTHE NIN OF THE BINTTTTTHE WIT RARTTTHE THERE SOT THE WILL SUTTTHE NARM ALL THE BEST SROPWORE PETTTTHE TRONED AND THE SESS THE BETTTHER FIRLD THE WALL KORKEN WITD AND AHE HAD MAND OF WALL FOR THE WRARE WHER THE IW BEMARD FOR AVITL YOR AND WHHICH THE MARTTTTTTHER THE WHIPH OF THE WHIPHON A NO OF THE FOR THEE FOR NOS THE BINTTTTTTHE NARIE BERREE BEMULLEE WHIPD WERE OF THE TARRCED THE SARTTTO
# THE FARR SICBER THE MANDER HORE THE WHEOR ANCER THE WARD FOR ABFER MATTTTTTTHE FOR WHHICH THE ANIMALS WERE THE MARTTTTTHERE JONES THE ANE THE WARD THE FARTT THE FALD N  AND WAS TO WAS REOT AND THE RESM THE FIRETTTHE ANS THE AIRTTTTTHERE ANLER THE FARR SUNLER FOR THE AND WHERE THE BARCED SIG THE FARTTT THE RERIRED FOR WITH ANTIT ON THE SINGING ON THE WARE SMEMLER TURKED FOR THE MARE BE ROME BIED AND THE GARLER THE WITIDER THE WENE WHHHHITTTHERE SME GETT THE ANOUR ZAROJLLQH SIMLER THE  TO FER THE PIG WAS AND THE WHICCTHE FARR ANLER AND THE CALLT OF THE OTHOSE THE FARR THE FARR AND ANLED THEY THE WADS THE FARR POCT WHICE THE AITTTRTHERE WHHERE SAST ALL THE THE S IN THE BEM THE BARE THE BARM AND THE OTHERM FOR TTHE BOJMNEN BBALL JONED THE FARM SOTT ANL THE FARR AND WAS ALL AND THE RIRTT ZARM BE THE THE OLD THE WITH WAS THE OR WAS RET TF WITH AND SUXN THE BEAM THE AILH THE THE OARM SIC FOR AND THE FIRMMONN AND WORLALLER WAS THEGES  THE WITH THE WAND THE BESTTHE PIG UNIMALS ANLER THE THE WHE
# THE AND IN THE  OST BE JONES WAS SING BE WITH THE JIGN A BE FOR THE FARMED THE WARNRE AND THE BE WAS COMANG THE FIURON WHIINERTHE OF THE BLORCED THE IN THE AND AND THE FARH WITH THE PTOTE THE THE BE EHARDER AND THE IN THE FALD MOT FOR THE WARDER IN THE SOALE ANE THE OF AND IN THE BE THE ON THE BARUQRTT THE ANIMALS WERE XE BE THE FIFTRE AND THE BE AND WHITE THE WARD FIRALE AND THE SITTCAND THE BE THE BE THE BE BE SNANDER THE WHERE WHHERE TO SITT OF THE BE FARE BEXKER BIDE THE BBERE THE FARH WITH OF THE BERALD WASRE BE THE WARH WITH THE IN SUT BE ANCE IN THE EITTER OF AND THE SUEN HAD AN THE FARHEIR PET BE IN THE BARMED SINGVER THE KRALD WORE THE FARH SES THE   THE UTREOOT THE WAS AND WASS AND AND THE WARH TO THE NATER THE FART AND THE AND THE OTHER OF AND WERE AND THE AND AND A NOED AND ERUTT AND ANIMED AVER AND WITH THE BE WASRE BE WRHITE BE FING WHON THE FARM ALL WAND SEAD WITH FIRE WHERE WITH WITH WHICH AND THE WITE AND THE BE FARMED SRRTT SRRON WERE BE THE FIRDEED BE OF THE WANDD TH
# BETER THE ENED THE BARS AND WAT THE BERZER AND WHOULD THE THE THITG WEREING AND SATE WHHILE THE JARM THE BARH THE BERSSFORE AND THE TARD AND ELLIHED THE OUTTHE SENFULDED WERE BEING AND DUGTT BEY AND BEY AND THE NOING THE ON THE JALBED THE ON FOR SEEE THE BIGGS AND ENDED ON THE FARM SASE BEAJ THEY WHAT THE XINT WAT THITG BERE THE REST THE WALL KOTT AND FOR THE THERE THEER AND BEAN DOQT THE THERE THE FARE THE FARCED THE TARD ANDMOSEED THE AIITE ON THE AND THE REQTTY BESFOTT THE BERJ SUBT TO AND THE BISS SOKE THE FART BEFORM FURM OF THE BERUFED AND HE AND THE SONG HE COALD THE BARE WHHICT YOUT BETORE AND THE ABALL FOR THE THERE THE DEAN THE BERY THE BALL THE BARK WHOUED IN THE BARE AND S THE AND TRRECE UNDE BEER ANDMENER AND THE AND BEBKED THE ROBBEAR THE FOR THE AIN AND MART THE HURLED WHOUED SATT THE OTHER AND THE GOAND SOTER THE ONER THESE THE FIZALD ON THE AND THE SULDER THE ANTARD THE FARL BEALD TRARD HIHED WERE AND THE FARM BAWALL ANE THE BERSSDED ON THE FIMALS THE BARE THE BERE AND
# THE IN KIS WALL ANN THE BABRE XONDAY AND THE OILD THE FOR THE AN AND THE BEON ANT IN AND THE BIBBBBBBBBBOCBWIGM THE BALL AND THE WALL THE WALL AND AND AND THE ON AND WALL AND THE SALL AND HIR AND WALL JONES OF THE RRRRKKT IN AND THE BEAS THE MANDE TIN THE SUBT THE AN THE FARAED  AND AND THE RAAT OF THE BALL THE TAVE WALL WALL WOTLATE WITH GRREE IN THE BADCETTER FOR NOT THE AN THE BETTERUIND THE BALL OF HAD ON THE IN THE RRRRMUT OF THE BESKAND THE BIS WALL THE  AND FOR THE SUMTER THE BAXAR AND THE TARQ RRREING AND BOT THE TART AND THE BEST BEAND UUTTTLE BEBAND THE BALL TO WRRIKE BEY BEALEN BEJORED HERTALL WITING AND AND THE SALL AND THE WM ALL THE SANDER THE AN THE AN THE BEWALL THE FMAALD EVERN WITHND THE BEN THE SALL FOR THAT SEARING THE AN THE BAGT AND TING AND UUT SUICING AND THE SRRRTER THE FOR WITH TAS AND AND AND THE FMARASALE THE FOR THE BEAR AND THE BBBAND OT WOALD THE ON THHALK FOR QCET THE ABBRGMON THE AN FOR THE GANG WALL BEAN SITTING WERVER WOTERTERE THE AN THE AN THE LAR T
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-a66789ef7460> in <module>
#      27                 print("                          Backprop: " + str(network.backprop(e*len(data) + i + 1)))
#      28             else:
# ---> 29                 network.backprop(e*len(data) + i + 1)
#      30     if e % plotRate == 0:
#      31         plt.figure(figsize=(12, 6))
#
# <ipython-input-70-a7ef0615ed0a> in backprop(self, iteration)
#      28         grad = (self.ERRORDER / self.batchSize) * self.layers[-1].H[-1]
#      29         for i in range(1, len(self.layers)+1):
# ---> 30             grad = self.layers[-i].backprop(grad, iteration+1)
#      31
#      32         errToReturn = self.ERROR / self.batchSize
#
# <ipython-input-69-293787315f4a> in backprop(self, grad, iteration)
#     208
#     209             dHt = d12 + d14 + d1 + d17
# --> 210             dWxr += d16 @ self.X[t].T
#     211             dWxz += d7 @ self.X[t].T
#     212             dWxh += d8 @ self.X[t].T
#
# KeyboardInterrupt:
