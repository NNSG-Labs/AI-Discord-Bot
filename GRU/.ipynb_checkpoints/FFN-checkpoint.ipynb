# %%
import numpy as np

# %%
def activate(x, func):
    if func == "tanh":
        return np.tanh(x)
    
    elif func == "sigmoid":
        return 1.0/(1.0+np.exp(-x))
    
    elif func == "none":
        return x
    
    else:
        return None
    
    
    
def activateDer(x, func):
    if func == "tanh":
        return 1 - x**2
    
    elif func == "sigmoid":
        return x*(1-x)
    
    elif func == "none":
        return np.ones(x.shape)
    
    else:
        return np.zeros(x.shape)
    
    
    
def MSE_der(tar, x):
    return 2*(x-tar)

def MSE(tar, x):
    return (x-tar)**2

# %%
class Layer:
    
    def __init__(self, inp, out, act, lr):
        self.activation = act
        self.inputs = inp
        self.outputs = out
        self.learnRate = lr
        
        self.Wx = np.random.rand(self.outputs, self.inputs) * 2 - 1
        self.Wb = np.random.rand(self.outputs, 1) * 2 - 1
        self.A = np.zeros((self.outputs, 1))
        self.X = np.zeros((self.inputs, 1))
        
    def forwardPass(self, inp):
        self.X = inp
        self.Z = self.Wx @ inp + self.Wb
        self.A = activate(self.Z, self.activation)
        return self.A
    
    def backprop(self, grad):
        dEdA = grad
        dAdZ = activateDer(self.A, self.activation)
        dZdWx = self.X.T
        
        dEdZ = dEdA * dAdZ
        
        dEdWx = dEdZ @ dZdWx
        dEdX = self.Wx.T @ dEdZ
        dEdWb = dEdZ
        
        self.Wx = self.Wx - self.learnRate * dEdWx
        self.Wb = self.Wb - self.learnRate * dEdWb
        
        #dEdWb
        return dEdX

# %%
class Network:
    
    def __init__(self, bs, lr):
        self.layers = []
        self.batchSize = bs
        self.learnRate = lr
        
    
    def addLayer(self, inp, out, act):
        layer = Layer(inp, out, act, self.learnRate)
        self.layers.append(layer)
        self.ERROR = np.zeros((out,1))
        self.ERRORDER = np.zeros((out,1))
        
    def forwardPass(self, inp):
        self.layers[0].forwardPass(inp)
        for l in range(1, len(self.layers)):
            self.layers[l].forwardPass(self.layers[l-1].A)
        return self.layers[-1].A
    
    def error(self, ans):
        self.ERROR += MSE(ans, self.layers[-1].A)
        self.ERRORDER += MSE_der(ans, self.layers[-1].A)
    
    def backprop(self):
        grad = self.ERRORDER / self.batchSize
        for i in range(1, len(self.layers)+1):
            grad = self.layers[-i].backprop(grad)
            
        errToReturn = self.ERROR / self.batchSize
        self.ERROR.fill(0)
        self.ERRORDER.fill(0)
        return errToReturn

# %%
data = np.array([
    [[1],[-2],[0]],
    [[0],[2],[3]],
    [[5],[2],[-3]],
    [[-1],[0],[3]],
    [[-1],[2],[3]],
    [[1],[-2],[0]],
    [[-2],[3],[2]],
    [[2],[-1],[-1]],
    [[-2],[2],[-3]]
])

ans = np.array([
    [[-1]],
    [[5]],
    [[4]],
    [[2]],
    [[4]],
    [[-1]],
    [[3]],
    [[0]],
    [[-3]]
])

# %%
batchSize = 1
epochs = 1000
learnRate = 0.001
network = Network(batchSize, learnRate)
network.addLayer(3, 8, "sigmoid")
network.addLayer(8, 5, "tanh")
network.addLayer(5, 1, "none")

for e in range(0, epochs):
    for i in range(0, len(data)):
        print("EPOCH " + str(e) + " , SAMPLE " + str(i) + "-----------------")
        print("Forward pass:" + str(network.forwardPass(data[i])))
        print("Truth: " + str(ans[i]))
        network.error(ans[i])
        if (e*len(data) + i + 1) % batchSize == 0:
            print("                          Backprop: " + str(network.backprop()))
# Out:
# EPOCH 0 , SAMPLE 0-----------------
# Forward pass:[[-0.09474255]]
# Truth: [[-1]]
#                           Backprop: [[0.81949106]]
# EPOCH 0 , SAMPLE 1-----------------
# Forward pass:[[-0.30747865]]
# Truth: [[5]]
#                           Backprop: [[28.16932964]]
# EPOCH 0 , SAMPLE 2-----------------
# Forward pass:[[-0.29536108]]
# Truth: [[4]]
#                           Backprop: [[18.45012677]]
# EPOCH 0 , SAMPLE 3-----------------
# Forward pass:[[0.0012965]]
# Truth: [[2]]
#                           Backprop: [[3.99481568]]
# EPOCH 0 , SAMPLE 4-----------------
# Forward pass:[[-0.10803413]]
# Truth: [[4]]
#                           Backprop: [[16.87594439]]
# EPOCH 0 , SAMPLE 5-----------------
# Forward pass:[[-0.02349458]]
# Truth: [[-1]]
#                           Backprop: [[0.95356283]]
# EPOCH 0 , SAMPLE 6-----------------
# Forward pass:[[-0.09095196]]
# Truth: [[3]]
#                           Backprop: [[9.55398401]]
# EPOCH 0 , SAMPLE 7-----------------
# Forward pass:[[-0.21593251]]
# Truth: [[0]]
#                           Backprop: [[0.04662685]]
# EPOCH 0 , SAMPLE 8-----------------
# Forward pass:[[-0.14504381]]
# Truth: [[-3]]
#                           Backprop: [[8.15077486]]
# EPOCH 1 , SAMPLE 0-----------------
# Forward pass:[[-0.02899678]]
# Truth: [[-1]]
#                           Backprop: [[0.94284725]]
# EPOCH 1 , SAMPLE 1-----------------
# Forward pass:[[-0.18949078]]
# Truth: [[5]]
#                           Backprop: [[26.9308146]]
# EPOCH 1 , SAMPLE 2-----------------
# Forward pass:[[-0.20709972]]
# Truth: [[4]]
#                           Backprop: [[17.69968802]]
# EPOCH 1 , SAMPLE 3-----------------
# Forward pass:[[0.1004177]]
# Truth: [[2]]
#                           Backprop: [[3.60841292]]
# EPOCH 1 , SAMPLE 4-----------------
# Forward pass:[[0.00265894]]
# Truth: [[4]]
#                           Backprop: [[15.97873553]]
# EPOCH 1 , SAMPLE 5-----------------
# Forward pass:[[0.0385991]]
# Truth: [[-1]]
#                           Backprop: [[1.0786881]]
# EPOCH 1 , SAMPLE 6-----------------
# Forward pass:[[0.01209287]]
# Truth: [[3]]
#                           Backprop: [[8.92758905]]
# EPOCH 1 , SAMPLE 7-----------------
# Forward pass:[[-0.14494253]]
# Truth: [[0]]
#                           Backprop: [[0.02100834]]
# EPOCH 1 , SAMPLE 8-----------------
# Forward pass:[[-0.0756955]]
# Truth: [[-3]]
#                           Backprop: [[8.5515568]]
# EPOCH 2 , SAMPLE 0-----------------
# Forward pass:[[0.03135246]]
# Truth: [[-1]]
#                           Backprop: [[1.06368789]]
# EPOCH 2 , SAMPLE 1-----------------
# Forward pass:[[-0.07938136]]
# Truth: [[5]]
#                           Backprop: [[25.80011501]]
# EPOCH 2 , SAMPLE 2-----------------
# Forward pass:[[-0.12610793]]
# Truth: [[4]]
#                           Backprop: [[17.02476661]]
# EPOCH 2 , SAMPLE 3-----------------
# Forward pass:[[0.19230054]]
# Truth: [[2]]
#                           Backprop: [[3.26777735]]
# EPOCH 2 , SAMPLE 4-----------------
# Forward pass:[[0.10557462]]
# Truth: [[4]]
#                           Backprop: [[15.16654904]]
# EPOCH 2 , SAMPLE 5-----------------
# Forward pass:[[0.09571142]]
# Truth: [[-1]]
#                           Backprop: [[1.20058351]]
# EPOCH 2 , SAMPLE 6-----------------
# Forward pass:[[0.1076459]]
# Truth: [[3]]
#                           Backprop: [[8.36571223]]
# EPOCH 2 , SAMPLE 7-----------------
# Forward pass:[[-0.0798575]]
# Truth: [[0]]
#                           Backprop: [[0.00637722]]
# EPOCH 2 , SAMPLE 8-----------------
# Forward pass:[[-0.01180202]]
# Truth: [[-3]]
#                           Backprop: [[8.92932715]]
# EPOCH 3 , SAMPLE 0-----------------
# Forward pass:[[0.08689143]]
# Truth: [[-1]]
#                           Backprop: [[1.18133297]]
# EPOCH 3 , SAMPLE 1-----------------
# Forward pass:[[0.02373956]]
# Truth: [[5]]
#                           Backprop: [[24.76316795]]
# EPOCH 3 , SAMPLE 2-----------------
# Forward pass:[[-0.05144661]]
# Truth: [[4]]
#                           Backprop: [[16.41421964]]
# EPOCH 3 , SAMPLE 3-----------------
# Forward pass:[[0.27788952]]
# Truth: [[2]]
#                           Backprop: [[2.96566451]]
# EPOCH 3 , SAMPLE 4-----------------
# Forward pass:[[0.20166137]]
# Truth: [[4]]
#                           Backprop: [[14.42737633]]
# EPOCH 3 , SAMPLE 5-----------------
# Forward pass:[[0.1483716]]
# Truth: [[-1]]
#                           Backprop: [[1.31875732]]
# EPOCH 3 , SAMPLE 6-----------------
# Forward pass:[[0.19665184]]
# Truth: [[3]]
#                           Backprop: [[7.85876089]]
# EPOCH 3 , SAMPLE 7-----------------
# Forward pass:[[-0.02004496]]
# Truth: [[0]]
#                           Backprop: [[0.0004018]]
# EPOCH 3 , SAMPLE 8-----------------
# Forward pass:[[0.04717699]]
# Truth: [[-3]]
#                           Backprop: [[9.28528763]]
# EPOCH 4 , SAMPLE 0-----------------
# Forward pass:[[0.13812177]]
# Truth: [[-1]]
#                           Backprop: [[1.29532117]]
# EPOCH 4 , SAMPLE 1-----------------
# Forward pass:[[0.12065505]]
# Truth: [[5]]
#                           Backprop: [[23.80800718]]
# EPOCH 4 , SAMPLE 2-----------------
# Forward pass:[[0.0177017]]
# Truth: [[4]]
#                           Backprop: [[15.85869974]]
# EPOCH 4 , SAMPLE 3-----------------
# Forward pass:[[0.35798728]]
# Truth: [[2]]
#                           Backprop: [[2.69620578]]
# EPOCH 4 , SAMPLE 4-----------------
# Forward pass:[[0.29174366]]
# Truth: [[4]]
#                           Backprop: [[13.75116509]]
# EPOCH 4 , SAMPLE 5-----------------
# Forward pass:[[0.19703276]]
# Truth: [[-1]]
#                           Backprop: [[1.43288742]]
# EPOCH 4 , SAMPLE 6-----------------
# Forward pass:[[0.27992266]]
# Truth: [[3]]
#                           Backprop: [[7.39882074]]
# EPOCH 4 , SAMPLE 7-----------------
# Forward pass:[[0.03504579]]
# Truth: [[0]]
#                           Backprop: [[0.00122821]]
# EPOCH 4 , SAMPLE 8-----------------
# Forward pass:[[0.1017072]]
# Truth: [[-3]]
#                           Backprop: [[9.62058757]]
# EPOCH 5 , SAMPLE 0-----------------
# Forward pass:[[0.18547361]]
# Truth: [[-1]]
#                           Backprop: [[1.40534768]]
# EPOCH 5 , SAMPLE 1-----------------
# Forward pass:[[0.21205023]]
# Truth: [[5]]
#                           Backprop: [[22.92446303]]
# EPOCH 5 , SAMPLE 2-----------------
# Forward pass:[[0.08204895]]
# Truth: [[4]]
#                           Backprop: [[15.35034047]]
# EPOCH 5 , SAMPLE 3-----------------
# Forward pass:[[0.43327303]]
# Truth: [[2]]
#                           Backprop: [[2.45463339]]
# EPOCH 5 , SAMPLE 4-----------------
# Forward pass:[[0.37653288]]
# Truth: [[4]]
#                           Backprop: [[13.12951398]]
# EPOCH 5 , SAMPLE 5-----------------
# Forward pass:[[0.24208372]]
# Truth: [[-1]]
#                           Backprop: [[1.54277197]]
# EPOCH 5 , SAMPLE 6-----------------
# Forward pass:[[0.35815186]]
# Truth: [[3]]
#                           Backprop: [[6.97936158]]
# EPOCH 5 , SAMPLE 7-----------------
# Forward pass:[[0.08589486]]
# Truth: [[0]]
#                           Backprop: [[0.00737793]]
# EPOCH 5 , SAMPLE 8-----------------
# Forward pass:[[0.15219028]]
# Truth: [[-3]]
#                           Backprop: [[9.93630357]]
# EPOCH 6 , SAMPLE 0-----------------
# Forward pass:[[0.22931647]]
# Truth: [[-1]]
#                           Backprop: [[1.51121898]]
# EPOCH 6 , SAMPLE 1-----------------
# Forward pass:[[0.29852187]]
# Truth: [[5]]
#                           Backprop: [[22.10389656]]
# EPOCH 6 , SAMPLE 2-----------------
# Forward pass:[[0.14221567]]
# Truth: [[4]]
#                           Backprop: [[14.88249991]]
# EPOCH 6 , SAMPLE 3-----------------
# Forward pass:[[0.50432017]]
# Truth: [[2]]
#                           Backprop: [[2.23705814]]
# EPOCH 6 , SAMPLE 4-----------------
# Forward pass:[[0.45663969]]
# Truth: [[4]]
#                           Backprop: [[12.55540228]]
# EPOCH 6 , SAMPLE 5-----------------
# Forward pass:[[0.28385886]]
# Truth: [[-1]]
#                           Backprop: [[1.64829357]]
# EPOCH 6 , SAMPLE 6-----------------
# Forward pass:[[0.43192942]]
# Truth: [[3]]
#                           Backprop: [[6.59498652]]
# EPOCH 6 , SAMPLE 7-----------------
# Forward pass:[[0.13292149]]
# Truth: [[0]]
#                           Backprop: [[0.01766812]]
# EPOCH 6 , SAMPLE 8-----------------
# Forward pass:[[0.19897311]]
# Truth: [[-3]]
#                           Backprop: [[10.23342893]]
# EPOCH 7 , SAMPLE 0-----------------
# Forward pass:[[0.26996845]]
# Truth: [[-1]]
#                           Backprop: [[1.61281987]]
# EPOCH 7 , SAMPLE 1-----------------
# Forward pass:[[0.38058811]]
# Truth: [[5]]
#                           Backprop: [[21.33896621]]
# EPOCH 7 , SAMPLE 2-----------------
# Forward pass:[[0.19874335]]
# Truth: [[4]]
#                           Backprop: [[14.44955211]]
# EPOCH 7 , SAMPLE 3-----------------
# Forward pass:[[0.57161234]]
# Truth: [[2]]
#                           Backprop: [[2.04029132]]
# EPOCH 7 , SAMPLE 4-----------------
# Forward pass:[[0.53258662]]
# Truth: [[4]]
#                           Backprop: [[12.02295554]]
# EPOCH 7 , SAMPLE 5-----------------
# Forward pass:[[0.32264628]]
# Truth: [[-1]]
#                           Backprop: [[1.74939317]]
# EPOCH 7 , SAMPLE 6-----------------
# Forward pass:[[0.5017562]]
# Truth: [[3]]
#                           Backprop: [[6.24122209]]
# EPOCH 7 , SAMPLE 7-----------------
# Forward pass:[[0.17649222]]
# Truth: [[0]]
#                           Backprop: [[0.0311495]]
# EPOCH 7 , SAMPLE 8-----------------
# Forward pass:[[0.24235556]]
# Truth: [[-3]]
#                           Backprop: [[10.51286955]]
# EPOCH 8 , SAMPLE 0-----------------
# Forward pass:[[0.30770391]]
# Truth: [[-1]]
#                           Backprop: [[1.71008952]]
# EPOCH 8 , SAMPLE 1-----------------
# Forward pass:[[0.45869789]]
# Truth: [[5]]
#                           Backprop: [[20.62342488]]
# EPOCH 8 , SAMPLE 2-----------------
# Forward pass:[[0.25210493]]
# Truth: [[4]]
#                           Backprop: [[14.04671743]]
# EPOCH 8 , SAMPLE 3-----------------
# Forward pass:[[0.63555769]]
# Truth: [[2]]
#                           Backprop: [[1.86170282]]
# EPOCH 8 , SAMPLE 4-----------------
# Forward pass:[[0.60482017]]
# Truth: [[4]]
#                           Backprop: [[11.5272461]]
# EPOCH 8 , SAMPLE 5-----------------
# Forward pass:[[0.35869466]]
# Truth: [[-1]]
#                           Backprop: [[1.84605118]]
# EPOCH 8 , SAMPLE 6-----------------
# Forward pass:[[0.56805737]]
# Truth: [[3]]
#                           Backprop: [[5.91434497]]
# EPOCH 8 , SAMPLE 7-----------------
# Forward pass:[[0.21692789]]
# Truth: [[0]]
#                           Backprop: [[0.04705771]]
# EPOCH 8 , SAMPLE 8-----------------
# Forward pass:[[0.28259714]]
# Truth: [[-3]]
#                           Backprop: [[10.77544398]]
# EPOCH 9 , SAMPLE 0-----------------
# Forward pass:[[0.34275984]]
# Truth: [[-1]]
#                           Backprop: [[1.80300399]]
# EPOCH 9 , SAMPLE 1-----------------
# Forward pass:[[0.53323995]]
# Truth: [[5]]
#                           Backprop: [[19.95194536]]
# EPOCH 9 , SAMPLE 2-----------------
# Forward pass:[[0.30271389]]
# Truth: [[4]]
#                           Backprop: [[13.66992455]]
# EPOCH 9 , SAMPLE 3-----------------
# Forward pass:[[0.69650135]]
# Truth: [[2]]
#                           Backprop: [[1.69910872]]
# EPOCH 9 , SAMPLE 4-----------------
# Forward pass:[[0.67372197]]
# Truth: [[4]]
#                           Backprop: [[11.06412556]]
# EPOCH 9 , SAMPLE 5-----------------
# Forward pass:[[0.39221901]]
# Truth: [[-1]]
#                           Backprop: [[1.93827378]]
# EPOCH 9 , SAMPLE 6-----------------
# Forward pass:[[0.63119435]]
# Truth: [[3]]
#                           Backprop: [[5.61124019]]
# EPOCH 9 , SAMPLE 7-----------------
# Forward pass:[[0.25450964]]
# Truth: [[0]]
#                           Backprop: [[0.06477516]]
# EPOCH 9 , SAMPLE 8-----------------
# Forward pass:[[0.31992264]]
# Truth: [[-3]]
#                           Backprop: [[11.02188635]]
# EPOCH 10 , SAMPLE 0-----------------
# Forward pass:[[0.37534128]]
# Truth: [[-1]]
#                           Backprop: [[1.89156364]]
# EPOCH 10 , SAMPLE 1-----------------
# Forward pass:[[0.60455106]]
# Truth: [[5]]
#                           Backprop: [[19.31997139]]
# EPOCH 10 , SAMPLE 2-----------------
# Forward pass:[[0.35093193]]
# Truth: [[4]]
#                           Backprop: [[13.3156978]]
# EPOCH 10 , SAMPLE 3-----------------
# Forward pass:[[0.75473605]]
# Truth: [[2]]
#                           Backprop: [[1.5506823]]
# EPOCH 10 , SAMPLE 4-----------------
# Forward pass:[[0.73961879]]
# Truth: [[4]]
#                           Backprop: [[10.63008566]]
# EPOCH 10 , SAMPLE 5-----------------
# Forward pass:[[0.42340542]]
# Truth: [[-1]]
#                           Backprop: [[2.026083]]
# EPOCH 10 , SAMPLE 6-----------------
# Forward pass:[[0.69147534]]
# Truth: [[3]]
#                           Backprop: [[5.32928608]]
# EPOCH 10 , SAMPLE 7-----------------
# Forward pass:[[0.28948401]]
# Truth: [[0]]
#                           Backprop: [[0.08380099]]
# EPOCH 10 , SAMPLE 8-----------------
# Forward pass:[[0.35452694]]
# Truth: [[-3]]
#                           Backprop: [[11.25285096]]
# EPOCH 11 , SAMPLE 0-----------------
# Forward pass:[[0.40562583]]
# Truth: [[-1]]
#                           Backprop: [[1.97578397]]
# EPOCH 11 , SAMPLE 1-----------------
# Forward pass:[[0.67292342]]
# Truth: [[5]]
#                           Backprop: [[18.7235917]]
# EPOCH 11 , SAMPLE 2-----------------
# Forward pass:[[0.39707549]]
# Truth: [[4]]
#                           Backprop: [[12.981065]]
# EPOCH 11 , SAMPLE 3-----------------
# Forward pass:[[0.81051108]]
# Truth: [[2]]
#                           Backprop: [[1.41488388]]
# EPOCH 11 , SAMPLE 4-----------------
# Forward pass:[[0.80279126]]
# Truth: [[4]]
#                           Backprop: [[10.22214371]]
# EPOCH 11 , SAMPLE 5-----------------
# Forward pass:[[0.45241513]]
# Truth: [[-1]]
#                           Backprop: [[2.10950972]]
# EPOCH 11 , SAMPLE 6-----------------
# Forward pass:[[0.7491643]]
# Truth: [[3]]
#                           Backprop: [[5.06626136]]
# EPOCH 11 , SAMPLE 7-----------------
# Forward pass:[[0.32206723]]
# Truth: [[0]]
#                           Backprop: [[0.1037273]]
# EPOCH 11 , SAMPLE 8-----------------
# Forward pass:[[0.3865791]]
# Truth: [[-3]]
#                           Backprop: [[11.46891797]]
# EPOCH 12 , SAMPLE 0-----------------
# Forward pass:[[0.43376747]]
# Truth: [[-1]]
#                           Backprop: [[2.05568915]]
# EPOCH 12 , SAMPLE 1-----------------
# Forward pass:[[0.73861122]]
# Truth: [[5]]
#                           Backprop: [[18.1594343]]
# EPOCH 12 , SAMPLE 2-----------------
# Forward pass:[[0.4414214]]
# Truth: [[4]]
#                           Backprop: [[12.66348166]]
# EPOCH 12 , SAMPLE 3-----------------
# Forward pass:[[0.86403988]]
# Truth: [[2]]
#                           Backprop: [[1.29040538]]
# EPOCH 12 , SAMPLE 4-----------------
# Forward pass:[[0.8634814]]
# Truth: [[4]]
#                           Backprop: [[9.83774894]]
# EPOCH 12 , SAMPLE 5-----------------
# Forward pass:[[0.47938794]]
# Truth: [[-1]]
#                           Backprop: [[2.18858869]]
# EPOCH 12 , SAMPLE 6-----------------
# Forward pass:[[0.80448856]]
# Truth: [[3]]
#                           Backprop: [[4.82027046]]
# EPOCH 12 , SAMPLE 7-----------------
# Forward pass:[[0.35244902]]
# Truth: [[0]]
#                           Backprop: [[0.12422031]]
# EPOCH 12 , SAMPLE 8-----------------
# Forward pass:[[0.41622594]]
# Truth: [[-3]]
#                           Backprop: [[11.67059965]]
# EPOCH 13 , SAMPLE 0-----------------
# Forward pass:[[0.45989981]]
# Truth: [[-1]]
#                           Backprop: [[2.13130745]]
# EPOCH 13 , SAMPLE 1-----------------
# Forward pass:[[0.80183632]]
# Truth: [[5]]
#                           Backprop: [[17.6245783]]
# EPOCH 13 , SAMPLE 2-----------------
# Forward pass:[[0.48421155]]
# Truth: [[4]]
#                           Backprop: [[12.36076843]]
# EPOCH 13 , SAMPLE 3-----------------
# Forward pass:[[0.91550626]]
# Truth: [[2]]
#                           Backprop: [[1.17612667]]
# EPOCH 13 , SAMPLE 4-----------------
# Forward pass:[[0.9218989]]
# Truth: [[4]]
#                           Backprop: [[9.47470637]]
# EPOCH 13 , SAMPLE 5-----------------
# Forward pass:[[0.5044451]]
# Truth: [[-1]]
#                           Backprop: [[2.26335506]]
# EPOCH 13 , SAMPLE 6-----------------
# Forward pass:[[0.85764527]]
# Truth: [[3]]
#                           Backprop: [[4.58968378]]
# EPOCH 13 , SAMPLE 7-----------------
# Forward pass:[[0.38079575]]
# Truth: [[0]]
#                           Backprop: [[0.14500541]]
# EPOCH 13 , SAMPLE 8-----------------
# Forward pass:[[0.44359505]]
# Truth: [[-3]]
#                           Backprop: [[11.85834688]]
# EPOCH 14 , SAMPLE 0-----------------
# Forward pass:[[0.48413883]]
# Truth: [[-1]]
#                           Backprop: [[2.20266806]]
# EPOCH 14 , SAMPLE 1-----------------
# Forward pass:[[0.86279312]]
# Truth: [[5]]
#                           Backprop: [[17.11648075]]
# EPOCH 14 , SAMPLE 2-----------------
# Forward pass:[[0.52565702]]
# Truth: [[4]]
#                           Backprop: [[12.07105912]]
# EPOCH 14 , SAMPLE 3-----------------
# Forward pass:[[0.96506956]]
# Truth: [[2]]
#                           Backprop: [[1.07108102]]
# EPOCH 14 , SAMPLE 4-----------------
# Forward pass:[[0.9782265]]
# Truth: [[4]]
#                           Backprop: [[9.13111507]]
# EPOCH 14 , SAMPLE 5-----------------
# Forward pass:[[0.52769177]]
# Truth: [[-1]]
#                           Backprop: [[2.33384215]]
# EPOCH 14 , SAMPLE 6-----------------
# Forward pass:[[0.90880659]]
# Truth: [[3]]
#                           Backprop: [[4.37308988]]
# EPOCH 14 , SAMPLE 7-----------------
# Forward pass:[[0.40725321]]
# Truth: [[0]]
#                           Backprop: [[0.16585517]]
# EPOCH 14 , SAMPLE 8-----------------
# Forward pass:[[0.46879745]]
# Truth: [[-3]]
#                           Backprop: [[12.03255572]]
# EPOCH 15 , SAMPLE 0-----------------
# Forward pass:[[0.50658521]]
# Truth: [[-1]]
#                           Backprop: [[2.269799]]
# EPOCH 15 , SAMPLE 1-----------------
# Forward pass:[[0.92165275]]
# Truth: [[5]]
#                           Backprop: [[16.63291631]]
# EPOCH 15 , SAMPLE 2-----------------
# Forward pass:[[0.56594157]]
# Truth: [[4]]
#                           Backprop: [[11.79275727]]
# EPOCH 15 , SAMPLE 3-----------------
# Forward pass:[[1.01286887]]
# Truth: [[2]]
#                           Backprop: [[0.97442787]]
# EPOCH 15 , SAMPLE 4-----------------
# Forward pass:[[1.03262433]]
# Truth: [[4]]
#                           Backprop: [[8.80531837]]
# EPOCH 15 , SAMPLE 5-----------------
# Forward pass:[[0.54921914]]
# Truth: [[-1]]
#                           Backprop: [[2.40007996]]
# EPOCH 15 , SAMPLE 6-----------------
# Forward pass:[[0.95812404]]
# Truth: [[3]]
#                           Backprop: [[4.16925743]]
# EPOCH 15 , SAMPLE 7-----------------
# Forward pass:[[0.43194897]]
# Truth: [[0]]
#                           Backprop: [[0.18657991]]
# EPOCH 15 , SAMPLE 8-----------------
# Forward pass:[[0.49192979]]
# Truth: [[-3]]
#                           Backprop: [[12.19357368]]
# EPOCH 16 , SAMPLE 0-----------------
# Forward pass:[[0.52732636]]
# Truth: [[-1]]
#                           Backprop: [[2.33272582]]
# EPOCH 16 , SAMPLE 1-----------------
# Forward pass:[[0.97856649]]
# Truth: [[5]]
#                           Backprop: [[16.17192744]]
# EPOCH 16 , SAMPLE 2-----------------
# Forward pass:[[0.60522465]]
# Truth: [[4]]
#                           Backprop: [[11.52449967]]
# EPOCH 16 , SAMPLE 3-----------------
# Forward pass:[[1.05902646]]
# Truth: [[2]]
#                           Backprop: [[0.8854312]]
# EPOCH 16 , SAMPLE 4-----------------
# Forward pass:[[1.08523352]]
# Truth: [[4]]
#                           Backprop: [[8.49586364]]
# EPOCH 16 , SAMPLE 5-----------------
# Forward pass:[[0.56910624]]
# Truth: [[-1]]
#                           Backprop: [[2.46209439]]
# EPOCH 16 , SAMPLE 6-----------------
# Forward pass:[[1.005732]]
# Truth: [[3]]
#                           Backprop: [[3.97710486]]
# EPOCH 16 , SAMPLE 7-----------------
# Forward pass:[[0.4549945]]
# Truth: [[0]]
#                           Backprop: [[0.20701999]]
# EPOCH 16 , SAMPLE 8-----------------
# Forward pass:[[0.51307642]]
# Truth: [[-3]]
#                           Backprop: [[12.34170592]]
# EPOCH 17 , SAMPLE 0-----------------
# Forward pass:[[0.54643814]]
# Truth: [[-1]]
#                           Backprop: [[2.39147091]]
# EPOCH 17 , SAMPLE 1-----------------
# Forward pass:[[1.03366875]]
# Truth: [[5]]
#                           Backprop: [[15.73178359]]
# EPOCH 17 , SAMPLE 2-----------------
# Forward pass:[[0.64364403]]
# Truth: [[4]]
#                           Backprop: [[11.26512542]]
# EPOCH 17 , SAMPLE 3-----------------
# Forward pass:[[1.10365057]]
# Truth: [[2]]
#                           Backprop: [[0.8034423]]
# EPOCH 17 , SAMPLE 4-----------------
# Forward pass:[[1.13617915]]
# Truth: [[4]]
#                           Backprop: [[8.20146984]]
# EPOCH 17 , SAMPLE 5-----------------
# Forward pass:[[0.58742146]]
# Truth: [[-1]]
#                           Backprop: [[2.5199069]]
# EPOCH 17 , SAMPLE 6-----------------
# Forward pass:[[1.05175049]]
# Truth: [[3]]
#                           Backprop: [[3.79567616]]
# EPOCH 17 , SAMPLE 7-----------------
# Forward pass:[[0.47648695]]
# Truth: [[0]]
#                           Backprop: [[0.22703981]]
# EPOCH 17 , SAMPLE 8-----------------
# Forward pass:[[0.53231099]]
# Truth: [[-3]]
#                           Backprop: [[12.47722091]]
# EPOCH 18 , SAMPLE 0-----------------
# Forward pass:[[0.5639863]]
# Truth: [[-1]]
#                           Backprop: [[2.44605313]]
# EPOCH 18 , SAMPLE 1-----------------
# Forward pass:[[1.08707941]]
# Truth: [[5]]
#                           Backprop: [[15.31094753]]
# EPOCH 18 , SAMPLE 2-----------------
# Forward pass:[[0.68131809]]
# Truth: [[4]]
#                           Backprop: [[11.01364959]]
# EPOCH 18 , SAMPLE 3-----------------
# Forward pass:[[1.14683762]]
# Truth: [[2]]
#                           Backprop: [[0.72788605]]
# EPOCH 18 , SAMPLE 4-----------------
# Forward pass:[[1.18557266]]
# Truth: [[4]]
#                           Backprop: [[7.92100128]]
# EPOCH 18 , SAMPLE 5-----------------
# Forward pass:[[0.60422396]]
# Truth: [[-1]]
#                           Backprop: [[2.57353452]]
# EPOCH 18 , SAMPLE 6-----------------
# Forward pass:[[1.09628742]]
# Truth: [[3]]
#                           Backprop: [[3.6241216]]
# EPOCH 18 , SAMPLE 7-----------------
# Forward pass:[[0.49651074]]
# Truth: [[0]]
#                           Backprop: [[0.24652291]]
# EPOCH 18 , SAMPLE 8-----------------
# Forward pass:[[0.549698]]
# Truth: [[-3]]
#                           Backprop: [[12.60035589]]
# EPOCH 19 , SAMPLE 0-----------------
# Forward pass:[[0.58002783]]
# Truth: [[-1]]
#                           Backprop: [[2.49648794]]
# EPOCH 19 , SAMPLE 1-----------------
# Forward pass:[[1.1389059]]
# Truth: [[5]]
#                           Backprop: [[14.90804768]]
# EPOCH 19 , SAMPLE 2-----------------
# Forward pass:[[0.71834791]]
# Truth: [[4]]
#                           Backprop: [[10.76924045]]
# EPOCH 19 , SAMPLE 3-----------------
# Forward pass:[[1.18867403]]
# Truth: [[2]]
#                           Backprop: [[0.65824984]]
# EPOCH 19 , SAMPLE 4-----------------
# Forward pass:[[1.23351374]]
# Truth: [[4]]
#                           Backprop: [[7.65344625]]
# EPOCH 19 , SAMPLE 5-----------------
# Forward pass:[[0.6195648]]
# Truth: [[-1]]
#                           Backprop: [[2.62299013]]
# EPOCH 19 , SAMPLE 6-----------------
# Forward pass:[[1.13944036]]
# Truth: [[3]]
#                           Backprop: [[3.46168216]]
# EPOCH 19 , SAMPLE 7-----------------
# Forward pass:[[0.51513898]]
# Truth: [[0]]
#                           Backprop: [[0.26536817]]
# EPOCH 19 , SAMPLE 8-----------------
# Forward pass:[[0.56529408]]
# Truth: [[-3]]
#                           Backprop: [[12.71132187]]
# EPOCH 20 , SAMPLE 0-----------------
# Forward pass:[[0.59461207]]
# Truth: [[-1]]
#                           Backprop: [[2.54278764]]
# EPOCH 20 , SAMPLE 1-----------------
# Forward pass:[[1.18924481]]
# Truth: [[5]]
#                           Backprop: [[14.52185511]]
# EPOCH 20 , SAMPLE 2-----------------
# Forward pass:[[0.754819]]
# Truth: [[4]]
#                           Backprop: [[10.53119975]]
# EPOCH 20 , SAMPLE 3-----------------
# Forward pass:[[1.22923766]]
# Truth: [[2]]
#                           Backprop: [[0.59407459]]
# EPOCH 20 , SAMPLE 4-----------------
# Forward pass:[[1.28009198]]
# Truth: [[4]]
#                           Backprop: [[7.39789962]]
# EPOCH 20 , SAMPLE 5-----------------
# Forward pass:[[0.63348798]]
# Truth: [[-1]]
#                           Backprop: [[2.66828297]]
# EPOCH 20 , SAMPLE 6-----------------
# Forward pass:[[1.18129799]]
# Truth: [[3]]
#                           Backprop: [[3.30767702]]
# EPOCH 20 , SAMPLE 7-----------------
# Forward pass:[[0.53243472]]
# Truth: [[0]]
#                           Backprop: [[0.28348673]]
# EPOCH 20 , SAMPLE 8-----------------
# Forward pass:[[0.5791491]]
# Truth: [[-3]]
#                           Backprop: [[12.81030829]]
# EPOCH 21 , SAMPLE 0-----------------
# Forward pass:[[0.60778167]]
# Truth: [[-1]]
#                           Backprop: [[2.58496189]]
# EPOCH 21 , SAMPLE 1-----------------
# Forward pass:[[1.23818335]]
# Truth: [[5]]
#                           Backprop: [[14.1512645]]
# EPOCH 21 , SAMPLE 2-----------------
# Forward pass:[[0.79080299]]
# Truth: [[4]]
#                           Backprop: [[10.29894547]]
# EPOCH 21 , SAMPLE 3-----------------
# Forward pass:[[1.268599]]
# Truth: [[2]]
#                           Backprop: [[0.53494743]]
# EPOCH 21 , SAMPLE 4-----------------
# Forward pass:[[1.32538817]]
# Truth: [[4]]
#                           Backprop: [[7.15354842]]
# EPOCH 21 , SAMPLE 5-----------------
# Forward pass:[[0.64603138]]
# Truth: [[-1]]
#                           Backprop: [[2.70941932]]
# EPOCH 21 , SAMPLE 6-----------------
# Forward pass:[[1.22194114]]
# Truth: [[3]]
#                           Backprop: [[3.1614933]]
# EPOCH 21 , SAMPLE 7-----------------
# Forward pass:[[0.54845207]]
# Truth: [[0]]
#                           Backprop: [[0.30079968]]
# EPOCH 21 , SAMPLE 8-----------------
# Forward pass:[[0.5913072]]
# Truth: [[-3]]
#                           Backprop: [[12.8974874]]
# EPOCH 22 , SAMPLE 0-----------------
# Forward pass:[[0.6195735]]
# Truth: [[-1]]
#                           Backprop: [[2.62301833]]
# EPOCH 22 , SAMPLE 1-----------------
# Forward pass:[[1.28580048]]
# Truth: [[5]]
#                           Backprop: [[13.79527804]]
# EPOCH 22 , SAMPLE 2-----------------
# Forward pass:[[0.82635912]]
# Truth: [[4]]
#                           Backprop: [[10.07199642]]
# EPOCH 22 , SAMPLE 3-----------------
# Forward pass:[[1.30682212]]
# Truth: [[2]]
#                           Backprop: [[0.48049558]]
# EPOCH 22 , SAMPLE 4-----------------
# Forward pass:[[1.36947537]]
# Truth: [[4]]
#                           Backprop: [[6.91965984]]
# EPOCH 22 , SAMPLE 5-----------------
# Forward pass:[[0.65722758]]
# Truth: [[-1]]
#                           Backprop: [[2.74640324]]
# EPOCH 22 , SAMPLE 6-----------------
# Forward pass:[[1.2614438]]
# Truth: [[3]]
#                           Backprop: [[3.02257766]]
# EPOCH 22 , SAMPLE 7-----------------
# Forward pass:[[0.56323726]]
# Truth: [[0]]
#                           Backprop: [[0.31723621]]
# EPOCH 22 , SAMPLE 8-----------------
# Forward pass:[[0.60180764]]
# Truth: [[-3]]
#                           Backprop: [[12.9730183]]
# EPOCH 23 , SAMPLE 0-----------------
# Forward pass:[[0.63001946]]
# Truth: [[-1]]
#                           Backprop: [[2.65696344]]
# EPOCH 23 , SAMPLE 1-----------------
# Forward pass:[[1.33216796]]
# Truth: [[5]]
#                           Backprop: [[13.45299186]]
# EPOCH 23 , SAMPLE 2-----------------
# Forward pass:[[0.86153563]]
# Truth: [[4]]
#                           Backprop: [[9.84995861]]
# EPOCH 23 , SAMPLE 3-----------------
# Forward pass:[[1.34396546]]
# Truth: [[2]]
#                           Backprop: [[0.43038131]]
# EPOCH 23 , SAMPLE 4-----------------
# Forward pass:[[1.41241983]]
# Truth: [[4]]
#                           Backprop: [[6.69557116]]
# EPOCH 23 , SAMPLE 5-----------------
# Forward pass:[[0.66710455]]
# Truth: [[-1]]
#                           Backprop: [[2.77923757]]
# EPOCH 23 , SAMPLE 6-----------------
# Forward pass:[[1.29987377]]
# Truth: [[3]]
#                           Backprop: [[2.89042918]]
# EPOCH 23 , SAMPLE 7-----------------
# Forward pass:[[0.57682954]]
# Truth: [[0]]
#                           Backprop: [[0.33273231]]
# EPOCH 23 , SAMPLE 8-----------------
# Forward pass:[[0.61068564]]
# Truth: [[-3]]
#                           Backprop: [[13.03705077]]
# EPOCH 24 , SAMPLE 0-----------------
# Forward pass:[[0.63914713]]
# Truth: [[-1]]
#                           Backprop: [[2.68680331]]
# EPOCH 24 , SAMPLE 1-----------------
# Forward pass:[[1.3773512]]
# Truth: [[5]]
#                           Backprop: [[13.12358436]]
# EPOCH 24 , SAMPLE 2-----------------
# Forward pass:[[0.89637101]]
# Truth: [[4]]
#                           Backprop: [[9.63251291]]
# EPOCH 24 , SAMPLE 3-----------------
# Forward pass:[[1.38008254]]
# Truth: [[2]]
#                           Backprop: [[0.38429766]]
# EPOCH 24 , SAMPLE 4-----------------
# Forward pass:[[1.45428182]]
# Truth: [[4]]
#                           Backprop: [[6.48068107]]
# EPOCH 24 , SAMPLE 5-----------------
# Forward pass:[[0.67568639]]
# Truth: [[-1]]
#                           Backprop: [[2.80792489]]
# EPOCH 24 , SAMPLE 6-----------------
# Forward pass:[[1.33729336]]
# Truth: [[3]]
#                           Backprop: [[2.76459338]]
# EPOCH 24 , SAMPLE 7-----------------
# Forward pass:[[0.58926207]]
# Truth: [[0]]
#                           Backprop: [[0.34722979]]
# EPOCH 24 , SAMPLE 8-----------------
# Forward pass:[[0.61797303]]
# Truth: [[-3]]
#                           Backprop: [[13.08972887]]
# EPOCH 25 , SAMPLE 0-----------------
# Forward pass:[[0.64698049]]
# Truth: [[-1]]
#                           Backprop: [[2.71254474]]
# EPOCH 25 , SAMPLE 1-----------------
# Forward pass:[[1.42141002]]
# Truth: [[5]]
#                           Backprop: [[12.80630621]]
# EPOCH 25 , SAMPLE 2-----------------
# Forward pass:[[0.93089526]]
# Truth: [[4]]
#                           Backprop: [[9.41940391]]
# EPOCH 25 , SAMPLE 3-----------------
# Forward pass:[[1.41522245]]
# Truth: [[2]]
#                           Backprop: [[0.34196478]]
# EPOCH 25 , SAMPLE 4-----------------
# Forward pass:[[1.49511631]]
# Truth: [[4]]
#                           Backprop: [[6.2744423]]
# EPOCH 25 , SAMPLE 5-----------------
# Forward pass:[[0.68299394]]
# Truth: [[-1]]
#                           Backprop: [[2.8324686]]
# EPOCH 25 , SAMPLE 6-----------------
# Forward pass:[[1.37375985]]
# Truth: [[3]]
#                           Backprop: [[2.64465702]]
# EPOCH 25 , SAMPLE 7-----------------
# Forward pass:[[0.60056278]]
# Truth: [[0]]
#                           Backprop: [[0.36067566]]
# EPOCH 25 , SAMPLE 8-----------------
# Forward pass:[[0.62369899]]
# Truth: [[-3]]
#                           Backprop: [[13.13119436]]
# EPOCH 26 , SAMPLE 0-----------------
# Forward pass:[[0.6535405]]
# Truth: [[-1]]
#                           Backprop: [[2.73419619]]
# EPOCH 26 , SAMPLE 1-----------------
# Forward pass:[[1.4643994]]
# Truth: [[5]]
#                           Backprop: [[12.50047158]]
# EPOCH 26 , SAMPLE 2-----------------
# Forward pass:[[0.96513102]]
# Truth: [[4]]
#                           Backprop: [[9.21042974]]
# EPOCH 26 , SAMPLE 3-----------------
# Forward pass:[[1.44943045]]
# Truth: [[2]]
#                           Backprop: [[0.30312683]]
# EPOCH 26 , SAMPLE 4-----------------
# Forward pass:[[1.53497361]]
# Truth: [[4]]
#                           Backprop: [[6.07635508]]
# EPOCH 26 , SAMPLE 5-----------------
# Forward pass:[[0.68904532]]
# Truth: [[-1]]
#                           Backprop: [[2.85287409]]
# EPOCH 26 , SAMPLE 6-----------------
# Forward pass:[[1.40932604]]
# Truth: [[3]]
#                           Backprop: [[2.53024365]]
# EPOCH 26 , SAMPLE 7-----------------
# Forward pass:[[0.61075508]]
# Truth: [[0]]
#                           Backprop: [[0.37302177]]
# EPOCH 26 , SAMPLE 8-----------------
# Forward pass:[[0.62789057]]
# Truth: [[-3]]
#                           Backprop: [[13.16158996]]
# EPOCH 27 , SAMPLE 0-----------------
# Forward pass:[[0.65884566]]
# Truth: [[-1]]
#                           Backprop: [[2.75176891]]
# EPOCH 27 , SAMPLE 1-----------------
# Forward pass:[[1.50637001]]
# Truth: [[5]]
#                           Backprop: [[12.20545049]]
# EPOCH 27 , SAMPLE 2-----------------
# Forward pass:[[0.99909467]]
# Truth: [[4]]
#                           Backprop: [[9.00543282]]
# EPOCH 27 , SAMPLE 3-----------------
# Forward pass:[[1.48274836]]
# Truth: [[2]]
#                           Backprop: [[0.26754926]]
# EPOCH 27 , SAMPLE 4-----------------
# Forward pass:[[1.57389992]]
# Truth: [[4]]
#                           Backprop: [[5.88596158]]
# EPOCH 27 , SAMPLE 5-----------------
# Forward pass:[[0.69385652]]
# Truth: [[-1]]
#                           Backprop: [[2.86914989]]
# EPOCH 27 , SAMPLE 6-----------------
# Forward pass:[[1.44404064]]
# Truth: [[3]]
#                           Backprop: [[2.42100954]]
# EPOCH 27 , SAMPLE 7-----------------
# Forward pass:[[0.61985861]]
# Truth: [[0]]
#                           Backprop: [[0.3842247]]
# EPOCH 27 , SAMPLE 8-----------------
# Forward pass:[[0.63057329]]
# Truth: [[-3]]
#                           Backprop: [[13.18106245]]
# EPOCH 28 , SAMPLE 0-----------------
# Forward pass:[[0.66291252]]
# Truth: [[-1]]
#                           Backprop: [[2.76527806]]
# EPOCH 28 , SAMPLE 1-----------------
# Forward pass:[[1.54736882]]
# Truth: [[5]]
#                           Backprop: [[11.92066207]]
# EPOCH 28 , SAMPLE 2-----------------
# Forward pass:[[1.03279736]]
# Truth: [[4]]
#                           Backprop: [[8.80429149]]
# EPOCH 28 , SAMPLE 3-----------------
# Forward pass:[[1.51521497]]
# Truth: [[2]]
#                           Backprop: [[0.23501652]]
# EPOCH 28 , SAMPLE 4-----------------
# Forward pass:[[1.61193785]]
# Truth: [[4]]
#                           Backprop: [[5.70284081]]
# EPOCH 28 , SAMPLE 5-----------------
# Forward pass:[[0.69744187]]
# Truth: [[-1]]
#                           Backprop: [[2.88130891]]
# EPOCH 28 , SAMPLE 6-----------------
# Forward pass:[[1.47794868]]
# Truth: [[3]]
#                           Backprop: [[2.31664021]]
# EPOCH 28 , SAMPLE 7-----------------
# Forward pass:[[0.62788996]]
# Truth: [[0]]
#                           Backprop: [[0.3942458]]
# EPOCH 28 , SAMPLE 8-----------------
# Forward pass:[[0.63177168]]
# Truth: [[-3]]
#                           Backprop: [[13.18976551]]
# EPOCH 29 , SAMPLE 0-----------------
# Forward pass:[[0.66575623]]
# Truth: [[-1]]
#                           Backprop: [[2.77474381]]
# EPOCH 29 , SAMPLE 1-----------------
# Forward pass:[[1.58743957]]
# Truth: [[5]]
#                           Backprop: [[11.64556867]]
# EPOCH 29 , SAMPLE 2-----------------
# Forward pass:[[1.06624604]]
# Truth: [[4]]
#                           Backprop: [[8.60691232]]
# EPOCH 29 , SAMPLE 3-----------------
# Forward pass:[[1.54686645]]
# Truth: [[2]]
#                           Backprop: [[0.20533001]]
# EPOCH 29 , SAMPLE 4-----------------
# Forward pass:[[1.6491269]]
# Truth: [[4]]
#                           Backprop: [[5.52660433]]
# EPOCH 29 , SAMPLE 5-----------------
# Forward pass:[[0.69981457]]
# Truth: [[-1]]
#                           Backprop: [[2.88936956]]
# EPOCH 29 , SAMPLE 6-----------------
# Forward pass:[[1.51109194]]
# Truth: [[3]]
#                           Backprop: [[2.21684722]]
# EPOCH 29 , SAMPLE 7-----------------
# Forward pass:[[0.63486328]]
# Truth: [[0]]
#                           Backprop: [[0.40305138]]
# EPOCH 29 , SAMPLE 8-----------------
# Forward pass:[[0.63150968]]
# Truth: [[-3]]
#                           Backprop: [[13.18786253]]
# EPOCH 30 , SAMPLE 0-----------------
# Forward pass:[[0.66739093]]
# Truth: [[-1]]
#                           Backprop: [[2.7801925]]
# EPOCH 30 , SAMPLE 1-----------------
# Forward pass:[[1.62662325]]
# Truth: [[5]]
#                           Backprop: [[11.37967066]]
# EPOCH 30 , SAMPLE 2-----------------
# Forward pass:[[1.09944431]]
# Truth: [[4]]
#                           Backprop: [[8.41322332]]
# EPOCH 30 , SAMPLE 3-----------------
# Forward pass:[[1.57773664]]
# Truth: [[2]]
#                           Backprop: [[0.17830635]]
# EPOCH 30 , SAMPLE 4-----------------
# Forward pass:[[1.68550387]]
# Truth: [[4]]
#                           Backprop: [[5.35689234]]
# EPOCH 30 , SAMPLE 5-----------------
# Forward pass:[[0.70098706]]
# Truth: [[-1]]
#                           Backprop: [[2.89335697]]
# EPOCH 30 , SAMPLE 6-----------------
# Forward pass:[[1.54350922]]
# Truth: [[3]]
#                           Backprop: [[2.1213654]]
# EPOCH 30 , SAMPLE 7-----------------
# Forward pass:[[0.64079093]]
# Truth: [[0]]
#                           Backprop: [[0.41061302]]
# EPOCH 30 , SAMPLE 8-----------------
# Forward pass:[[0.62981115]]
# Truth: [[-3]]
#                           Backprop: [[13.175529]]
# EPOCH 31 , SAMPLE 0-----------------
# Forward pass:[[0.66783022]]
# Truth: [[-1]]
#                           Backprop: [[2.78165766]]
# EPOCH 31 , SAMPLE 1-----------------
# Forward pass:[[1.66495848]]
# Truth: [[5]]
#                           Backprop: [[11.12250194]]
# EPOCH 31 , SAMPLE 2-----------------
# Forward pass:[[1.13239336]]
# Truth: [[4]]
#                           Backprop: [[8.22316782]]
# EPOCH 31 , SAMPLE 3-----------------
# Forward pass:[[1.60785738]]
# Truth: [[2]]
#                           Backprop: [[0.15377583]]
# EPOCH 31 , SAMPLE 4-----------------
# Forward pass:[[1.72110326]]
# Truth: [[4]]
#                           Backprop: [[5.19337033]]
# EPOCH 31 , SAMPLE 5-----------------
# Forward pass:[[0.70097151]]
# Truth: [[-1]]
#                           Backprop: [[2.89330408]]
# EPOCH 31 , SAMPLE 6-----------------
# Forward pass:[[1.57523675]]
# Truth: [[3]]
#                           Backprop: [[2.02995031]]
# EPOCH 31 , SAMPLE 7-----------------
# Forward pass:[[0.64568407]]
# Truth: [[0]]
#                           Backprop: [[0.41690792]]
# EPOCH 31 , SAMPLE 8-----------------
# Forward pass:[[0.62670027]]
# Truth: [[-3]]
#                           Backprop: [[13.15295482]]
# EPOCH 32 , SAMPLE 0-----------------
# Forward pass:[[0.66708759]]
# Truth: [[-1]]
#                           Backprop: [[2.77918102]]
# EPOCH 32 , SAMPLE 1-----------------
# Forward pass:[[1.70248185]]
# Truth: [[5]]
#                           Backprop: [[10.87362593]]
# EPOCH 32 , SAMPLE 2-----------------
# Forward pass:[[1.16509276]]
# Truth: [[4]]
#                           Backprop: [[8.03669908]]
# EPOCH 32 , SAMPLE 3-----------------
# Forward pass:[[1.6372588]]
# Truth: [[2]]
#                           Backprop: [[0.13158118]]
# EPOCH 32 , SAMPLE 4-----------------
# Forward pass:[[1.75595763]]
# Truth: [[4]]
#                           Backprop: [[5.03572617]]
# EPOCH 32 , SAMPLE 5-----------------
# Forward pass:[[0.69978017]]
# Truth: [[-1]]
#                           Backprop: [[2.88925261]]
# EPOCH 32 , SAMPLE 6-----------------
# Forward pass:[[1.6063085]]
# Truth: [[3]]
#                           Backprop: [[1.94237601]]
# EPOCH 32 , SAMPLE 7-----------------
# Forward pass:[[0.64955318]]
# Truth: [[0]]
#                           Backprop: [[0.42191933]]
# EPOCH 32 , SAMPLE 8-----------------
# Forward pass:[[0.62220184]]
# Truth: [[-3]]
#                           Backprop: [[13.12034619]]
# EPOCH 33 , SAMPLE 0-----------------
# Forward pass:[[0.66517669]]
# Truth: [[-1]]
#                           Backprop: [[2.77281343]]
# EPOCH 33 , SAMPLE 1-----------------
# Forward pass:[[1.73922826]]
# Truth: [[5]]
#                           Backprop: [[10.63263233]]
# EPOCH 33 , SAMPLE 2-----------------
# Forward pass:[[1.19754112]]
# Truth: [[4]]
#                           Backprop: [[7.85377578]]
# EPOCH 33 , SAMPLE 3-----------------
# Forward pass:[[1.66596953]]
# Truth: [[2]]
#                           Backprop: [[0.11157635]]
# EPOCH 33 , SAMPLE 4-----------------
# Forward pass:[[1.79009784]]
# Truth: [[4]]
#                           Backprop: [[4.88366754]]
# EPOCH 33 , SAMPLE 5-----------------
# Forward pass:[[0.69742571]]
# Truth: [[-1]]
#                           Backprop: [[2.88125403]]
# EPOCH 33 , SAMPLE 6-----------------
# Forward pass:[[1.6367564]]
# Truth: [[3]]
#                           Backprop: [[1.85843311]]
# EPOCH 33 , SAMPLE 7-----------------
# Forward pass:[[0.65240855]]
# Truth: [[0]]
#                           Backprop: [[0.42563691]]
# EPOCH 33 , SAMPLE 8-----------------
# Forward pass:[[0.61634169]]
# Truth: [[-3]]
#                           Backprop: [[13.07792723]]
# EPOCH 34 , SAMPLE 0-----------------
# Forward pass:[[0.6621118]]
# Truth: [[-1]]
#                           Backprop: [[2.76261564]]
# EPOCH 34 , SAMPLE 1-----------------
# Forward pass:[[1.77523114]]
# Truth: [[5]]
#                           Backprop: [[10.39913417]]
# EPOCH 34 , SAMPLE 2-----------------
# Forward pass:[[1.22973683]]
# Truth: [[4]]
#                           Backprop: [[7.67435804]]
# EPOCH 34 , SAMPLE 3-----------------
# Forward pass:[[1.69401696]]
# Truth: [[2]]
#                           Backprop: [[0.09362562]]
# EPOCH 34 , SAMPLE 4-----------------
# Forward pass:[[1.82355339]]
# Truth: [[4]]
#                           Backprop: [[4.73691986]]
# EPOCH 34 , SAMPLE 5-----------------
# Forward pass:[[0.69392158]]
# Truth: [[-1]]
#                           Backprop: [[2.8693703]]
# EPOCH 34 , SAMPLE 6-----------------
# Forward pass:[[1.66661068]]
# Truth: [[3]]
#                           Backprop: [[1.77792707]]
# EPOCH 34 , SAMPLE 7-----------------
# Forward pass:[[0.65426079]]
# Truth: [[0]]
#                           Backprop: [[0.42805718]]
# EPOCH 34 , SAMPLE 8-----------------
# Forward pass:[[0.60914688]]
# Truth: [[-3]]
#                           Backprop: [[13.0259412]]
# EPOCH 35 , SAMPLE 0-----------------
# Forward pass:[[0.65790801]]
# Truth: [[-1]]
#                           Backprop: [[2.74865898]]
# EPOCH 35 , SAMPLE 1-----------------
# Forward pass:[[1.81052269]]
# Truth: [[5]]
#                           Backprop: [[10.17276551]]
# EPOCH 35 , SAMPLE 2-----------------
# Forward pass:[[1.26167856]]
# Truth: [[4]]
#                           Backprop: [[7.49840433]]
# EPOCH 35 , SAMPLE 3-----------------
# Forward pass:[[1.72142738]]
# Truth: [[2]]
#                           Backprop: [[0.0776027]]
# EPOCH 35 , SAMPLE 4-----------------
# Forward pass:[[1.85635253]]
# Truth: [[4]]
#                           Backprop: [[4.59522447]]
# EPOCH 35 , SAMPLE 5-----------------
# Forward pass:[[0.68928225]]
# Truth: [[-1]]
#                           Backprop: [[2.85367452]]
# EPOCH 35 , SAMPLE 6-----------------
# Forward pass:[[1.69590003]]
# Truth: [[3]]
#                           Backprop: [[1.70067672]]
# EPOCH 35 , SAMPLE 7-----------------
# Forward pass:[[0.65512119]]
# Truth: [[0]]
#                           Backprop: [[0.42918378]]
# EPOCH 35 , SAMPLE 8-----------------
# Forward pass:[[0.60064596]]
# Truth: [[-3]]
#                           Backprop: [[12.96465133]]
# EPOCH 36 , SAMPLE 0-----------------
# Forward pass:[[0.65258156]]
# Truth: [[-1]]
#                           Backprop: [[2.73102582]]
# EPOCH 36 , SAMPLE 1-----------------
# Forward pass:[[1.845134]]
# Truth: [[5]]
#                           Backprop: [[9.95317945]]
# EPOCH 36 , SAMPLE 2-----------------
# Forward pass:[[1.29336575]]
# Truth: [[4]]
#                           Backprop: [[7.32586896]]
# EPOCH 36 , SAMPLE 3-----------------
# Forward pass:[[1.74822616]]
# Truth: [[2]]
#                           Backprop: [[0.06339007]]
# EPOCH 36 , SAMPLE 4-----------------
# Forward pass:[[1.88852253]]
# Truth: [[4]]
#                           Backprop: [[4.45833712]]
# EPOCH 36 , SAMPLE 5-----------------
# Forward pass:[[0.6835235]]
# Truth: [[-1]]
#                           Backprop: [[2.83425138]]
# EPOCH 36 , SAMPLE 6-----------------
# Forward pass:[[1.72465181]]
# Truth: [[3]]
#                           Backprop: [[1.626513]]
# EPOCH 36 , SAMPLE 7-----------------
# Forward pass:[[0.65500214]]
# Truth: [[0]]
#                           Backprop: [[0.4290278]]
# EPOCH 36 , SAMPLE 8-----------------
# Forward pass:[[0.59086915]]
# Truth: [[-3]]
#                           Backprop: [[12.89434123]]
# EPOCH 37 , SAMPLE 0-----------------
# Forward pass:[[0.64615004]]
# Truth: [[-1]]
#                           Backprop: [[2.70980996]]
# EPOCH 37 , SAMPLE 1-----------------
# Forward pass:[[1.87909523]]
# Truth: [[5]]
#                           Backprop: [[9.74004659]]
# EPOCH 37 , SAMPLE 2-----------------
# Forward pass:[[1.32479902]]
# Truth: [[4]]
#                           Backprop: [[7.15670026]]
# EPOCH 37 , SAMPLE 3-----------------
# Forward pass:[[1.77443784]]
# Truth: [[2]]
#                           Backprop: [[0.05087829]]
# EPOCH 37 , SAMPLE 4-----------------
# Forward pass:[[1.92008971]]
# Truth: [[4]]
#                           Backprop: [[4.3260268]]
# EPOCH 37 , SAMPLE 5-----------------
# Forward pass:[[0.6766626]]
# Truth: [[-1]]
#                           Backprop: [[2.81119747]]
# EPOCH 37 , SAMPLE 6-----------------
# Forward pass:[[1.75289219]]
# Truth: [[3]]
#                           Backprop: [[1.55527789]]
# EPOCH 37 , SAMPLE 7-----------------
# Forward pass:[[0.65391735]]
# Truth: [[0]]
#                           Backprop: [[0.42760791]]
# EPOCH 37 , SAMPLE 8-----------------
# Forward pass:[[0.57984845]]
# Truth: [[-3]]
#                           Backprop: [[12.81531492]]
# EPOCH 38 , SAMPLE 0-----------------
# Forward pass:[[0.63863258]]
# Truth: [[-1]]
#                           Backprop: [[2.68511674]]
# EPOCH 38 , SAMPLE 1-----------------
# Forward pass:[[1.91243562]]
# Truth: [[5]]
#                           Backprop: [[9.5330538]]
# EPOCH 38 , SAMPLE 2-----------------
# Forward pass:[[1.35598046]]
# Truth: [[4]]
#                           Backprop: [[6.99083935]]
# EPOCH 38 , SAMPLE 3-----------------
# Forward pass:[[1.80008624]]
# Truth: [[2]]
#                           Backprop: [[0.03996551]]
# EPOCH 38 , SAMPLE 4-----------------
# Forward pass:[[1.95107961]]
# Truth: [[4]]
#                           Backprop: [[4.19807477]]
# EPOCH 38 , SAMPLE 5-----------------
# Forward pass:[[0.66871848]]
# Truth: [[-1]]
#                           Backprop: [[2.78462137]]
# EPOCH 38 , SAMPLE 6-----------------
# Forward pass:[[1.78064626]]
# Truth: [[3]]
#                           Backprop: [[1.48682354]]
# EPOCH 38 , SAMPLE 7-----------------
# Forward pass:[[0.65188222]]
# Truth: [[0]]
#                           Backprop: [[0.42495043]]
# EPOCH 38 , SAMPLE 8-----------------
# Forward pass:[[0.56761774]]
# Truth: [[-3]]
#                           Backprop: [[12.72789634]]
# EPOCH 39 , SAMPLE 0-----------------
# Forward pass:[[0.63005001]]
# Truth: [[-1]]
#                           Backprop: [[2.65706304]]
# EPOCH 39 , SAMPLE 1-----------------
# Forward pass:[[1.9451836]]
# Truth: [[5]]
#                           Backprop: [[9.33190326]]
# EPOCH 39 , SAMPLE 2-----------------
# Forward pass:[[1.38691381]]
# Truth: [[4]]
#                           Backprop: [[6.82821944]]
# EPOCH 39 , SAMPLE 3-----------------
# Forward pass:[[1.82519448]]
# Truth: [[2]]
#                           Backprop: [[0.03055697]]
# EPOCH 39 , SAMPLE 4-----------------
# Forward pass:[[1.98151696]]
# Truth: [[4]]
#                           Backprop: [[4.07427379]]
# EPOCH 39 , SAMPLE 5-----------------
# Forward pass:[[0.65971188]]
# Truth: [[-1]]
#                           Backprop: [[2.75464354]]
# EPOCH 39 , SAMPLE 6-----------------
# Forward pass:[[1.80793812]]
# Truth: [[3]]
#                           Backprop: [[1.42101154]]
# EPOCH 39 , SAMPLE 7-----------------
# Forward pass:[[0.64891397]]
# Truth: [[0]]
#                           Backprop: [[0.42108934]]
# EPOCH 39 , SAMPLE 8-----------------
# Forward pass:[[0.55421279]]
# Truth: [[-3]]
#                           Backprop: [[12.63242853]]
# EPOCH 40 , SAMPLE 0-----------------
# Forward pass:[[0.62042496]]
# Truth: [[-1]]
#                           Backprop: [[2.62577706]]
# EPOCH 40 , SAMPLE 1-----------------
# Forward pass:[[1.97736675]]
# Truth: [[5]]
#                           Backprop: [[9.13631178]]
# EPOCH 40 , SAMPLE 2-----------------
# Forward pass:[[1.41760467]]
# Truth: [[4]]
#                           Backprop: [[6.66876563]]
# EPOCH 40 , SAMPLE 3-----------------
# Forward pass:[[1.84978506]]
# Truth: [[2]]
#                           Backprop: [[0.02256453]]
# EPOCH 40 , SAMPLE 4-----------------
# Forward pass:[[2.01142576]]
# Truth: [[4]]
#                           Backprop: [[3.95442751]]
# EPOCH 40 , SAMPLE 5-----------------
# Forward pass:[[0.64966544]]
# Truth: [[-1]]
#                           Backprop: [[2.72139608]]
# EPOCH 40 , SAMPLE 6-----------------
# Forward pass:[[1.8347909]]
# Truth: [[3]]
#                           Backprop: [[1.35771225]]
# EPOCH 40 , SAMPLE 7-----------------
# Forward pass:[[0.64503182]]
# Truth: [[0]]
#                           Backprop: [[0.41606605]]
# EPOCH 40 , SAMPLE 8-----------------
# Forward pass:[[0.53967123]]
# Truth: [[-3]]
#                           Backprop: [[12.5292724]]
# EPOCH 41 , SAMPLE 0-----------------
# Forward pass:[[0.60978195]]
# Truth: [[-1]]
#                           Backprop: [[2.59139792]]
# EPOCH 41 , SAMPLE 1-----------------
# Forward pass:[[2.00901182]]
# Truth: [[5]]
#                           Backprop: [[8.94601029]]
# EPOCH 41 , SAMPLE 2-----------------
# Forward pass:[[1.44806051]]
# ...
# EPOCH 986 , SAMPLE 6-----------------
# Forward pass:[[2.98191035]]
# Truth: [[3]]
#                           Backprop: [[0.00032724]]
# EPOCH 986 , SAMPLE 7-----------------
# Forward pass:[[0.00976988]]
# Truth: [[0]]
#                           Backprop: [[9.54506324e-05]]
# EPOCH 986 , SAMPLE 8-----------------
# Forward pass:[[-2.99985828]]
# Truth: [[-3]]
#                           Backprop: [[2.00846105e-08]]
# EPOCH 987 , SAMPLE 0-----------------
# Forward pass:[[-1.00455532]]
# Truth: [[-1]]
#                           Backprop: [[2.07509086e-05]]
# EPOCH 987 , SAMPLE 1-----------------
# Forward pass:[[4.92717009]]
# Truth: [[5]]
#                           Backprop: [[0.0053042]]
# EPOCH 987 , SAMPLE 2-----------------
# Forward pass:[[4.00005103]]
# Truth: [[4]]
#                           Backprop: [[2.6045334e-09]]
# EPOCH 987 , SAMPLE 3-----------------
# Forward pass:[[1.99219499]]
# Truth: [[2]]
#                           Backprop: [[6.09182217e-05]]
# EPOCH 987 , SAMPLE 4-----------------
# Forward pass:[[4.08139154]]
# Truth: [[4]]
#                           Backprop: [[0.00662458]]
# EPOCH 987 , SAMPLE 5-----------------
# Forward pass:[[-1.00428845]]
# Truth: [[-1]]
#                           Backprop: [[1.8390808e-05]]
# EPOCH 987 , SAMPLE 6-----------------
# Forward pass:[[2.98192581]]
# Truth: [[3]]
#                           Backprop: [[0.00032668]]
# EPOCH 987 , SAMPLE 7-----------------
# Forward pass:[[0.00971858]]
# Truth: [[0]]
#                           Backprop: [[9.44508031e-05]]
# EPOCH 987 , SAMPLE 8-----------------
# Forward pass:[[-2.99988335]]
# Truth: [[-3]]
#                           Backprop: [[1.36060838e-08]]
# EPOCH 988 , SAMPLE 0-----------------
# Forward pass:[[-1.0045203]]
# Truth: [[-1]]
#                           Backprop: [[2.04330725e-05]]
# EPOCH 988 , SAMPLE 1-----------------
# Forward pass:[[4.92724206]]
# Truth: [[5]]
#                           Backprop: [[0.00529372]]
# EPOCH 988 , SAMPLE 2-----------------
# Forward pass:[[4.00006294]]
# Truth: [[4]]
#                           Backprop: [[3.96158829e-09]]
# EPOCH 988 , SAMPLE 3-----------------
# Forward pass:[[1.99215161]]
# Truth: [[2]]
#                           Backprop: [[6.15972687e-05]]
# EPOCH 988 , SAMPLE 4-----------------
# Forward pass:[[4.08135771]]
# Truth: [[4]]
#                           Backprop: [[0.00661908]]
# EPOCH 988 , SAMPLE 5-----------------
# Forward pass:[[-1.00425492]]
# Truth: [[-1]]
#                           Backprop: [[1.81043824e-05]]
# EPOCH 988 , SAMPLE 6-----------------
# Forward pass:[[2.98194119]]
# Truth: [[3]]
#                           Backprop: [[0.00032612]]
# EPOCH 988 , SAMPLE 7-----------------
# Forward pass:[[0.00966755]]
# Truth: [[0]]
#                           Backprop: [[9.34614467e-05]]
# EPOCH 988 , SAMPLE 8-----------------
# Forward pass:[[-2.99990822]]
# Truth: [[-3]]
#                           Backprop: [[8.42378512e-09]]
# EPOCH 989 , SAMPLE 0-----------------
# Forward pass:[[-1.00448548]]
# Truth: [[-1]]
#                           Backprop: [[2.01195198e-05]]
# EPOCH 989 , SAMPLE 1-----------------
# Forward pass:[[4.92731385]]
# Truth: [[5]]
#                           Backprop: [[0.00528328]]
# EPOCH 989 , SAMPLE 2-----------------
# Forward pass:[[4.00007478]]
# Truth: [[4]]
#                           Backprop: [[5.59241202e-09]]
# EPOCH 989 , SAMPLE 3-----------------
# Forward pass:[[1.99210851]]
# Truth: [[2]]
#                           Backprop: [[6.22755395e-05]]
# EPOCH 989 , SAMPLE 4-----------------
# Forward pass:[[4.08132383]]
# Truth: [[4]]
#                           Backprop: [[0.00661356]]
# EPOCH 989 , SAMPLE 5-----------------
# Forward pass:[[-1.00422159]]
# Truth: [[-1]]
#                           Backprop: [[1.78218609e-05]]
# EPOCH 989 , SAMPLE 6-----------------
# Forward pass:[[2.9819565]]
# Truth: [[3]]
#                           Backprop: [[0.00032557]]
# EPOCH 989 , SAMPLE 7-----------------
# Forward pass:[[0.00961678]]
# Truth: [[0]]
#                           Backprop: [[9.24824534e-05]]
# EPOCH 989 , SAMPLE 8-----------------
# Forward pass:[[-2.99993287]]
# Truth: [[-3]]
#                           Backprop: [[4.50601283e-09]]
# EPOCH 990 , SAMPLE 0-----------------
# Forward pass:[[-1.00445086]]
# Truth: [[-1]]
#                           Backprop: [[1.98101973e-05]]
# EPOCH 990 , SAMPLE 1-----------------
# Forward pass:[[4.92738546]]
# Truth: [[5]]
#                           Backprop: [[0.00527287]]
# EPOCH 990 , SAMPLE 2-----------------
# Forward pass:[[4.00008656]]
# Truth: [[4]]
#                           Backprop: [[7.49242139e-09]]
# EPOCH 990 , SAMPLE 3-----------------
# Forward pass:[[1.99206571]]
# Truth: [[2]]
#                           Backprop: [[6.2952986e-05]]
# EPOCH 990 , SAMPLE 4-----------------
# Forward pass:[[4.0812899]]
# Truth: [[4]]
#                           Backprop: [[0.00660805]]
# EPOCH 990 , SAMPLE 5-----------------
# Forward pass:[[-1.00418846]]
# Truth: [[-1]]
#                           Backprop: [[1.75431949e-05]]
# EPOCH 990 , SAMPLE 6-----------------
# Forward pass:[[2.98197173]]
# Truth: [[3]]
#                           Backprop: [[0.00032502]]
# EPOCH 990 , SAMPLE 7-----------------
# Forward pass:[[0.00956628]]
# Truth: [[0]]
#                           Backprop: [[9.15137148e-05]]
# EPOCH 990 , SAMPLE 8-----------------
# Forward pass:[[-2.99995732]]
# Truth: [[-3]]
#                           Backprop: [[1.82163222e-09]]
# EPOCH 991 , SAMPLE 0-----------------
# Forward pass:[[-1.00441645]]
# Truth: [[-1]]
#                           Backprop: [[1.95050525e-05]]
# EPOCH 991 , SAMPLE 1-----------------
# Forward pass:[[4.92745691]]
# Truth: [[5]]
#                           Backprop: [[0.0052625]]
# EPOCH 991 , SAMPLE 2-----------------
# Forward pass:[[4.00009827]]
# Truth: [[4]]
#                           Backprop: [[9.65708649e-09]]
# EPOCH 991 , SAMPLE 3-----------------
# Forward pass:[[1.99202319]]
# Truth: [[2]]
#                           Backprop: [[6.36295606e-05]]
# EPOCH 991 , SAMPLE 4-----------------
# Forward pass:[[4.08125592]]
# Truth: [[4]]
#                           Backprop: [[0.00660252]]
# EPOCH 991 , SAMPLE 5-----------------
# Forward pass:[[-1.00415552]]
# Truth: [[-1]]
#                           Backprop: [[1.72683363e-05]]
# EPOCH 991 , SAMPLE 6-----------------
# Forward pass:[[2.98198688]]
# Truth: [[3]]
#                           Backprop: [[0.00032447]]
# EPOCH 991 , SAMPLE 7-----------------
# Forward pass:[[0.00951605]]
# Truth: [[0]]
#                           Backprop: [[9.05551233e-05]]
# EPOCH 991 , SAMPLE 8-----------------
# Forward pass:[[-2.99998156]]
# Truth: [[-3]]
#                           Backprop: [[3.40066807e-10]]
# EPOCH 992 , SAMPLE 0-----------------
# Forward pass:[[-1.00438224]]
# Truth: [[-1]]
#                           Backprop: [[1.92040337e-05]]
# EPOCH 992 , SAMPLE 1-----------------
# Forward pass:[[4.92752818]]
# Truth: [[5]]
#                           Backprop: [[0.00525216]]
# EPOCH 992 , SAMPLE 2-----------------
# Forward pass:[[4.00010992]]
# Truth: [[4]]
#                           Backprop: [[1.20819303e-08]]
# EPOCH 992 , SAMPLE 3-----------------
# Forward pass:[[1.99198095]]
# Truth: [[2]]
#                           Backprop: [[6.43052171e-05]]
# EPOCH 992 , SAMPLE 4-----------------
# Forward pass:[[4.08122188]]
# Truth: [[4]]
#                           Backprop: [[0.00659699]]
# EPOCH 992 , SAMPLE 5-----------------
# Forward pass:[[-1.00412277]]
# Truth: [[-1]]
#                           Backprop: [[1.69972373e-05]]
# EPOCH 992 , SAMPLE 6-----------------
# Forward pass:[[2.98200197]]
# Truth: [[3]]
#                           Backprop: [[0.00032393]]
# EPOCH 992 , SAMPLE 7-----------------
# Forward pass:[[0.00946607]]
# Truth: [[0]]
#                           Backprop: [[8.96065726e-05]]
# EPOCH 992 , SAMPLE 8-----------------
# Forward pass:[[-3.00000559]]
# Truth: [[-3]]
#                           Backprop: [[3.12895415e-11]]
# EPOCH 993 , SAMPLE 0-----------------
# Forward pass:[[-1.00434823]]
# Truth: [[-1]]
#                           Backprop: [[1.89070896e-05]]
# EPOCH 993 , SAMPLE 1-----------------
# Forward pass:[[4.92759929]]
# Truth: [[5]]
#                           Backprop: [[0.00524186]]
# EPOCH 993 , SAMPLE 2-----------------
# Forward pass:[[4.0001215]]
# Truth: [[4]]
#                           Backprop: [[1.47625279e-08]]
# EPOCH 993 , SAMPLE 3-----------------
# Forward pass:[[1.99193899]]
# Truth: [[2]]
#                           Backprop: [[6.49799099e-05]]
# EPOCH 993 , SAMPLE 4-----------------
# Forward pass:[[4.0811878]]
# Truth: [[4]]
#                           Backprop: [[0.00659146]]
# EPOCH 993 , SAMPLE 5-----------------
# Forward pass:[[-1.00409021]]
# Truth: [[-1]]
#                           Backprop: [[1.6729851e-05]]
# EPOCH 993 , SAMPLE 6-----------------
# Forward pass:[[2.98201698]]
# Truth: [[3]]
#                           Backprop: [[0.00032339]]
# EPOCH 993 , SAMPLE 7-----------------
# Forward pass:[[0.00941637]]
# Truth: [[0]]
#                           Backprop: [[8.86679577e-05]]
# EPOCH 993 , SAMPLE 8-----------------
# Forward pass:[[-3.00002942]]
# Truth: [[-3]]
#                           Backprop: [[8.65814213e-10]]
# EPOCH 994 , SAMPLE 0-----------------
# Forward pass:[[-1.00431441]]
# Truth: [[-1]]
#                           Backprop: [[1.86141696e-05]]
# EPOCH 994 , SAMPLE 1-----------------
# Forward pass:[[4.92767022]]
# Truth: [[5]]
#                           Backprop: [[0.0052316]]
# EPOCH 994 , SAMPLE 2-----------------
# Forward pass:[[4.00013302]]
# Truth: [[4]]
#                           Backprop: [[1.76945065e-08]]
# EPOCH 994 , SAMPLE 3-----------------
# Forward pass:[[1.99189731]]
# Truth: [[2]]
#                           Backprop: [[6.56535942e-05]]
# EPOCH 994 , SAMPLE 4-----------------
# Forward pass:[[4.08115367]]
# Truth: [[4]]
#                           Backprop: [[0.00658592]]
# EPOCH 994 , SAMPLE 5-----------------
# Forward pass:[[-1.00405785]]
# Truth: [[-1]]
#                           Backprop: [[1.6466131e-05]]
# EPOCH 994 , SAMPLE 6-----------------
# Forward pass:[[2.98203192]]
# Truth: [[3]]
#                           Backprop: [[0.00032285]]
# EPOCH 994 , SAMPLE 7-----------------
# Forward pass:[[0.00936692]]
# Truth: [[0]]
#                           Backprop: [[8.77391744e-05]]
# EPOCH 994 , SAMPLE 8-----------------
# Forward pass:[[-3.00005305]]
# Truth: [[-3]]
#                           Backprop: [[2.81468696e-09]]
# EPOCH 995 , SAMPLE 0-----------------
# Forward pass:[[-1.0042808]]
# Truth: [[-1]]
#                           Backprop: [[1.83252238e-05]]
# EPOCH 995 , SAMPLE 1-----------------
# Forward pass:[[4.92774099]]
# Truth: [[5]]
#                           Backprop: [[0.00522136]]
# EPOCH 995 , SAMPLE 2-----------------
# Forward pass:[[4.00014448]]
# Truth: [[4]]
#                           Backprop: [[2.08735442e-08]]
# EPOCH 995 , SAMPLE 3-----------------
# Forward pass:[[1.99185591]]
# Truth: [[2]]
#                           Backprop: [[6.63262264e-05]]
# EPOCH 995 , SAMPLE 4-----------------
# Forward pass:[[4.08111949]]
# Truth: [[4]]
#                           Backprop: [[0.00658037]]
# EPOCH 995 , SAMPLE 5-----------------
# Forward pass:[[-1.00402567]]
# Truth: [[-1]]
#                           Backprop: [[1.62060314e-05]]
# EPOCH 995 , SAMPLE 6-----------------
# Forward pass:[[2.98204678]]
# Truth: [[3]]
#                           Backprop: [[0.00032232]]
# EPOCH 995 , SAMPLE 7-----------------
# Forward pass:[[0.00931773]]
# Truth: [[0]]
#                           Backprop: [[8.68201197e-05]]
# EPOCH 995 , SAMPLE 8-----------------
# Forward pass:[[-3.00007648]]
# Truth: [[-3]]
#                           Backprop: [[5.84947791e-09]]
# EPOCH 996 , SAMPLE 0-----------------
# Forward pass:[[-1.00424738]]
# Truth: [[-1]]
#                           Backprop: [[1.80402027e-05]]
# EPOCH 996 , SAMPLE 1-----------------
# Forward pass:[[4.92781159]]
# Truth: [[5]]
#                           Backprop: [[0.00521117]]
# EPOCH 996 , SAMPLE 2-----------------
# Forward pass:[[4.00015587]]
# Truth: [[4]]
#                           Backprop: [[2.429537e-08]]
# EPOCH 996 , SAMPLE 3-----------------
# Forward pass:[[1.99181478]]
# Truth: [[2]]
#                           Backprop: [[6.69977632e-05]]
# EPOCH 996 , SAMPLE 4-----------------
# Forward pass:[[4.08108527]]
# Truth: [[4]]
#                           Backprop: [[0.00657482]]
# EPOCH 996 , SAMPLE 5-----------------
# Forward pass:[[-1.00399368]]
# Truth: [[-1]]
#                           Backprop: [[1.59495069e-05]]
# EPOCH 996 , SAMPLE 6-----------------
# Forward pass:[[2.98206158]]
# Truth: [[3]]
#                           Backprop: [[0.00032179]]
# EPOCH 996 , SAMPLE 7-----------------
# Forward pass:[[0.0092688]]
# Truth: [[0]]
#                           Backprop: [[8.59106918e-05]]
# EPOCH 996 , SAMPLE 8-----------------
# Forward pass:[[-3.00009971]]
# Truth: [[-3]]
#                           Backprop: [[9.94227291e-09]]
# EPOCH 997 , SAMPLE 0-----------------
# Forward pass:[[-1.00421415]]
# Truth: [[-1]]
#                           Backprop: [[1.77590575e-05]]
# EPOCH 997 , SAMPLE 1-----------------
# Forward pass:[[4.92788202]]
# Truth: [[5]]
#                           Backprop: [[0.005201]]
# EPOCH 997 , SAMPLE 2-----------------
# Forward pass:[[4.0001672]]
# Truth: [[4]]
#                           Backprop: [[2.79557632e-08]]
# EPOCH 997 , SAMPLE 3-----------------
# Forward pass:[[1.99177393]]
# Truth: [[2]]
#                           Backprop: [[6.76681628e-05]]
# EPOCH 997 , SAMPLE 4-----------------
# Forward pass:[[4.08105099]]
# Truth: [[4]]
#                           Backprop: [[0.00656926]]
# EPOCH 997 , SAMPLE 5-----------------
# Forward pass:[[-1.00396188]]
# Truth: [[-1]]
#                           Backprop: [[1.56965127e-05]]
# EPOCH 997 , SAMPLE 6-----------------
# Forward pass:[[2.9820763]]
# Truth: [[3]]
#                           Backprop: [[0.00032126]]
# EPOCH 997 , SAMPLE 7-----------------
# Forward pass:[[0.00922013]]
# Truth: [[0]]
#                           Backprop: [[8.50107897e-05]]
# EPOCH 997 , SAMPLE 8-----------------
# Forward pass:[[-3.00012274]]
# Truth: [[-3]]
#                           Backprop: [[1.50656655e-08]]
# EPOCH 998 , SAMPLE 0-----------------
# Forward pass:[[-1.00418112]]
# Truth: [[-1]]
#                           Backprop: [[1.748174e-05]]
# EPOCH 998 , SAMPLE 1-----------------
# Forward pass:[[4.92795228]]
# Truth: [[5]]
#                           Backprop: [[0.00519087]]
# EPOCH 998 , SAMPLE 2-----------------
# Forward pass:[[4.00017847]]
# Truth: [[4]]
#                           Backprop: [[3.18505529e-08]]
# EPOCH 998 , SAMPLE 3-----------------
# Forward pass:[[1.99173336]]
# Truth: [[2]]
#                           Backprop: [[6.83373836e-05]]
# EPOCH 998 , SAMPLE 4-----------------
# Forward pass:[[4.08101666]]
# Truth: [[4]]
#                           Backprop: [[0.0065637]]
# EPOCH 998 , SAMPLE 5-----------------
# Forward pass:[[-1.00393027]]
# Truth: [[-1]]
#                           Backprop: [[1.54470044e-05]]
# EPOCH 998 , SAMPLE 6-----------------
# Forward pass:[[2.98209095]]
# Truth: [[3]]
#                           Backprop: [[0.00032073]]
# EPOCH 998 , SAMPLE 7-----------------
# Forward pass:[[0.00917171]]
# Truth: [[0]]
#                           Backprop: [[8.41203137e-05]]
# EPOCH 998 , SAMPLE 8-----------------
# Forward pass:[[-3.00014558]]
# Truth: [[-3]]
#                           Backprop: [[2.11927486e-08]]
# EPOCH 999 , SAMPLE 0-----------------
# Forward pass:[[-1.00414828]]
# Truth: [[-1]]
#                           Backprop: [[1.72082025e-05]]
# EPOCH 999 , SAMPLE 1-----------------
# Forward pass:[[4.92802238]]
# Truth: [[5]]
#                           Backprop: [[0.00518078]]
# EPOCH 999 , SAMPLE 2-----------------
# Forward pass:[[4.00018967]]
# Truth: [[4]]
#                           Backprop: [[3.59756172e-08]]
# EPOCH 999 , SAMPLE 3-----------------
# Forward pass:[[1.99169305]]
# Truth: [[2]]
#                           Backprop: [[6.90053853e-05]]
# EPOCH 999 , SAMPLE 4-----------------
# Forward pass:[[4.08098229]]
# Truth: [[4]]
#                           Backprop: [[0.00655813]]
# EPOCH 999 , SAMPLE 5-----------------
# Forward pass:[[-1.00389884]]
# Truth: [[-1]]
#                           Backprop: [[1.52009385e-05]]
# EPOCH 999 , SAMPLE 6-----------------
# Forward pass:[[2.98210554]]
# Truth: [[3]]
#                           Backprop: [[0.00032021]]
# EPOCH 999 , SAMPLE 7-----------------
# Forward pass:[[0.00912355]]
# Truth: [[0]]
#                           Backprop: [[8.3239165e-05]]
# EPOCH 999 , SAMPLE 8-----------------
# Forward pass:[[-3.00016822]]
# Truth: [[-3]]
#                           Backprop: [[2.82971072e-08]]
